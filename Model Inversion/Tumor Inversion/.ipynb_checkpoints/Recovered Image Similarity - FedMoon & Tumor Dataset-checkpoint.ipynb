# %%
# Attempting to recover training data using model's parameters and a DCGAN that was trained on similar data
# Author: Suraj Neupane
# Written from scratch as a part of a Research Project 2025, Concordia University of Edmonton.
import numpy as np

import torch
from torch import nn
from torch.nn import functional

from torch.utils import data
from torch.utils.data import DataLoader

import torchvision
from torchvision import datasets
from torchvision import transforms

import pickle

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
torch.__version__
# Out:
# '2.7.1+cu118'

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
device
# Out:
# 'cuda'

# %%
# DCGAN Implementation Class
# Discriminator
class Discriminator(nn.Module):
    def __init__(self, img_channels, features_d):
        super().__init__()
        self.disc = nn.Sequential(
            # Input shape: img_channels x 64 x 64
            nn.Conv2d(
              in_channels=img_channels, out_channels=features_d, kernel_size=4, stride=2, padding=1
            ), # Output shape: features_d x 32 x 32
            nn.LeakyReLU(0.2),
            self._block(features_d, features_d*2, 4, 2, 1), # Output shape: features_d*2 x 16 x 16
            self._block(features_d*2, features_d*4, 4, 2, 1), # Output shape: features_d*4 x 8 x 8
            self._block(features_d*4, features_d*8, 4, 2, 1), # Output shape: features_d*8 x 4 x 4
           
            nn.Conv2d(in_channels=features_d*8, out_channels=1, kernel_size=4, stride=2, padding=0), # Output shape: 1 x 1
            nn.Sigmoid(),
        )

    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(0.2),
        )

    def forward(self, X):
        return self.disc(X)

# %%
# Generator
class Generator(nn.Module):
    def __init__(self, z_dim, img_channels, features_g):
        super().__init__()
        self.gen = nn.Sequential(
            self._block(z_dim, features_g*16, 4, 1, 0), # z_dim: (batch_size, 100, 1, 1) -> (batch_size, 1024, 4, 4)
            self._block(features_g*16, features_g*8, 4, 2, 1), # z_dim: (batch_size, 1024, 4, 4) -> (batch_size, 512, 8, 8)
            self._block(features_g*8, features_g*4, 4, 2, 1), # z_dim: (batch_size, 512, 8, 8) -> (batch_size, 256, 16, 16)
            self._block(features_g*4, features_g*2, 4, 2, 1), # z_dim: (batch_size, 128, 16, 16) -> (batch_size, 64, 32, 32)
            nn.ConvTranspose2d(
                in_channels=features_g*2, out_channels=img_channels, kernel_size=4, stride=2, padding=1 # z_dim: (batch_size, 64, 32, 32) -> (batch_size, 1, 64, 64)
            ),
            nn.Tanh(),
        )
        
    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.ConvTranspose2d(
                in_channels, out_channels, kernel_size, stride, padding, bias=False,
            ),
            nn.InstanceNorm2d(out_channels, affine=True),
            nn.ReLU(),
        )

    def forward(self, X):
        return self.gen(X)

# %%
# Hyperparams
z_dim = 100
img_channels = 1
features_disc = 64
features_gen = 64

# %%
# Create the model instances
gen = Generator(z_dim, img_channels, features_gen).to(device)
disc = Discriminator(img_channels, features_disc).to(device)

# %%
# Load the trained GAN
gen.load_state_dict(torch.load('saved models/Generator2.pth', weights_only=True))
disc.load_state_dict(torch.load('saved models/Discriminator2.pth', weights_only=True))
# Out:
# <All keys matched successfully>

# %%
# Generate a random fake image
noise = torch.randn(1, z_dim, 1, 1).to(device)
fake_img = gen(noise)

# %%
fake_img.shape
# Out:
# torch.Size([1, 1, 64, 64])

# %%
fake_img = fake_img.squeeze()
print(fake_img.shape)
plt.axis(False)
plt.title('Fake Generated Image:')
plt.imshow(fake_img.cpu().detach(), cmap='gray')
# Out:
# torch.Size([64, 64])

# %%
# Target Model
class TFCNN(nn.Module):
    def __init__(self, n_classes):
        super().__init__()
        self.n_classes = n_classes

        self.encoder = nn.Sequential(
            nn.Conv2d(3, 32, 3, stride=1, padding=1),
            nn.ReLU(True),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, 3, stride=1, padding=1),
            nn.ReLU(True),
            nn.MaxPool2d(2),
            nn.Conv2d(64, 64, 3, stride=1, padding=1),
            nn.ReLU(True),
            nn.MaxPool2d(2),
            Reshape(),
        )

        self.h_size = 64 * 4 * 4

        self.classifier = nn.Sequential(
            nn.Linear(64 * 4 * 4, 128),
            nn.ReLU(True),
            nn.Linear(128, n_classes)
        )

    def forward(self, xs):
        code = self.encoder(xs)
        logits = self.classifier(code)
        return code, logits

# %%
class Reshape(nn.Module):
    def __init__(self,):
        super().__init__()

    def forward(self, xs):
        return xs.reshape((xs.shape[0], -1))

# %%
class ClassifyNet(nn.Module):
    def __init__(self, net, init_way, n_classes, input_size=None):
        super().__init__()
        self.net = net
        self.init_way = init_way
        self.n_classes = n_classes

        model = TFCNN(n_classes)

        self.h_size = model.h_size

        # Convo and pool layers
        self.encoder = model.encoder

        # Classifier layer
        self.classifier = nn.Linear(
            self.h_size, self.n_classes, bias=False
        )

        if self.init_way == "orth":
            ws = get_orth_weights(self.h_size, self.n_classes)
            self.classifier.load_state_dict({"weight": ws})

    def forward(self, xs):
        hs = self.encoder(xs)
        logits = self.classifier(hs)
        return hs, logits

# %%
def load_target_model(base_net, n_classes, path):
    # Create the base model
    model = ClassifyNet(net=base_net, init_way='none', n_classes=n_classes)
    # Load the model
    model.load_state_dict(torch.load(path, weights_only=True))

    return model

# %%
# Target Model Loading
BASE_NET = 'TFCNN'
DATASET = 'tumor4'
N_CLASSES = 4

target_model = load_target_model(base_net=BASE_NET, n_classes=N_CLASSES, path='saved models/moon_global_model.path').to(device)
print('Model loaded successfully!')
target_model.eval()

num_params = sum(p.numel() for p in target_model.parameters())
print('Number of parameters in the loaded model:', num_params)
# Out:
# Model loaded successfully!
# Number of parameters in the loaded model: 60416

# %%
# BEGIN BATCH MODEL INVERSION
img_count = 20
latent_vectors = torch.randn(img_count, z_dim, 1, 1, requires_grad=True) # Start with 20 random noises

# %%
def recover_images(count, target_image_class, latent_vectors):
    optimized_latent_vectors = []
    
    for x in range(0, count):
        z = latent_vectors[x].unsqueeze(dim=0).clone().detach().requires_grad_(True)
        
        learning_rate = 0.01
        target_class = 1 # The second class
        
        # Create the optimizer
        optimizer = torch.optim.Adam([z], lr=learning_rate)
        
        # Loss function (e.g., Cross-Entropy with classifier outputs)
        loss_fn = nn.CrossEntropyLoss()
        target_class = torch.tensor([target_image_class])  # Set the target class
    
        # Optimization loop to find the best z
        rounds = 500
        for i in range(rounds):
            optimizer.zero_grad()
            
            generated_image = gen(z.to(device))  # Generate an image from the latent vector
            generated_image = generated_image.repeat(1, 3, 1, 1)
            generated_image = functional.interpolate(generated_image, size=(32, 32), mode='nearest')
            #print(generated_image.shape)
            hs, prediction_logits = target_model(generated_image)  # Classifier output
            #print(prediction_logits)
            #print(type(prediction_logits))
            loss = loss_fn(prediction_logits, target_class.to(device))  # Minimize difference with true class
            loss.backward()
            optimizer.step()
            
            if i % 50 == 0:
                print(f"Generating Image Number: {x+1} for target class {target_class}. Step {i}, Loss: {loss.item()}")
    
        optimized_latent_vectors.append(z)
        
    return optimized_latent_vectors

# %%
class0_optimized_latent_vectors = recover_images(img_count, 0, latent_vectors)
# Out:
# Generating Image Number: 1 for target class tensor([0]). Step 0, Loss: 4.809418201446533
# Generating Image Number: 1 for target class tensor([0]). Step 50, Loss: 0.29529884457588196
# Generating Image Number: 1 for target class tensor([0]). Step 100, Loss: 0.1382039338350296
# Generating Image Number: 1 for target class tensor([0]). Step 150, Loss: 0.09621968120336533
# Generating Image Number: 1 for target class tensor([0]). Step 200, Loss: 0.0731019675731659
# Generating Image Number: 1 for target class tensor([0]). Step 250, Loss: 0.05985892191529274
# Generating Image Number: 1 for target class tensor([0]). Step 300, Loss: 0.051934678107500076
# Generating Image Number: 1 for target class tensor([0]). Step 350, Loss: 0.045656707137823105
# Generating Image Number: 1 for target class tensor([0]). Step 400, Loss: 0.03990990296006203
# Generating Image Number: 1 for target class tensor([0]). Step 450, Loss: 0.03527912497520447
# Generating Image Number: 2 for target class tensor([0]). Step 0, Loss: 0.40856117010116577
# Generating Image Number: 2 for target class tensor([0]). Step 50, Loss: 0.09378837049007416
# Generating Image Number: 2 for target class tensor([0]). Step 100, Loss: 0.053929343819618225
# Generating Image Number: 2 for target class tensor([0]). Step 150, Loss: 0.04035767540335655
# Generating Image Number: 2 for target class tensor([0]). Step 200, Loss: 0.032483454793691635
# Generating Image Number: 2 for target class tensor([0]). Step 250, Loss: 0.026954077184200287
# Generating Image Number: 2 for target class tensor([0]). Step 300, Loss: 0.02328714169561863
# Generating Image Number: 2 for target class tensor([0]). Step 350, Loss: 0.019875768572092056
# Generating Image Number: 2 for target class tensor([0]). Step 400, Loss: 0.01767503283917904
# Generating Image Number: 2 for target class tensor([0]). Step 450, Loss: 0.015878895297646523
# Generating Image Number: 3 for target class tensor([0]). Step 0, Loss: 6.626347541809082
# Generating Image Number: 3 for target class tensor([0]). Step 50, Loss: 2.0294384956359863
# Generating Image Number: 3 for target class tensor([0]). Step 100, Loss: 1.3842008113861084
# Generating Image Number: 3 for target class tensor([0]). Step 150, Loss: 0.907728910446167
# Generating Image Number: 3 for target class tensor([0]). Step 200, Loss: 0.6284003257751465
# Generating Image Number: 3 for target class tensor([0]). Step 250, Loss: 0.5559095740318298
# Generating Image Number: 3 for target class tensor([0]). Step 300, Loss: 0.44621384143829346
# Generating Image Number: 3 for target class tensor([0]). Step 350, Loss: 0.3694019317626953
# Generating Image Number: 3 for target class tensor([0]). Step 400, Loss: 0.33356916904449463
# Generating Image Number: 3 for target class tensor([0]). Step 450, Loss: 0.3072614371776581
# Generating Image Number: 4 for target class tensor([0]). Step 0, Loss: 0.8530467748641968
# Generating Image Number: 4 for target class tensor([0]). Step 50, Loss: 0.19375865161418915
# Generating Image Number: 4 for target class tensor([0]). Step 100, Loss: 0.1173735037446022
# Generating Image Number: 4 for target class tensor([0]). Step 150, Loss: 0.08429869264364243
# Generating Image Number: 4 for target class tensor([0]). Step 200, Loss: 0.06301984935998917
# Generating Image Number: 4 for target class tensor([0]). Step 250, Loss: 0.050219833850860596
# Generating Image Number: 4 for target class tensor([0]). Step 300, Loss: 0.03924199566245079
# Generating Image Number: 4 for target class tensor([0]). Step 350, Loss: 0.03267499804496765
# Generating Image Number: 4 for target class tensor([0]). Step 400, Loss: 0.0291377492249012
# Generating Image Number: 4 for target class tensor([0]). Step 450, Loss: 0.02677512727677822
# Generating Image Number: 5 for target class tensor([0]). Step 0, Loss: 0.0
# Generating Image Number: 5 for target class tensor([0]). Step 50, Loss: 0.0
# Generating Image Number: 5 for target class tensor([0]). Step 100, Loss: 0.0
# Generating Image Number: 5 for target class tensor([0]). Step 150, Loss: 0.0
# Generating Image Number: 5 for target class tensor([0]). Step 200, Loss: 0.0
# Generating Image Number: 5 for target class tensor([0]). Step 250, Loss: 0.0
# Generating Image Number: 5 for target class tensor([0]). Step 300, Loss: 0.0
# Generating Image Number: 5 for target class tensor([0]). Step 350, Loss: 0.0
# Generating Image Number: 5 for target class tensor([0]). Step 400, Loss: 0.0
# Generating Image Number: 5 for target class tensor([0]). Step 450, Loss: 0.0
# Generating Image Number: 6 for target class tensor([0]). Step 0, Loss: 0.11703984439373016
# Generating Image Number: 6 for target class tensor([0]). Step 50, Loss: 0.02763105183839798
# Generating Image Number: 6 for target class tensor([0]). Step 100, Loss: 0.019197965040802956
# Generating Image Number: 6 for target class tensor([0]). Step 150, Loss: 0.014492134563624859
# Generating Image Number: 6 for target class tensor([0]). Step 200, Loss: 0.011516991071403027
# Generating Image Number: 6 for target class tensor([0]). Step 250, Loss: 0.009302131831645966
# Generating Image Number: 6 for target class tensor([0]). Step 300, Loss: 0.007715780287981033
# Generating Image Number: 6 for target class tensor([0]). Step 350, Loss: 0.0068284254521131516
# Generating Image Number: 6 for target class tensor([0]). Step 400, Loss: 0.005674088839441538
# Generating Image Number: 6 for target class tensor([0]). Step 450, Loss: 0.004829883575439453
# Generating Image Number: 7 for target class tensor([0]). Step 0, Loss: 1.1452255249023438
# Generating Image Number: 7 for target class tensor([0]). Step 50, Loss: 0.7786062359809875
# Generating Image Number: 7 for target class tensor([0]). Step 100, Loss: 0.6332468390464783
# Generating Image Number: 7 for target class tensor([0]). Step 150, Loss: 0.5345708727836609
# Generating Image Number: 7 for target class tensor([0]). Step 200, Loss: 0.4119446277618408
# Generating Image Number: 7 for target class tensor([0]). Step 250, Loss: 0.23315481841564178
# Generating Image Number: 7 for target class tensor([0]). Step 300, Loss: 0.120916448533535
# Generating Image Number: 7 for target class tensor([0]). Step 350, Loss: 0.09174219518899918
# Generating Image Number: 7 for target class tensor([0]). Step 400, Loss: 0.07572384923696518
# Generating Image Number: 7 for target class tensor([0]). Step 450, Loss: 0.06094320863485336
# Generating Image Number: 8 for target class tensor([0]). Step 0, Loss: 0.2408725768327713
# Generating Image Number: 8 for target class tensor([0]). Step 50, Loss: 0.005603202618658543
# Generating Image Number: 8 for target class tensor([0]). Step 100, Loss: 0.004507856443524361
# Generating Image Number: 8 for target class tensor([0]). Step 150, Loss: 0.0035843905061483383
# Generating Image Number: 8 for target class tensor([0]). Step 200, Loss: 0.0030772972386330366
# Generating Image Number: 8 for target class tensor([0]). Step 250, Loss: 0.0027366350404918194
# Generating Image Number: 8 for target class tensor([0]). Step 300, Loss: 0.0024194037541747093
# Generating Image Number: 8 for target class tensor([0]). Step 350, Loss: 0.002141089178621769
# Generating Image Number: 8 for target class tensor([0]). Step 400, Loss: 0.0019250449258834124
# Generating Image Number: 8 for target class tensor([0]). Step 450, Loss: 0.0017591729993000627
# Generating Image Number: 9 for target class tensor([0]). Step 0, Loss: 0.02480504661798477
# Generating Image Number: 9 for target class tensor([0]). Step 50, Loss: 0.005955095402896404
# Generating Image Number: 9 for target class tensor([0]). Step 100, Loss: 0.0031760509591549635
# Generating Image Number: 9 for target class tensor([0]). Step 150, Loss: 0.001940036192536354
# Generating Image Number: 9 for target class tensor([0]). Step 200, Loss: 0.0016364767216145992
# Generating Image Number: 9 for target class tensor([0]). Step 250, Loss: 0.0014484162675216794
# Generating Image Number: 9 for target class tensor([0]). Step 300, Loss: 0.0013102050870656967
# Generating Image Number: 9 for target class tensor([0]). Step 350, Loss: 0.0012013844680041075
# Generating Image Number: 9 for target class tensor([0]). Step 400, Loss: 0.0011062461417168379
# Generating Image Number: 9 for target class tensor([0]). Step 450, Loss: 0.0009978797752410173
# Generating Image Number: 10 for target class tensor([0]). Step 0, Loss: 1.8298298120498657
# Generating Image Number: 10 for target class tensor([0]). Step 50, Loss: 0.6819224953651428
# Generating Image Number: 10 for target class tensor([0]). Step 100, Loss: 0.44023022055625916
# Generating Image Number: 10 for target class tensor([0]). Step 150, Loss: 0.3439432680606842
# Generating Image Number: 10 for target class tensor([0]). Step 200, Loss: 0.28155651688575745
# Generating Image Number: 10 for target class tensor([0]). Step 250, Loss: 0.21071532368659973
# Generating Image Number: 10 for target class tensor([0]). Step 300, Loss: 0.1588297188282013
# Generating Image Number: 10 for target class tensor([0]). Step 350, Loss: 0.13588258624076843
# Generating Image Number: 10 for target class tensor([0]). Step 400, Loss: 0.1194826290011406
# Generating Image Number: 10 for target class tensor([0]). Step 450, Loss: 0.10736120492219925
# Generating Image Number: 11 for target class tensor([0]). Step 0, Loss: 4.548153877258301
# Generating Image Number: 11 for target class tensor([0]). Step 50, Loss: 0.8787165880203247
# Generating Image Number: 11 for target class tensor([0]). Step 100, Loss: 0.5685550570487976
# Generating Image Number: 11 for target class tensor([0]). Step 150, Loss: 0.3982214629650116
# Generating Image Number: 11 for target class tensor([0]). Step 200, Loss: 0.30359840393066406
# Generating Image Number: 11 for target class tensor([0]). Step 250, Loss: 0.24987494945526123
# Generating Image Number: 11 for target class tensor([0]). Step 300, Loss: 0.212535560131073
# Generating Image Number: 11 for target class tensor([0]). Step 350, Loss: 0.18160121142864227
# Generating Image Number: 11 for target class tensor([0]). Step 400, Loss: 0.1588870733976364
# Generating Image Number: 11 for target class tensor([0]). Step 450, Loss: 0.13389447331428528
# Generating Image Number: 12 for target class tensor([0]). Step 0, Loss: 0.0
# Generating Image Number: 12 for target class tensor([0]). Step 50, Loss: 0.0
# Generating Image Number: 12 for target class tensor([0]). Step 100, Loss: 0.0
# Generating Image Number: 12 for target class tensor([0]). Step 150, Loss: 0.0
# Generating Image Number: 12 for target class tensor([0]). Step 200, Loss: 0.0
# Generating Image Number: 12 for target class tensor([0]). Step 250, Loss: 0.0
# Generating Image Number: 12 for target class tensor([0]). Step 300, Loss: 0.0
# Generating Image Number: 12 for target class tensor([0]). Step 350, Loss: 0.0
# Generating Image Number: 12 for target class tensor([0]). Step 400, Loss: 0.0
# Generating Image Number: 12 for target class tensor([0]). Step 450, Loss: 0.0
# Generating Image Number: 13 for target class tensor([0]). Step 0, Loss: 0.8412941694259644
# Generating Image Number: 13 for target class tensor([0]). Step 50, Loss: 0.18272504210472107
# Generating Image Number: 13 for target class tensor([0]). Step 100, Loss: 0.1162070631980896
# Generating Image Number: 13 for target class tensor([0]). Step 150, Loss: 0.0839303508400917
# Generating Image Number: 13 for target class tensor([0]). Step 200, Loss: 0.06596594303846359
# Generating Image Number: 13 for target class tensor([0]). Step 250, Loss: 0.05071423575282097
# Generating Image Number: 13 for target class tensor([0]). Step 300, Loss: 0.03642141819000244
# Generating Image Number: 13 for target class tensor([0]). Step 350, Loss: 0.03027007356286049
# Generating Image Number: 13 for target class tensor([0]). Step 400, Loss: 0.02685648202896118
# Generating Image Number: 13 for target class tensor([0]). Step 450, Loss: 0.02364206500351429
# Generating Image Number: 14 for target class tensor([0]). Step 0, Loss: 0.1016298457980156
# Generating Image Number: 14 for target class tensor([0]). Step 50, Loss: 0.003745565889403224
# Generating Image Number: 14 for target class tensor([0]). Step 100, Loss: 0.0027101237792521715
# Generating Image Number: 14 for target class tensor([0]). Step 150, Loss: 0.0022802562452852726
# Generating Image Number: 14 for target class tensor([0]). Step 200, Loss: 0.002008922165259719
# Generating Image Number: 14 for target class tensor([0]). Step 250, Loss: 0.0018102225149050355
# Generating Image Number: 14 for target class tensor([0]). Step 300, Loss: 0.0016365956980735064
# Generating Image Number: 14 for target class tensor([0]). Step 350, Loss: 0.001492696930654347
# Generating Image Number: 14 for target class tensor([0]). Step 400, Loss: 0.0013624681159853935
# Generating Image Number: 14 for target class tensor([0]). Step 450, Loss: 0.0012246021069586277
# Generating Image Number: 15 for target class tensor([0]). Step 0, Loss: 0.05385874584317207
# Generating Image Number: 15 for target class tensor([0]). Step 50, Loss: 0.010093126446008682
# Generating Image Number: 15 for target class tensor([0]). Step 100, Loss: 0.006422948557883501
# Generating Image Number: 15 for target class tensor([0]). Step 150, Loss: 0.004737462382763624
# Generating Image Number: 15 for target class tensor([0]). Step 200, Loss: 0.003745803376659751
# Generating Image Number: 15 for target class tensor([0]). Step 250, Loss: 0.0030797929503023624
# Generating Image Number: 15 for target class tensor([0]). Step 300, Loss: 0.002561147790402174
# Generating Image Number: 15 for target class tensor([0]). Step 350, Loss: 0.002198542468249798
# Generating Image Number: 15 for target class tensor([0]). Step 400, Loss: 0.0019415830029174685
# Generating Image Number: 15 for target class tensor([0]). Step 450, Loss: 0.0017062166007235646
# Generating Image Number: 16 for target class tensor([0]). Step 0, Loss: 0.0
# Generating Image Number: 16 for target class tensor([0]). Step 50, Loss: 0.0
# Generating Image Number: 16 for target class tensor([0]). Step 100, Loss: 0.0
# Generating Image Number: 16 for target class tensor([0]). Step 150, Loss: 0.0
# Generating Image Number: 16 for target class tensor([0]). Step 200, Loss: 0.0
# Generating Image Number: 16 for target class tensor([0]). Step 250, Loss: 0.0
# Generating Image Number: 16 for target class tensor([0]). Step 300, Loss: 0.0
# Generating Image Number: 16 for target class tensor([0]). Step 350, Loss: 0.0
# Generating Image Number: 16 for target class tensor([0]). Step 400, Loss: 0.0
# Generating Image Number: 16 for target class tensor([0]). Step 450, Loss: 0.0
# Generating Image Number: 17 for target class tensor([0]). Step 0, Loss: 1.6836929321289062
# Generating Image Number: 17 for target class tensor([0]). Step 50, Loss: 0.5369793772697449
# Generating Image Number: 17 for target class tensor([0]). Step 100, Loss: 0.3415885865688324
# Generating Image Number: 17 for target class tensor([0]). Step 150, Loss: 0.22927269339561462
# Generating Image Number: 17 for target class tensor([0]). Step 200, Loss: 0.15998001396656036
# Generating Image Number: 17 for target class tensor([0]). Step 250, Loss: 0.1186031773686409
# Generating Image Number: 17 for target class tensor([0]). Step 300, Loss: 0.09157523512840271
# Generating Image Number: 17 for target class tensor([0]). Step 350, Loss: 0.07232990860939026
# Generating Image Number: 17 for target class tensor([0]). Step 400, Loss: 0.0551062747836113
# Generating Image Number: 17 for target class tensor([0]). Step 450, Loss: 0.04370183125138283
# Generating Image Number: 18 for target class tensor([0]). Step 0, Loss: 0.6660953760147095
# Generating Image Number: 18 for target class tensor([0]). Step 50, Loss: 0.027536539360880852
# Generating Image Number: 18 for target class tensor([0]). Step 100, Loss: 0.00963631458580494
# Generating Image Number: 18 for target class tensor([0]). Step 150, Loss: 0.0055954973213374615
# Generating Image Number: 18 for target class tensor([0]). Step 200, Loss: 0.005134491249918938
# Generating Image Number: 18 for target class tensor([0]). Step 250, Loss: 0.004746598191559315
# Generating Image Number: 18 for target class tensor([0]). Step 300, Loss: 0.004419797100126743
# Generating Image Number: 18 for target class tensor([0]). Step 350, Loss: 0.004111884627491236
# Generating Image Number: 18 for target class tensor([0]). Step 400, Loss: 0.0038658662233501673
# Generating Image Number: 18 for target class tensor([0]). Step 450, Loss: 0.003660408779978752
# Generating Image Number: 19 for target class tensor([0]). Step 0, Loss: 2.077580451965332
# Generating Image Number: 19 for target class tensor([0]). Step 50, Loss: 0.8305138945579529
# Generating Image Number: 19 for target class tensor([0]). Step 100, Loss: 0.5060155987739563
# Generating Image Number: 19 for target class tensor([0]). Step 150, Loss: 0.3417282700538635
# Generating Image Number: 19 for target class tensor([0]). Step 200, Loss: 0.25442519783973694
# Generating Image Number: 19 for target class tensor([0]). Step 250, Loss: 0.1999947428703308
# Generating Image Number: 19 for target class tensor([0]). Step 300, Loss: 0.15860512852668762
# Generating Image Number: 19 for target class tensor([0]). Step 350, Loss: 0.13682588934898376
# Generating Image Number: 19 for target class tensor([0]). Step 400, Loss: 0.1172441691160202
# Generating Image Number: 19 for target class tensor([0]). Step 450, Loss: 0.1028984859585762
# Generating Image Number: 20 for target class tensor([0]). Step 0, Loss: 2.6677138805389404
# Generating Image Number: 20 for target class tensor([0]). Step 50, Loss: 0.23732982575893402
# Generating Image Number: 20 for target class tensor([0]). Step 100, Loss: 0.1466311663389206
# Generating Image Number: 20 for target class tensor([0]). Step 150, Loss: 0.11588256806135178
# Generating Image Number: 20 for target class tensor([0]). Step 200, Loss: 0.0960996001958847
# Generating Image Number: 20 for target class tensor([0]). Step 250, Loss: 0.07897336035966873
# Generating Image Number: 20 for target class tensor([0]). Step 300, Loss: 0.06636036932468414
# Generating Image Number: 20 for target class tensor([0]). Step 350, Loss: 0.05809969827532768
# Generating Image Number: 20 for target class tensor([0]). Step 400, Loss: 0.05086459219455719
# Generating Image Number: 20 for target class tensor([0]). Step 450, Loss: 0.04459960386157036

# %%
torch.manual_seed(100)
latent_vectors = torch.randn(img_count, z_dim, 1, 1, requires_grad=True) # Start with 20 random noises
class1_optimized_latent_vectors = recover_images(img_count, 1, latent_vectors)
# Out:
# Generating Image Number: 1 for target class tensor([1]). Step 0, Loss: 6.273411273956299
# Generating Image Number: 1 for target class tensor([1]). Step 50, Loss: 5.215507984161377
# Generating Image Number: 1 for target class tensor([1]). Step 100, Loss: 3.5871338844299316
# Generating Image Number: 1 for target class tensor([1]). Step 150, Loss: 2.469475269317627
# Generating Image Number: 1 for target class tensor([1]). Step 200, Loss: 1.6467328071594238
# Generating Image Number: 1 for target class tensor([1]). Step 250, Loss: 1.3009039163589478
# Generating Image Number: 1 for target class tensor([1]). Step 300, Loss: 1.0930759906768799
# Generating Image Number: 1 for target class tensor([1]). Step 350, Loss: 0.9134984016418457
# Generating Image Number: 1 for target class tensor([1]). Step 400, Loss: 0.7818706631660461
# Generating Image Number: 1 for target class tensor([1]). Step 450, Loss: 0.6913113594055176
# Generating Image Number: 2 for target class tensor([1]). Step 0, Loss: 9.364476203918457
# Generating Image Number: 2 for target class tensor([1]). Step 50, Loss: 3.4222066402435303
# Generating Image Number: 2 for target class tensor([1]). Step 100, Loss: 2.2538652420043945
# Generating Image Number: 2 for target class tensor([1]). Step 150, Loss: 1.4565150737762451
# Generating Image Number: 2 for target class tensor([1]). Step 200, Loss: 1.043093204498291
# Generating Image Number: 2 for target class tensor([1]). Step 250, Loss: 0.7324917316436768
# Generating Image Number: 2 for target class tensor([1]). Step 300, Loss: 0.5069863796234131
# Generating Image Number: 2 for target class tensor([1]). Step 350, Loss: 0.3859587013721466
# Generating Image Number: 2 for target class tensor([1]). Step 400, Loss: 0.3227609395980835
# Generating Image Number: 2 for target class tensor([1]). Step 450, Loss: 0.28410711884498596
# Generating Image Number: 3 for target class tensor([1]). Step 0, Loss: 10.159700393676758
# Generating Image Number: 3 for target class tensor([1]). Step 50, Loss: 6.527406692504883
# Generating Image Number: 3 for target class tensor([1]). Step 100, Loss: 5.287830352783203
# Generating Image Number: 3 for target class tensor([1]). Step 150, Loss: 4.654868125915527
# Generating Image Number: 3 for target class tensor([1]). Step 200, Loss: 4.2392706871032715
# Generating Image Number: 3 for target class tensor([1]). Step 250, Loss: 3.9504406452178955
# Generating Image Number: 3 for target class tensor([1]). Step 300, Loss: 3.64728045463562
# Generating Image Number: 3 for target class tensor([1]). Step 350, Loss: 3.4747891426086426
# Generating Image Number: 3 for target class tensor([1]). Step 400, Loss: 3.3485703468322754
# Generating Image Number: 3 for target class tensor([1]). Step 450, Loss: 3.054769515991211
# Generating Image Number: 4 for target class tensor([1]). Step 0, Loss: 14.389554977416992
# Generating Image Number: 4 for target class tensor([1]). Step 50, Loss: 7.18043851852417
# Generating Image Number: 4 for target class tensor([1]). Step 100, Loss: 6.515439033508301
# Generating Image Number: 4 for target class tensor([1]). Step 150, Loss: 5.690128803253174
# Generating Image Number: 4 for target class tensor([1]). Step 200, Loss: 5.073606014251709
# Generating Image Number: 4 for target class tensor([1]). Step 250, Loss: 4.555974960327148
# Generating Image Number: 4 for target class tensor([1]). Step 300, Loss: 4.281042575836182
# Generating Image Number: 4 for target class tensor([1]). Step 350, Loss: 4.025703430175781
# Generating Image Number: 4 for target class tensor([1]). Step 400, Loss: 3.883192539215088
# Generating Image Number: 4 for target class tensor([1]). Step 450, Loss: 3.791231393814087
# Generating Image Number: 5 for target class tensor([1]). Step 0, Loss: 9.548149108886719
# Generating Image Number: 5 for target class tensor([1]). Step 50, Loss: 7.006830215454102
# Generating Image Number: 5 for target class tensor([1]). Step 100, Loss: 6.139742374420166
# Generating Image Number: 5 for target class tensor([1]). Step 150, Loss: 5.375448226928711
# Generating Image Number: 5 for target class tensor([1]). Step 200, Loss: 4.844604015350342
# Generating Image Number: 5 for target class tensor([1]). Step 250, Loss: 4.49949836730957
# Generating Image Number: 5 for target class tensor([1]). Step 300, Loss: 4.339674472808838
# Generating Image Number: 5 for target class tensor([1]). Step 350, Loss: 4.209705352783203
# Generating Image Number: 5 for target class tensor([1]). Step 400, Loss: 4.09226655960083
# Generating Image Number: 5 for target class tensor([1]). Step 450, Loss: 4.014174938201904
# Generating Image Number: 6 for target class tensor([1]). Step 0, Loss: 7.41499137878418
# Generating Image Number: 6 for target class tensor([1]). Step 50, Loss: 5.710358142852783
# Generating Image Number: 6 for target class tensor([1]). Step 100, Loss: 5.000227451324463
# Generating Image Number: 6 for target class tensor([1]). Step 150, Loss: 4.611586570739746
# Generating Image Number: 6 for target class tensor([1]). Step 200, Loss: 4.3402862548828125
# Generating Image Number: 6 for target class tensor([1]). Step 250, Loss: 4.015042781829834
# Generating Image Number: 6 for target class tensor([1]). Step 300, Loss: 3.781303644180298
# Generating Image Number: 6 for target class tensor([1]). Step 350, Loss: 3.5864145755767822
# Generating Image Number: 6 for target class tensor([1]). Step 400, Loss: 3.478792190551758
# Generating Image Number: 6 for target class tensor([1]). Step 450, Loss: 3.3561794757843018
# Generating Image Number: 7 for target class tensor([1]). Step 0, Loss: 41.2856330871582
# Generating Image Number: 7 for target class tensor([1]). Step 50, Loss: 7.094684600830078
# Generating Image Number: 7 for target class tensor([1]). Step 100, Loss: 6.41505765914917
# Generating Image Number: 7 for target class tensor([1]). Step 150, Loss: 5.944859981536865
# Generating Image Number: 7 for target class tensor([1]). Step 200, Loss: 5.3967366218566895
# Generating Image Number: 7 for target class tensor([1]). Step 250, Loss: 4.827361106872559
# Generating Image Number: 7 for target class tensor([1]). Step 300, Loss: 4.224559307098389
# Generating Image Number: 7 for target class tensor([1]). Step 350, Loss: 3.765374183654785
# Generating Image Number: 7 for target class tensor([1]). Step 400, Loss: 3.31532621383667
# Generating Image Number: 7 for target class tensor([1]). Step 450, Loss: 2.981001377105713
# Generating Image Number: 8 for target class tensor([1]). Step 0, Loss: 40.4256591796875
# Generating Image Number: 8 for target class tensor([1]). Step 50, Loss: 34.49791717529297
# Generating Image Number: 8 for target class tensor([1]). Step 100, Loss: 34.36295700073242
# Generating Image Number: 8 for target class tensor([1]). Step 150, Loss: 34.690284729003906
# Generating Image Number: 8 for target class tensor([1]). Step 200, Loss: 34.3563117980957
# Generating Image Number: 8 for target class tensor([1]). Step 250, Loss: 34.28867721557617
# Generating Image Number: 8 for target class tensor([1]). Step 300, Loss: 34.308998107910156
# Generating Image Number: 8 for target class tensor([1]). Step 350, Loss: 34.77576446533203
# Generating Image Number: 8 for target class tensor([1]). Step 400, Loss: 34.25062942504883
# Generating Image Number: 8 for target class tensor([1]). Step 450, Loss: 34.4760627746582
# Generating Image Number: 9 for target class tensor([1]). Step 0, Loss: 16.975549697875977
# Generating Image Number: 9 for target class tensor([1]). Step 50, Loss: 6.458148956298828
# Generating Image Number: 9 for target class tensor([1]). Step 100, Loss: 5.456652641296387
# Generating Image Number: 9 for target class tensor([1]). Step 150, Loss: 4.690460205078125
# Generating Image Number: 9 for target class tensor([1]). Step 200, Loss: 4.232767105102539
# Generating Image Number: 9 for target class tensor([1]). Step 250, Loss: 3.719329833984375
# Generating Image Number: 9 for target class tensor([1]). Step 300, Loss: 2.8396546840667725
# Generating Image Number: 9 for target class tensor([1]). Step 350, Loss: 1.949618935585022
# Generating Image Number: 9 for target class tensor([1]). Step 400, Loss: 1.5131001472473145
# Generating Image Number: 9 for target class tensor([1]). Step 450, Loss: 1.114833116531372
# Generating Image Number: 10 for target class tensor([1]). Step 0, Loss: 12.74010181427002
# Generating Image Number: 10 for target class tensor([1]). Step 50, Loss: 5.583806037902832
# Generating Image Number: 10 for target class tensor([1]). Step 100, Loss: 4.528604507446289
# Generating Image Number: 10 for target class tensor([1]). Step 150, Loss: 3.97153639793396
# Generating Image Number: 10 for target class tensor([1]). Step 200, Loss: 3.4110422134399414
# Generating Image Number: 10 for target class tensor([1]). Step 250, Loss: 2.766831159591675
# Generating Image Number: 10 for target class tensor([1]). Step 300, Loss: 2.2957913875579834
# Generating Image Number: 10 for target class tensor([1]). Step 350, Loss: 1.6716599464416504
# Generating Image Number: 10 for target class tensor([1]). Step 400, Loss: 1.1977696418762207
# Generating Image Number: 10 for target class tensor([1]). Step 450, Loss: 0.8857924938201904
# Generating Image Number: 11 for target class tensor([1]). Step 0, Loss: 6.604772090911865
# Generating Image Number: 11 for target class tensor([1]). Step 50, Loss: 3.1681485176086426
# Generating Image Number: 11 for target class tensor([1]). Step 100, Loss: 2.1155779361724854
# Generating Image Number: 11 for target class tensor([1]). Step 150, Loss: 1.6672286987304688
# Generating Image Number: 11 for target class tensor([1]). Step 200, Loss: 1.560760259628296
# Generating Image Number: 11 for target class tensor([1]). Step 250, Loss: 1.479559063911438
# Generating Image Number: 11 for target class tensor([1]). Step 300, Loss: 1.2700889110565186
# Generating Image Number: 11 for target class tensor([1]). Step 350, Loss: 1.1643121242523193
# Generating Image Number: 11 for target class tensor([1]). Step 400, Loss: 1.0760996341705322
# Generating Image Number: 11 for target class tensor([1]). Step 450, Loss: 1.0241624116897583
# Generating Image Number: 12 for target class tensor([1]). Step 0, Loss: 14.881876945495605
# Generating Image Number: 12 for target class tensor([1]). Step 50, Loss: 14.195555686950684
# Generating Image Number: 12 for target class tensor([1]). Step 100, Loss: 13.721138954162598
# Generating Image Number: 12 for target class tensor([1]). Step 150, Loss: 13.373138427734375
# Generating Image Number: 12 for target class tensor([1]). Step 200, Loss: 12.976344108581543
# Generating Image Number: 12 for target class tensor([1]). Step 250, Loss: 12.55313491821289
# Generating Image Number: 12 for target class tensor([1]). Step 300, Loss: 12.064023971557617
# Generating Image Number: 12 for target class tensor([1]). Step 350, Loss: 11.776477813720703
# Generating Image Number: 12 for target class tensor([1]). Step 400, Loss: 11.563774108886719
# Generating Image Number: 12 for target class tensor([1]). Step 450, Loss: 11.419000625610352
# Generating Image Number: 13 for target class tensor([1]). Step 0, Loss: 11.344414710998535
# Generating Image Number: 13 for target class tensor([1]). Step 50, Loss: 6.355985641479492
# Generating Image Number: 13 for target class tensor([1]). Step 100, Loss: 6.028796195983887
# Generating Image Number: 13 for target class tensor([1]). Step 150, Loss: 5.738590240478516
# Generating Image Number: 13 for target class tensor([1]). Step 200, Loss: 5.545837879180908
# Generating Image Number: 13 for target class tensor([1]). Step 250, Loss: 5.353507995605469
# Generating Image Number: 13 for target class tensor([1]). Step 300, Loss: 5.153329372406006
# Generating Image Number: 13 for target class tensor([1]). Step 350, Loss: 4.956457138061523
# Generating Image Number: 13 for target class tensor([1]). Step 400, Loss: 4.763273239135742
# Generating Image Number: 13 for target class tensor([1]). Step 450, Loss: 4.593619346618652
# Generating Image Number: 14 for target class tensor([1]). Step 0, Loss: 9.55379581451416
# Generating Image Number: 14 for target class tensor([1]). Step 50, Loss: 2.1038482189178467
# Generating Image Number: 14 for target class tensor([1]). Step 100, Loss: 1.4730186462402344
# Generating Image Number: 14 for target class tensor([1]). Step 150, Loss: 1.1206207275390625
# Generating Image Number: 14 for target class tensor([1]). Step 200, Loss: 0.8476587533950806
# Generating Image Number: 14 for target class tensor([1]). Step 250, Loss: 0.6156501173973083
# Generating Image Number: 14 for target class tensor([1]). Step 300, Loss: 0.4865405559539795
# Generating Image Number: 14 for target class tensor([1]). Step 350, Loss: 0.39095526933670044
# Generating Image Number: 14 for target class tensor([1]). Step 400, Loss: 0.3269655406475067
# Generating Image Number: 14 for target class tensor([1]). Step 450, Loss: 0.27408725023269653
# Generating Image Number: 15 for target class tensor([1]). Step 0, Loss: 7.937952041625977
# Generating Image Number: 15 for target class tensor([1]). Step 50, Loss: 2.02384877204895
# Generating Image Number: 15 for target class tensor([1]). Step 100, Loss: 1.5402419567108154
# Generating Image Number: 15 for target class tensor([1]). Step 150, Loss: 1.2885937690734863
# Generating Image Number: 15 for target class tensor([1]). Step 200, Loss: 1.1328656673431396
# Generating Image Number: 15 for target class tensor([1]). Step 250, Loss: 0.9298420548439026
# Generating Image Number: 15 for target class tensor([1]). Step 300, Loss: 0.7809153199195862
# Generating Image Number: 15 for target class tensor([1]). Step 350, Loss: 0.7300679087638855
# Generating Image Number: 15 for target class tensor([1]). Step 400, Loss: 0.6464137434959412
# Generating Image Number: 15 for target class tensor([1]). Step 450, Loss: 0.5735770463943481
# Generating Image Number: 16 for target class tensor([1]). Step 0, Loss: 42.07805633544922
# Generating Image Number: 16 for target class tensor([1]). Step 50, Loss: 6.986656665802002
# Generating Image Number: 16 for target class tensor([1]). Step 100, Loss: 6.690546989440918
# Generating Image Number: 16 for target class tensor([1]). Step 150, Loss: 6.493189334869385
# Generating Image Number: 16 for target class tensor([1]). Step 200, Loss: 6.306543350219727
# Generating Image Number: 16 for target class tensor([1]). Step 250, Loss: 6.157317638397217
# Generating Image Number: 16 for target class tensor([1]). Step 300, Loss: 6.008144855499268
# Generating Image Number: 16 for target class tensor([1]). Step 350, Loss: 5.854581832885742
# Generating Image Number: 16 for target class tensor([1]). Step 400, Loss: 5.712048530578613
# Generating Image Number: 16 for target class tensor([1]). Step 450, Loss: 5.559022903442383
# Generating Image Number: 17 for target class tensor([1]). Step 0, Loss: 11.197909355163574
# Generating Image Number: 17 for target class tensor([1]). Step 50, Loss: 2.744602680206299
# Generating Image Number: 17 for target class tensor([1]). Step 100, Loss: 1.8433805704116821
# Generating Image Number: 17 for target class tensor([1]). Step 150, Loss: 1.434985637664795
# Generating Image Number: 17 for target class tensor([1]). Step 200, Loss: 1.1485528945922852
# Generating Image Number: 17 for target class tensor([1]). Step 250, Loss: 0.889891505241394
# Generating Image Number: 17 for target class tensor([1]). Step 300, Loss: 0.7258804440498352
# Generating Image Number: 17 for target class tensor([1]). Step 350, Loss: 0.5974984765052795
# Generating Image Number: 17 for target class tensor([1]). Step 400, Loss: 0.5024378299713135
# Generating Image Number: 17 for target class tensor([1]). Step 450, Loss: 0.4244486689567566
# Generating Image Number: 18 for target class tensor([1]). Step 0, Loss: 10.545682907104492
# Generating Image Number: 18 for target class tensor([1]). Step 50, Loss: 7.453155040740967
# Generating Image Number: 18 for target class tensor([1]). Step 100, Loss: 6.104131698608398
# Generating Image Number: 18 for target class tensor([1]). Step 150, Loss: 4.669488430023193
# Generating Image Number: 18 for target class tensor([1]). Step 200, Loss: 3.5901312828063965
# Generating Image Number: 18 for target class tensor([1]). Step 250, Loss: 2.935671806335449
# Generating Image Number: 18 for target class tensor([1]). Step 300, Loss: 2.373347043991089
# Generating Image Number: 18 for target class tensor([1]). Step 350, Loss: 1.8461697101593018
# Generating Image Number: 18 for target class tensor([1]). Step 400, Loss: 1.5990967750549316
# Generating Image Number: 18 for target class tensor([1]). Step 450, Loss: 1.3987274169921875
# Generating Image Number: 19 for target class tensor([1]). Step 0, Loss: 1.4180407524108887
# Generating Image Number: 19 for target class tensor([1]). Step 50, Loss: 8.018648147583008
# Generating Image Number: 19 for target class tensor([1]). Step 100, Loss: 6.548840045928955
# Generating Image Number: 19 for target class tensor([1]). Step 150, Loss: 6.3193769454956055
# Generating Image Number: 19 for target class tensor([1]). Step 200, Loss: 6.063229560852051
# Generating Image Number: 19 for target class tensor([1]). Step 250, Loss: 5.802132606506348
# Generating Image Number: 19 for target class tensor([1]). Step 300, Loss: 5.620872497558594
# Generating Image Number: 19 for target class tensor([1]). Step 350, Loss: 5.286604404449463
# Generating Image Number: 19 for target class tensor([1]). Step 400, Loss: 4.941188812255859
# Generating Image Number: 19 for target class tensor([1]). Step 450, Loss: 4.667169094085693
# Generating Image Number: 20 for target class tensor([1]). Step 0, Loss: 5.471391201019287
# Generating Image Number: 20 for target class tensor([1]). Step 50, Loss: 2.6109087467193604
# Generating Image Number: 20 for target class tensor([1]). Step 100, Loss: 1.836878776550293
# Generating Image Number: 20 for target class tensor([1]). Step 150, Loss: 1.3811166286468506
# Generating Image Number: 20 for target class tensor([1]). Step 200, Loss: 1.0211186408996582
# Generating Image Number: 20 for target class tensor([1]). Step 250, Loss: 0.7778071761131287
# Generating Image Number: 20 for target class tensor([1]). Step 300, Loss: 0.6186357140541077
# Generating Image Number: 20 for target class tensor([1]). Step 350, Loss: 0.5144988894462585
# Generating Image Number: 20 for target class tensor([1]). Step 400, Loss: 0.4239315390586853
# Generating Image Number: 20 for target class tensor([1]). Step 450, Loss: 0.35824835300445557

# %%
torch.manual_seed(200)
latent_vectors = torch.randn(img_count, z_dim, 1, 1, requires_grad=True) # Start with 20 random noises
class2_optimized_latent_vectors = recover_images(img_count, 2, latent_vectors)
# Out:
# Generating Image Number: 1 for target class tensor([2]). Step 0, Loss: 3.181877613067627
# Generating Image Number: 1 for target class tensor([2]). Step 50, Loss: 0.3069502115249634
# Generating Image Number: 1 for target class tensor([2]). Step 100, Loss: 0.1355961710214615
# Generating Image Number: 1 for target class tensor([2]). Step 150, Loss: 0.08395808190107346
# Generating Image Number: 1 for target class tensor([2]). Step 200, Loss: 0.06428741663694382
# Generating Image Number: 1 for target class tensor([2]). Step 250, Loss: 0.05386767163872719
# Generating Image Number: 1 for target class tensor([2]). Step 300, Loss: 0.04772518202662468
# Generating Image Number: 1 for target class tensor([2]). Step 350, Loss: 0.041748154908418655
# Generating Image Number: 1 for target class tensor([2]). Step 400, Loss: 0.0368339903652668
# Generating Image Number: 1 for target class tensor([2]). Step 450, Loss: 0.033424898982048035
# Generating Image Number: 2 for target class tensor([2]). Step 0, Loss: 1.4458283185958862
# Generating Image Number: 2 for target class tensor([2]). Step 50, Loss: 0.24281945824623108
# Generating Image Number: 2 for target class tensor([2]). Step 100, Loss: 0.123885378241539
# Generating Image Number: 2 for target class tensor([2]). Step 150, Loss: 0.08463414013385773
# Generating Image Number: 2 for target class tensor([2]). Step 200, Loss: 0.05738823115825653
# Generating Image Number: 2 for target class tensor([2]). Step 250, Loss: 0.043039534240961075
# Generating Image Number: 2 for target class tensor([2]). Step 300, Loss: 0.03368011862039566
# Generating Image Number: 2 for target class tensor([2]). Step 350, Loss: 0.028791721910238266
# Generating Image Number: 2 for target class tensor([2]). Step 400, Loss: 0.025896402075886726
# Generating Image Number: 2 for target class tensor([2]). Step 450, Loss: 0.023549271747469902
# Generating Image Number: 3 for target class tensor([2]). Step 0, Loss: 1.1454710960388184
# Generating Image Number: 3 for target class tensor([2]). Step 50, Loss: 0.18918323516845703
# Generating Image Number: 3 for target class tensor([2]). Step 100, Loss: 0.07053696364164352
# Generating Image Number: 3 for target class tensor([2]). Step 150, Loss: 0.04836609587073326
# Generating Image Number: 3 for target class tensor([2]). Step 200, Loss: 0.03742634505033493
# Generating Image Number: 3 for target class tensor([2]). Step 250, Loss: 0.029385268688201904
# Generating Image Number: 3 for target class tensor([2]). Step 300, Loss: 0.024666769430041313
# Generating Image Number: 3 for target class tensor([2]). Step 350, Loss: 0.0212701428681612
# Generating Image Number: 3 for target class tensor([2]). Step 400, Loss: 0.01856732927262783
# Generating Image Number: 3 for target class tensor([2]). Step 450, Loss: 0.016246778890490532
# Generating Image Number: 4 for target class tensor([2]). Step 0, Loss: 0.7646102905273438
# Generating Image Number: 4 for target class tensor([2]). Step 50, Loss: 0.00367881846614182
# Generating Image Number: 4 for target class tensor([2]). Step 100, Loss: 0.0022135297767817974
# Generating Image Number: 4 for target class tensor([2]). Step 150, Loss: 0.0015048381173983216
# Generating Image Number: 4 for target class tensor([2]). Step 200, Loss: 0.001176618505269289
# Generating Image Number: 4 for target class tensor([2]). Step 250, Loss: 0.0008000510279089212
# Generating Image Number: 4 for target class tensor([2]). Step 300, Loss: 0.00044705410255119205
# Generating Image Number: 4 for target class tensor([2]). Step 350, Loss: 0.0003252692404203117
# Generating Image Number: 4 for target class tensor([2]). Step 400, Loss: 0.00025900822947733104
# Generating Image Number: 4 for target class tensor([2]). Step 450, Loss: 0.0002131234941771254
# Generating Image Number: 5 for target class tensor([2]). Step 0, Loss: 1.3695297241210938
# Generating Image Number: 5 for target class tensor([2]). Step 50, Loss: 0.33954623341560364
# Generating Image Number: 5 for target class tensor([2]). Step 100, Loss: 0.15318171679973602
# Generating Image Number: 5 for target class tensor([2]). Step 150, Loss: 0.10254382342100143
# Generating Image Number: 5 for target class tensor([2]). Step 200, Loss: 0.07634077966213226
# Generating Image Number: 5 for target class tensor([2]). Step 250, Loss: 0.05887461453676224
# Generating Image Number: 5 for target class tensor([2]). Step 300, Loss: 0.046103622764348984
# Generating Image Number: 5 for target class tensor([2]). Step 350, Loss: 0.038511015474796295
# Generating Image Number: 5 for target class tensor([2]). Step 400, Loss: 0.03198642283678055
# Generating Image Number: 5 for target class tensor([2]). Step 450, Loss: 0.02726570889353752
# Generating Image Number: 6 for target class tensor([2]). Step 0, Loss: 1.7407152652740479
# Generating Image Number: 6 for target class tensor([2]). Step 50, Loss: 0.3055739402770996
# Generating Image Number: 6 for target class tensor([2]). Step 100, Loss: 0.18123680353164673
# Generating Image Number: 6 for target class tensor([2]). Step 150, Loss: 0.13896477222442627
# Generating Image Number: 6 for target class tensor([2]). Step 200, Loss: 0.11069826781749725
# Generating Image Number: 6 for target class tensor([2]). Step 250, Loss: 0.0915771946310997
# Generating Image Number: 6 for target class tensor([2]). Step 300, Loss: 0.08019755780696869
# Generating Image Number: 6 for target class tensor([2]). Step 350, Loss: 0.06863072514533997
# Generating Image Number: 6 for target class tensor([2]). Step 400, Loss: 0.06012353673577309
# Generating Image Number: 6 for target class tensor([2]). Step 450, Loss: 0.05362613871693611
# Generating Image Number: 7 for target class tensor([2]). Step 0, Loss: 2.2268035411834717
# Generating Image Number: 7 for target class tensor([2]). Step 50, Loss: 0.34785544872283936
# Generating Image Number: 7 for target class tensor([2]). Step 100, Loss: 0.18398745357990265
# Generating Image Number: 7 for target class tensor([2]). Step 150, Loss: 0.13336630165576935
# Generating Image Number: 7 for target class tensor([2]). Step 200, Loss: 0.10684647411108017
# Generating Image Number: 7 for target class tensor([2]). Step 250, Loss: 0.08762720227241516
# Generating Image Number: 7 for target class tensor([2]). Step 300, Loss: 0.0750783383846283
# Generating Image Number: 7 for target class tensor([2]). Step 350, Loss: 0.06531544029712677
# Generating Image Number: 7 for target class tensor([2]). Step 400, Loss: 0.06005135551095009
# Generating Image Number: 7 for target class tensor([2]). Step 450, Loss: 0.055655546486377716
# Generating Image Number: 8 for target class tensor([2]). Step 0, Loss: 2.1586191654205322
# Generating Image Number: 8 for target class tensor([2]). Step 50, Loss: 0.8595134019851685
# Generating Image Number: 8 for target class tensor([2]). Step 100, Loss: 0.44100362062454224
# Generating Image Number: 8 for target class tensor([2]). Step 150, Loss: 0.2950296700000763
# Generating Image Number: 8 for target class tensor([2]). Step 200, Loss: 0.219148650765419
# Generating Image Number: 8 for target class tensor([2]). Step 250, Loss: 0.16189327836036682
# Generating Image Number: 8 for target class tensor([2]). Step 300, Loss: 0.12479313462972641
# Generating Image Number: 8 for target class tensor([2]). Step 350, Loss: 0.099937804043293
# Generating Image Number: 8 for target class tensor([2]). Step 400, Loss: 0.08070188015699387
# Generating Image Number: 8 for target class tensor([2]). Step 450, Loss: 0.06840008497238159
# Generating Image Number: 9 for target class tensor([2]). Step 0, Loss: 0.26971080899238586
# Generating Image Number: 9 for target class tensor([2]). Step 50, Loss: 0.022107701748609543
# Generating Image Number: 9 for target class tensor([2]). Step 100, Loss: 0.015125461854040623
# Generating Image Number: 9 for target class tensor([2]). Step 150, Loss: 0.01164920348674059
# Generating Image Number: 9 for target class tensor([2]). Step 200, Loss: 0.009312288835644722
# Generating Image Number: 9 for target class tensor([2]). Step 250, Loss: 0.007722877897322178
# Generating Image Number: 9 for target class tensor([2]). Step 300, Loss: 0.006519358605146408
# Generating Image Number: 9 for target class tensor([2]). Step 350, Loss: 0.00555151654407382
# Generating Image Number: 9 for target class tensor([2]). Step 400, Loss: 0.0048020039685070515
# Generating Image Number: 9 for target class tensor([2]). Step 450, Loss: 0.004238788038492203
# Generating Image Number: 10 for target class tensor([2]). Step 0, Loss: 1.9570283889770508
# Generating Image Number: 10 for target class tensor([2]). Step 50, Loss: 0.6770551204681396
# Generating Image Number: 10 for target class tensor([2]). Step 100, Loss: 0.5071290731430054
# Generating Image Number: 10 for target class tensor([2]). Step 150, Loss: 0.34899383783340454
# Generating Image Number: 10 for target class tensor([2]). Step 200, Loss: 0.2446122020483017
# Generating Image Number: 10 for target class tensor([2]). Step 250, Loss: 0.2046758234500885
# Generating Image Number: 10 for target class tensor([2]). Step 300, Loss: 0.18054130673408508
# Generating Image Number: 10 for target class tensor([2]). Step 350, Loss: 0.15608027577400208
# Generating Image Number: 10 for target class tensor([2]). Step 400, Loss: 0.14152084290981293
# Generating Image Number: 10 for target class tensor([2]). Step 450, Loss: 0.13187657296657562
# Generating Image Number: 11 for target class tensor([2]). Step 0, Loss: 1.251276969909668
# Generating Image Number: 11 for target class tensor([2]). Step 50, Loss: 0.1296488642692566
# Generating Image Number: 11 for target class tensor([2]). Step 100, Loss: 0.0722680315375328
# Generating Image Number: 11 for target class tensor([2]). Step 150, Loss: 0.05560040846467018
# Generating Image Number: 11 for target class tensor([2]). Step 200, Loss: 0.04633810371160507
# Generating Image Number: 11 for target class tensor([2]). Step 250, Loss: 0.0408652126789093
# Generating Image Number: 11 for target class tensor([2]). Step 300, Loss: 0.035801324993371964
# Generating Image Number: 11 for target class tensor([2]). Step 350, Loss: 0.031120585277676582
# Generating Image Number: 11 for target class tensor([2]). Step 400, Loss: 0.027201209217309952
# Generating Image Number: 11 for target class tensor([2]). Step 450, Loss: 0.024649672210216522
# Generating Image Number: 12 for target class tensor([2]). Step 0, Loss: 33.215087890625
# Generating Image Number: 12 for target class tensor([2]). Step 50, Loss: 26.785438537597656
# Generating Image Number: 12 for target class tensor([2]). Step 100, Loss: 26.273609161376953
# Generating Image Number: 12 for target class tensor([2]). Step 150, Loss: 26.000246047973633
# Generating Image Number: 12 for target class tensor([2]). Step 200, Loss: 25.859716415405273
# Generating Image Number: 12 for target class tensor([2]). Step 250, Loss: 25.794185638427734
# Generating Image Number: 12 for target class tensor([2]). Step 300, Loss: 25.719852447509766
# Generating Image Number: 12 for target class tensor([2]). Step 350, Loss: 25.833417892456055
# Generating Image Number: 12 for target class tensor([2]). Step 400, Loss: 25.661434173583984
# Generating Image Number: 12 for target class tensor([2]). Step 450, Loss: 25.600543975830078
# Generating Image Number: 13 for target class tensor([2]). Step 0, Loss: 0.8264676928520203
# Generating Image Number: 13 for target class tensor([2]). Step 50, Loss: 0.2855415642261505
# Generating Image Number: 13 for target class tensor([2]). Step 100, Loss: 0.18049204349517822
# Generating Image Number: 13 for target class tensor([2]). Step 150, Loss: 0.13706737756729126
# Generating Image Number: 13 for target class tensor([2]). Step 200, Loss: 0.10986968874931335
# Generating Image Number: 13 for target class tensor([2]). Step 250, Loss: 0.0965099185705185
# Generating Image Number: 13 for target class tensor([2]). Step 300, Loss: 0.08186805993318558
# Generating Image Number: 13 for target class tensor([2]). Step 350, Loss: 0.07170162349939346
# Generating Image Number: 13 for target class tensor([2]). Step 400, Loss: 0.06369969248771667
# Generating Image Number: 13 for target class tensor([2]). Step 450, Loss: 0.05717084929347038
# Generating Image Number: 14 for target class tensor([2]). Step 0, Loss: 3.5250332355499268
# Generating Image Number: 14 for target class tensor([2]). Step 50, Loss: 0.784165620803833
# Generating Image Number: 14 for target class tensor([2]). Step 100, Loss: 0.3747955858707428
# Generating Image Number: 14 for target class tensor([2]). Step 150, Loss: 0.2048378437757492
# Generating Image Number: 14 for target class tensor([2]). Step 200, Loss: 0.13717173039913177
# Generating Image Number: 14 for target class tensor([2]). Step 250, Loss: 0.09502514451742172
# Generating Image Number: 14 for target class tensor([2]). Step 300, Loss: 0.07580485194921494
# Generating Image Number: 14 for target class tensor([2]). Step 350, Loss: 0.0643668994307518
# Generating Image Number: 14 for target class tensor([2]). Step 400, Loss: 0.05572037771344185
# Generating Image Number: 14 for target class tensor([2]). Step 450, Loss: 0.04906051605939865
# Generating Image Number: 15 for target class tensor([2]). Step 0, Loss: 1.086188554763794
# Generating Image Number: 15 for target class tensor([2]). Step 50, Loss: 0.11017873883247375
# Generating Image Number: 15 for target class tensor([2]). Step 100, Loss: 0.05913252383470535
# Generating Image Number: 15 for target class tensor([2]). Step 150, Loss: 0.04300219565629959
# Generating Image Number: 15 for target class tensor([2]). Step 200, Loss: 0.03494465723633766
# Generating Image Number: 15 for target class tensor([2]). Step 250, Loss: 0.028937073424458504
# Generating Image Number: 15 for target class tensor([2]). Step 300, Loss: 0.02479609288275242
# Generating Image Number: 15 for target class tensor([2]). Step 350, Loss: 0.021689243614673615
# Generating Image Number: 15 for target class tensor([2]). Step 400, Loss: 0.019035518169403076
# Generating Image Number: 15 for target class tensor([2]). Step 450, Loss: 0.016706090420484543
# Generating Image Number: 16 for target class tensor([2]). Step 0, Loss: 3.54669189453125
# Generating Image Number: 16 for target class tensor([2]). Step 50, Loss: 0.1363644003868103
# Generating Image Number: 16 for target class tensor([2]). Step 100, Loss: 0.0847492590546608
# Generating Image Number: 16 for target class tensor([2]). Step 150, Loss: 0.0567362904548645
# Generating Image Number: 16 for target class tensor([2]). Step 200, Loss: 0.03913229703903198
# Generating Image Number: 16 for target class tensor([2]). Step 250, Loss: 0.02978154458105564
# Generating Image Number: 16 for target class tensor([2]). Step 300, Loss: 0.022656166926026344
# Generating Image Number: 16 for target class tensor([2]). Step 350, Loss: 0.018991656601428986
# Generating Image Number: 16 for target class tensor([2]). Step 400, Loss: 0.01674841158092022
# Generating Image Number: 16 for target class tensor([2]). Step 450, Loss: 0.014864286407828331
# Generating Image Number: 17 for target class tensor([2]). Step 0, Loss: 0.2767220437526703
# Generating Image Number: 17 for target class tensor([2]). Step 50, Loss: 0.009694874286651611
# Generating Image Number: 17 for target class tensor([2]). Step 100, Loss: 0.006435384973883629
# Generating Image Number: 17 for target class tensor([2]). Step 150, Loss: 0.004897146951407194
# Generating Image Number: 17 for target class tensor([2]). Step 200, Loss: 0.0036560141015797853
# Generating Image Number: 17 for target class tensor([2]). Step 250, Loss: 0.0028584832325577736
# Generating Image Number: 17 for target class tensor([2]). Step 300, Loss: 0.002102666301652789
# Generating Image Number: 17 for target class tensor([2]). Step 350, Loss: 0.001589583931490779
# Generating Image Number: 17 for target class tensor([2]). Step 400, Loss: 0.0012990139657631516
# Generating Image Number: 17 for target class tensor([2]). Step 450, Loss: 0.0010671879863366485
# Generating Image Number: 18 for target class tensor([2]). Step 0, Loss: 28.80089569091797
# Generating Image Number: 18 for target class tensor([2]). Step 50, Loss: 24.777584075927734
# Generating Image Number: 18 for target class tensor([2]). Step 100, Loss: 24.6182804107666
# Generating Image Number: 18 for target class tensor([2]). Step 150, Loss: 24.48455810546875
# Generating Image Number: 18 for target class tensor([2]). Step 200, Loss: 24.048925399780273
# Generating Image Number: 18 for target class tensor([2]). Step 250, Loss: 24.05773162841797
# Generating Image Number: 18 for target class tensor([2]). Step 300, Loss: 24.094444274902344
# Generating Image Number: 18 for target class tensor([2]). Step 350, Loss: 23.952566146850586
# Generating Image Number: 18 for target class tensor([2]). Step 400, Loss: 23.680997848510742
# Generating Image Number: 18 for target class tensor([2]). Step 450, Loss: 23.461240768432617
# Generating Image Number: 19 for target class tensor([2]). Step 0, Loss: 5.449136257171631
# Generating Image Number: 19 for target class tensor([2]). Step 50, Loss: 2.9074015617370605
# Generating Image Number: 19 for target class tensor([2]). Step 100, Loss: 1.775575041770935
# Generating Image Number: 19 for target class tensor([2]). Step 150, Loss: 1.143593668937683
# Generating Image Number: 19 for target class tensor([2]). Step 200, Loss: 0.9120745658874512
# Generating Image Number: 19 for target class tensor([2]). Step 250, Loss: 0.7856516242027283
# Generating Image Number: 19 for target class tensor([2]). Step 300, Loss: 0.6828216910362244
# Generating Image Number: 19 for target class tensor([2]). Step 350, Loss: 0.5859004259109497
# Generating Image Number: 19 for target class tensor([2]). Step 400, Loss: 0.5044671297073364
# Generating Image Number: 19 for target class tensor([2]). Step 450, Loss: 0.4278903007507324
# Generating Image Number: 20 for target class tensor([2]). Step 0, Loss: 0.2946506440639496
# Generating Image Number: 20 for target class tensor([2]). Step 50, Loss: 0.002003330737352371
# Generating Image Number: 20 for target class tensor([2]). Step 100, Loss: 0.0016075557796284556
# Generating Image Number: 20 for target class tensor([2]). Step 150, Loss: 0.001412466517649591
# Generating Image Number: 20 for target class tensor([2]). Step 200, Loss: 0.0012432949151843786
# Generating Image Number: 20 for target class tensor([2]). Step 250, Loss: 0.0011106519959867
# Generating Image Number: 20 for target class tensor([2]). Step 300, Loss: 0.0009901388548314571
# Generating Image Number: 20 for target class tensor([2]). Step 350, Loss: 0.0008856903295964003
# Generating Image Number: 20 for target class tensor([2]). Step 400, Loss: 0.0008106521563604474
# Generating Image Number: 20 for target class tensor([2]). Step 450, Loss: 0.0007465674425475299

# %%
torch.manual_seed(300)
latent_vectors = torch.randn(img_count, z_dim, 1, 1, requires_grad=True) # Start with 20 random noises
class3_optimized_latent_vectors = recover_images(img_count, 3, latent_vectors)
# Out:
# Generating Image Number: 1 for target class tensor([3]). Step 0, Loss: 0.00011872540198964998
# Generating Image Number: 1 for target class tensor([3]). Step 50, Loss: 0.20378363132476807
# Generating Image Number: 1 for target class tensor([3]). Step 100, Loss: 0.008963348343968391
# Generating Image Number: 1 for target class tensor([3]). Step 150, Loss: 0.006190885789692402
# Generating Image Number: 1 for target class tensor([3]). Step 200, Loss: 0.005987090524286032
# Generating Image Number: 1 for target class tensor([3]). Step 250, Loss: 0.0057769715785980225
# Generating Image Number: 1 for target class tensor([3]). Step 300, Loss: 0.005561237223446369
# Generating Image Number: 1 for target class tensor([3]). Step 350, Loss: 0.005362175405025482
# Generating Image Number: 1 for target class tensor([3]). Step 400, Loss: 0.005153941456228495
# Generating Image Number: 1 for target class tensor([3]). Step 450, Loss: 0.0050042616203427315
# Generating Image Number: 2 for target class tensor([3]). Step 0, Loss: 1.8835201263427734
# Generating Image Number: 2 for target class tensor([3]). Step 50, Loss: 0.2289419323205948
# Generating Image Number: 2 for target class tensor([3]). Step 100, Loss: 0.10935475677251816
# Generating Image Number: 2 for target class tensor([3]). Step 150, Loss: 0.07022597640752792
# Generating Image Number: 2 for target class tensor([3]). Step 200, Loss: 0.056538596749305725
# Generating Image Number: 2 for target class tensor([3]). Step 250, Loss: 0.049442946910858154
# Generating Image Number: 2 for target class tensor([3]). Step 300, Loss: 0.0440182127058506
# Generating Image Number: 2 for target class tensor([3]). Step 350, Loss: 0.03952621668577194
# Generating Image Number: 2 for target class tensor([3]). Step 400, Loss: 0.03639394789934158
# Generating Image Number: 2 for target class tensor([3]). Step 450, Loss: 0.03386325389146805
# Generating Image Number: 3 for target class tensor([3]). Step 0, Loss: 0.008533324114978313
# Generating Image Number: 3 for target class tensor([3]). Step 50, Loss: 2.288792165927589e-05
# Generating Image Number: 3 for target class tensor([3]). Step 100, Loss: 1.2397689715726301e-05
# Generating Image Number: 3 for target class tensor([3]). Step 150, Loss: 1.0609570381348021e-05
# Generating Image Number: 3 for target class tensor([3]). Step 200, Loss: 9.298280929215252e-06
# Generating Image Number: 3 for target class tensor([3]). Step 250, Loss: 8.4638240878121e-06
# Generating Image Number: 3 for target class tensor([3]). Step 300, Loss: 7.867782187531702e-06
# Generating Image Number: 3 for target class tensor([3]). Step 350, Loss: 7.271740287251305e-06
# Generating Image Number: 3 for target class tensor([3]). Step 400, Loss: 6.794906312279636e-06
# Generating Image Number: 3 for target class tensor([3]). Step 450, Loss: 6.437280717364047e-06
# Generating Image Number: 4 for target class tensor([3]). Step 0, Loss: 5.345629692077637
# Generating Image Number: 4 for target class tensor([3]). Step 50, Loss: 2.787193536758423
# Generating Image Number: 4 for target class tensor([3]). Step 100, Loss: 1.5263967514038086
# Generating Image Number: 4 for target class tensor([3]). Step 150, Loss: 1.017989993095398
# Generating Image Number: 4 for target class tensor([3]). Step 200, Loss: 0.8118891716003418
# Generating Image Number: 4 for target class tensor([3]). Step 250, Loss: 0.6898590326309204
# Generating Image Number: 4 for target class tensor([3]). Step 300, Loss: 0.6191094517707825
# Generating Image Number: 4 for target class tensor([3]). Step 350, Loss: 0.5758587121963501
# Generating Image Number: 4 for target class tensor([3]). Step 400, Loss: 0.5348498821258545
# Generating Image Number: 4 for target class tensor([3]). Step 450, Loss: 0.5052154660224915
# Generating Image Number: 5 for target class tensor([3]). Step 0, Loss: 2.799668073654175
# Generating Image Number: 5 for target class tensor([3]). Step 50, Loss: 0.016503607854247093
# Generating Image Number: 5 for target class tensor([3]). Step 100, Loss: 0.013611480593681335
# Generating Image Number: 5 for target class tensor([3]). Step 150, Loss: 0.011376393027603626
# Generating Image Number: 5 for target class tensor([3]). Step 200, Loss: 0.009565827436745167
# Generating Image Number: 5 for target class tensor([3]). Step 250, Loss: 0.008107016794383526
# Generating Image Number: 5 for target class tensor([3]). Step 300, Loss: 0.007086263038218021
# Generating Image Number: 5 for target class tensor([3]). Step 350, Loss: 0.006361591629683971
# Generating Image Number: 5 for target class tensor([3]). Step 400, Loss: 0.005715101025998592
# Generating Image Number: 5 for target class tensor([3]). Step 450, Loss: 0.005181574262678623
# Generating Image Number: 6 for target class tensor([3]). Step 0, Loss: 2.3992044925689697
# Generating Image Number: 6 for target class tensor([3]). Step 50, Loss: 1.603560209274292
# Generating Image Number: 6 for target class tensor([3]). Step 100, Loss: 1.0433847904205322
# Generating Image Number: 6 for target class tensor([3]). Step 150, Loss: 0.6788927316665649
# Generating Image Number: 6 for target class tensor([3]). Step 200, Loss: 0.42994147539138794
# Generating Image Number: 6 for target class tensor([3]). Step 250, Loss: 0.31616854667663574
# Generating Image Number: 6 for target class tensor([3]). Step 300, Loss: 0.24974912405014038
# Generating Image Number: 6 for target class tensor([3]). Step 350, Loss: 0.22651207447052002
# Generating Image Number: 6 for target class tensor([3]). Step 400, Loss: 0.1825316846370697
# Generating Image Number: 6 for target class tensor([3]). Step 450, Loss: 0.16087062656879425
# Generating Image Number: 7 for target class tensor([3]). Step 0, Loss: 2.3436472415924072
# Generating Image Number: 7 for target class tensor([3]). Step 50, Loss: 0.6409346461296082
# Generating Image Number: 7 for target class tensor([3]). Step 100, Loss: 0.3713795840740204
# Generating Image Number: 7 for target class tensor([3]). Step 150, Loss: 0.25261300802230835
# Generating Image Number: 7 for target class tensor([3]). Step 200, Loss: 0.18413947522640228
# Generating Image Number: 7 for target class tensor([3]). Step 250, Loss: 0.1454065442085266
# Generating Image Number: 7 for target class tensor([3]). Step 300, Loss: 0.1201833039522171
# Generating Image Number: 7 for target class tensor([3]). Step 350, Loss: 0.10120546072721481
# Generating Image Number: 7 for target class tensor([3]). Step 400, Loss: 0.08552426844835281
# Generating Image Number: 7 for target class tensor([3]). Step 450, Loss: 0.0730019062757492
# Generating Image Number: 8 for target class tensor([3]). Step 0, Loss: 0.5962470173835754
# Generating Image Number: 8 for target class tensor([3]). Step 50, Loss: 0.005224859807640314
# Generating Image Number: 8 for target class tensor([3]). Step 100, Loss: 0.004165663383901119
# Generating Image Number: 8 for target class tensor([3]). Step 150, Loss: 0.0035505369305610657
# Generating Image Number: 8 for target class tensor([3]). Step 200, Loss: 0.0030623229686170816
# Generating Image Number: 8 for target class tensor([3]). Step 250, Loss: 0.002647468587383628
# Generating Image Number: 8 for target class tensor([3]). Step 300, Loss: 0.00213216757401824
# Generating Image Number: 8 for target class tensor([3]). Step 350, Loss: 0.0017972521018236876
# Generating Image Number: 8 for target class tensor([3]). Step 400, Loss: 0.0015814905054867268
# Generating Image Number: 8 for target class tensor([3]). Step 450, Loss: 0.0013516347389668226
# Generating Image Number: 9 for target class tensor([3]). Step 0, Loss: 6.235653877258301
# Generating Image Number: 9 for target class tensor([3]). Step 50, Loss: 0.0021363310515880585
# Generating Image Number: 9 for target class tensor([3]). Step 100, Loss: 0.0015904169995337725
# Generating Image Number: 9 for target class tensor([3]). Step 150, Loss: 0.0010442048078402877
# Generating Image Number: 9 for target class tensor([3]). Step 200, Loss: 0.0008955758530646563
# Generating Image Number: 9 for target class tensor([3]). Step 250, Loss: 0.0007426364463753998
# Generating Image Number: 9 for target class tensor([3]). Step 300, Loss: 0.0006744970451109111
# Generating Image Number: 9 for target class tensor([3]). Step 350, Loss: 0.0006150499684736133
# Generating Image Number: 9 for target class tensor([3]). Step 400, Loss: 0.0005808573332615197
# Generating Image Number: 9 for target class tensor([3]). Step 450, Loss: 0.0004686211177613586
# Generating Image Number: 10 for target class tensor([3]). Step 0, Loss: 3.8308656215667725
# Generating Image Number: 10 for target class tensor([3]). Step 50, Loss: 0.0021167034283280373
# Generating Image Number: 10 for target class tensor([3]). Step 100, Loss: 0.0017902314430102706
# Generating Image Number: 10 for target class tensor([3]). Step 150, Loss: 0.001655518775805831
# Generating Image Number: 10 for target class tensor([3]). Step 200, Loss: 0.0015983913326635957
# Generating Image Number: 10 for target class tensor([3]). Step 250, Loss: 0.0015568528324365616
# Generating Image Number: 10 for target class tensor([3]). Step 300, Loss: 0.0015012671938166022
# Generating Image Number: 10 for target class tensor([3]). Step 350, Loss: 0.001447583083063364
# Generating Image Number: 10 for target class tensor([3]). Step 400, Loss: 0.0013946102699264884
# Generating Image Number: 10 for target class tensor([3]). Step 450, Loss: 0.0013435394503176212
# Generating Image Number: 11 for target class tensor([3]). Step 0, Loss: 4.65698766708374
# Generating Image Number: 11 for target class tensor([3]). Step 50, Loss: 0.00016306500765495002
# Generating Image Number: 11 for target class tensor([3]). Step 100, Loss: 0.0001746263587847352
# Generating Image Number: 11 for target class tensor([3]). Step 150, Loss: 0.0001674750237725675
# Generating Image Number: 11 for target class tensor([3]). Step 200, Loss: 0.00016366096679121256
# Generating Image Number: 11 for target class tensor([3]). Step 250, Loss: 0.00016234986833296716
# Generating Image Number: 11 for target class tensor([3]). Step 300, Loss: 0.00016032364510465413
# Generating Image Number: 11 for target class tensor([3]). Step 350, Loss: 0.00015639036428183317
# Generating Image Number: 11 for target class tensor([3]). Step 400, Loss: 0.00015317220822907984
# Generating Image Number: 11 for target class tensor([3]). Step 450, Loss: 0.00014828535495325923
# Generating Image Number: 12 for target class tensor([3]). Step 0, Loss: 3.793668031692505
# Generating Image Number: 12 for target class tensor([3]). Step 50, Loss: 0.27570024132728577
# Generating Image Number: 12 for target class tensor([3]). Step 100, Loss: 0.1596100777387619
# Generating Image Number: 12 for target class tensor([3]). Step 150, Loss: 0.10661065578460693
# Generating Image Number: 12 for target class tensor([3]). Step 200, Loss: 0.0749153196811676
# Generating Image Number: 12 for target class tensor([3]). Step 250, Loss: 0.0582391619682312
# Generating Image Number: 12 for target class tensor([3]). Step 300, Loss: 0.0468624085187912
# Generating Image Number: 12 for target class tensor([3]). Step 350, Loss: 0.03700092062354088
# Generating Image Number: 12 for target class tensor([3]). Step 400, Loss: 0.03097185306251049
# Generating Image Number: 12 for target class tensor([3]). Step 450, Loss: 0.026462413370609283
# Generating Image Number: 13 for target class tensor([3]). Step 0, Loss: 2.7088208198547363
# Generating Image Number: 13 for target class tensor([3]). Step 50, Loss: 0.3209271728992462
# Generating Image Number: 13 for target class tensor([3]). Step 100, Loss: 0.19369785487651825
# Generating Image Number: 13 for target class tensor([3]). Step 150, Loss: 0.13415218889713287
# Generating Image Number: 13 for target class tensor([3]). Step 200, Loss: 0.10391370207071304
# Generating Image Number: 13 for target class tensor([3]). Step 250, Loss: 0.08488527685403824
# Generating Image Number: 13 for target class tensor([3]). Step 300, Loss: 0.07257527858018875
# Generating Image Number: 13 for target class tensor([3]). Step 350, Loss: 0.0638204887509346
# Generating Image Number: 13 for target class tensor([3]). Step 400, Loss: 0.057062312960624695
# Generating Image Number: 13 for target class tensor([3]). Step 450, Loss: 0.052706580609083176
# Generating Image Number: 14 for target class tensor([3]). Step 0, Loss: 1.8238006830215454
# Generating Image Number: 14 for target class tensor([3]). Step 50, Loss: 0.0061548687517642975
# Generating Image Number: 14 for target class tensor([3]). Step 100, Loss: 0.0007668177131563425
# Generating Image Number: 14 for target class tensor([3]). Step 150, Loss: 0.0006504327175207436
# Generating Image Number: 14 for target class tensor([3]). Step 200, Loss: 0.0005301024066284299
# Generating Image Number: 14 for target class tensor([3]). Step 250, Loss: 0.00047100416850298643
# Generating Image Number: 14 for target class tensor([3]). Step 300, Loss: 0.000406301929615438
# Generating Image Number: 14 for target class tensor([3]). Step 350, Loss: 0.0003328961320221424
# Generating Image Number: 14 for target class tensor([3]). Step 400, Loss: 0.00027581225731410086
# Generating Image Number: 14 for target class tensor([3]). Step 450, Loss: 0.00023493390472140163
# Generating Image Number: 15 for target class tensor([3]). Step 0, Loss: 4.851391315460205
# Generating Image Number: 15 for target class tensor([3]). Step 50, Loss: 2.1328988075256348
# Generating Image Number: 15 for target class tensor([3]). Step 100, Loss: 1.4243675470352173
# Generating Image Number: 15 for target class tensor([3]). Step 150, Loss: 0.7916785478591919
# Generating Image Number: 15 for target class tensor([3]). Step 200, Loss: 0.4645286798477173
# Generating Image Number: 15 for target class tensor([3]). Step 250, Loss: 0.2792840600013733
# Generating Image Number: 15 for target class tensor([3]). Step 300, Loss: 0.18056151270866394
# Generating Image Number: 15 for target class tensor([3]). Step 350, Loss: 0.1358882188796997
# Generating Image Number: 15 for target class tensor([3]). Step 400, Loss: 0.10821079462766647
# Generating Image Number: 15 for target class tensor([3]). Step 450, Loss: 0.09618167579174042
# Generating Image Number: 16 for target class tensor([3]). Step 0, Loss: 6.905453205108643
# Generating Image Number: 16 for target class tensor([3]). Step 50, Loss: 1.870600700378418
# Generating Image Number: 16 for target class tensor([3]). Step 100, Loss: 1.698784589767456
# Generating Image Number: 16 for target class tensor([3]). Step 150, Loss: 1.455918550491333
# Generating Image Number: 16 for target class tensor([3]). Step 200, Loss: 1.3073958158493042
# Generating Image Number: 16 for target class tensor([3]). Step 250, Loss: 1.1041295528411865
# Generating Image Number: 16 for target class tensor([3]). Step 300, Loss: 0.8791972398757935
# Generating Image Number: 16 for target class tensor([3]). Step 350, Loss: 1.4840519428253174
# Generating Image Number: 16 for target class tensor([3]). Step 400, Loss: 1.5528168678283691
# Generating Image Number: 16 for target class tensor([3]). Step 450, Loss: 0.7434127926826477
# Generating Image Number: 17 for target class tensor([3]). Step 0, Loss: 1.0408670902252197
# Generating Image Number: 17 for target class tensor([3]). Step 50, Loss: 0.43634772300720215
# Generating Image Number: 17 for target class tensor([3]). Step 100, Loss: 0.264974981546402
# Generating Image Number: 17 for target class tensor([3]). Step 150, Loss: 0.19776441156864166
# Generating Image Number: 17 for target class tensor([3]). Step 200, Loss: 0.15557993948459625
# Generating Image Number: 17 for target class tensor([3]). Step 250, Loss: 0.12730272114276886
# Generating Image Number: 17 for target class tensor([3]). Step 300, Loss: 0.10472264140844345
# Generating Image Number: 17 for target class tensor([3]). Step 350, Loss: 0.09063517302274704
# Generating Image Number: 17 for target class tensor([3]). Step 400, Loss: 0.07865991443395615
# Generating Image Number: 17 for target class tensor([3]). Step 450, Loss: 0.07052496820688248
# Generating Image Number: 18 for target class tensor([3]). Step 0, Loss: 5.696263313293457
# Generating Image Number: 18 for target class tensor([3]). Step 50, Loss: 3.3960843086242676
# Generating Image Number: 18 for target class tensor([3]). Step 100, Loss: 2.1646246910095215
# Generating Image Number: 18 for target class tensor([3]). Step 150, Loss: 1.6785736083984375
# Generating Image Number: 18 for target class tensor([3]). Step 200, Loss: 1.4098395109176636
# Generating Image Number: 18 for target class tensor([3]). Step 250, Loss: 1.190146565437317
# Generating Image Number: 18 for target class tensor([3]). Step 300, Loss: 1.0067445039749146
# Generating Image Number: 18 for target class tensor([3]). Step 350, Loss: 0.8755174875259399
# Generating Image Number: 18 for target class tensor([3]). Step 400, Loss: 0.7686505317687988
# Generating Image Number: 18 for target class tensor([3]). Step 450, Loss: 0.6933466196060181
# Generating Image Number: 19 for target class tensor([3]). Step 0, Loss: 3.251270055770874
# Generating Image Number: 19 for target class tensor([3]). Step 50, Loss: 1.7796053886413574
# Generating Image Number: 19 for target class tensor([3]). Step 100, Loss: 1.276699423789978
# Generating Image Number: 19 for target class tensor([3]). Step 150, Loss: 0.9699088335037231
# Generating Image Number: 19 for target class tensor([3]). Step 200, Loss: 0.7391858100891113
# Generating Image Number: 19 for target class tensor([3]). Step 250, Loss: 0.6308752298355103
# Generating Image Number: 19 for target class tensor([3]). Step 300, Loss: 0.5631377696990967
# Generating Image Number: 19 for target class tensor([3]). Step 350, Loss: 0.494995653629303
# Generating Image Number: 19 for target class tensor([3]). Step 400, Loss: 0.4447307884693146
# Generating Image Number: 19 for target class tensor([3]). Step 450, Loss: 0.39742597937583923
# Generating Image Number: 20 for target class tensor([3]). Step 0, Loss: 3.548565626144409
# Generating Image Number: 20 for target class tensor([3]). Step 50, Loss: 0.7006016373634338
# Generating Image Number: 20 for target class tensor([3]). Step 100, Loss: 0.3597947359085083
# Generating Image Number: 20 for target class tensor([3]). Step 150, Loss: 0.2419840693473816
# Generating Image Number: 20 for target class tensor([3]). Step 200, Loss: 0.18549904227256775
# Generating Image Number: 20 for target class tensor([3]). Step 250, Loss: 0.14927586913108826
# Generating Image Number: 20 for target class tensor([3]). Step 300, Loss: 0.11972653865814209
# Generating Image Number: 20 for target class tensor([3]). Step 350, Loss: 0.09842786192893982
# Generating Image Number: 20 for target class tensor([3]). Step 400, Loss: 0.08108866959810257
# Generating Image Number: 20 for target class tensor([3]). Step 450, Loss: 0.06858119368553162

# %%
# Send the images through the model and get the probabilities
def get_probability(latent_vector, target_class):
    img = gen(latent_vector.to(device))

    img = img.repeat(1, 3, 1, 1) # Increase the color channels from 1 to 3 by repeating the color channel
    img = functional.interpolate(img, size=(32, 32), mode='nearest') # Change the image shape from 64x64(DCGAN output) to 32x32(Model input)

    hs, logits = target_model(img)
    probs = functional.softmax(logits, dim=1)

    return probs[:, target_class]
    
def get_class_probabilities(optimized_latent_vectors, target_class):
    probs = []
    for lv in optimized_latent_vectors:
        probs.append(get_probability(lv, target_class))

    return probs

# %%
def get_confidence_accuracy(probs_list, prob_threshold):
    size = len(probs_list)
    counter = 0
    for prob in probs_list:
        p = prob.item()
        if p > prob_threshold:
            counter += 1

    return ((counter/size)*100.0)

# %%
probability_confidence_threshold = 0.6

# %%
probs_class0 = get_class_probabilities(class0_optimized_latent_vectors, 0)
len(probs_class0)
for prob in probs_class0:
    print(prob)
    
print('Confidence percentage:', get_confidence_accuracy(probs_class0, probability_confidence_threshold))
# Out:
# tensor([0.9688], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9859], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.7542], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9759], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([1.], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9957], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9508], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9984], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9991], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9101], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.8927], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([1.], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9792], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9989], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9985], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([1.], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9650], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9965], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9133], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9618], device='cuda:0', grad_fn=<SelectBackward0>)
# Confidence percentage: 100.0

# %%
probs_class1 = get_class_probabilities(class1_optimized_latent_vectors, 1)
len(probs_class1)
for prob in probs_class1:
    print(prob)

print('Confidence percentage:', get_confidence_accuracy(probs_class1, probability_confidence_threshold))
# Out:
# tensor([0.5344], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.7769], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.0632], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.0258], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.0202], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.0367], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.0660], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([1.1056e-15], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.4512], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.4981], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.3809], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([1.3020e-05], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.0116], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.7915], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.6002], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.0046], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.6926], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.2733], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.0122], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.7362], device='cuda:0', grad_fn=<SelectBackward0>)
# Confidence percentage: 25.0

# %%
probs_class2 = get_class_probabilities(class2_optimized_latent_vectors, 2)
len(probs_class2)
for prob in probs_class2:
    print(prob)
    
print('Confidence percentage:', get_confidence_accuracy(probs_class2, probability_confidence_threshold))
# Out:
# tensor([0.9712], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9787], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9854], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9998], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9768], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9520], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9494], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9406], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9963], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.8811], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9776], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([7.4247e-12], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9508], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9574], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9852], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9866], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9991], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([7.1822e-11], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.6844], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9993], device='cuda:0', grad_fn=<SelectBackward0>)
# Confidence percentage: 90.0

# %%
probs_class3 = get_class_probabilities(class3_optimized_latent_vectors, 3)
len(probs_class3)
for prob in probs_class3:
    print(prob)

print('Confidence percentage:', get_confidence_accuracy(probs_class3, probability_confidence_threshold))
# Out:
# tensor([0.9951], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9687], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([1.0000], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.6359], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9952], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.8661], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9369], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9988], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9996], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9987], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9999], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9772], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9519], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9998], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9157], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.6125], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9389], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.5369], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.6985], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9422], device='cuda:0', grad_fn=<SelectBackward0>)
# Confidence percentage: 95.0

# %%
z0_1 = class0_optimized_latent_vectors[0]
z0_2 = class0_optimized_latent_vectors[1]
z0_3 = class0_optimized_latent_vectors[2]

# %%
# Display the generated image
img = gen(z0_1.to(device)).squeeze(dim=0).squeeze(dim=0)
print(img.shape)
# Out:
# torch.Size([64, 64])

# %%
plt.axis(False)
plt.title('Recovered Image:')
plt.imshow(img.cpu().detach(), cmap='gray')

# %%
z1 = class1_optimized_latent_vectors[0]
z2 = class1_optimized_latent_vectors[1]
z3 = class1_optimized_latent_vectors[2]

# %%
# Display the generated image
img = gen(z1.to(device)).squeeze(dim=0).squeeze(dim=0)
print(img.shape)
# Out:
# torch.Size([64, 64])

# %%
plt.axis(False)
plt.title('Recovered Image:')
plt.imshow(img.cpu().detach(), cmap='gray')

# %%
                                                            # Dataset Loading
# Load the .pkl files in as numpy arrays of pixels
def load_tumor_data(file_path):
    train_xs = []
    train_ys = []
    """ Load Digits Data from pickle data
    return:
    @xs: numpy.array, (n, c, w, h) 
    @ys: numpy.array, (n, ), 0-9
    """
    with open(file_path, 'rb') as file:
        data = pickle.load(file)
        train_xs.append(data["data"])
        train_ys.append(data["labels"])
    train_xs = np.concatenate(train_xs, axis=0)
    train_ys = np.concatenate(train_ys, axis=0)
    
    return train_xs, train_ys

# %%
# Custom Tumor Dataset
class TumorDataset(data.Dataset):
    def __init__(self, xs, ys, is_train=True):
        self.xs = xs
        self.ys = ys

        if is_train is True:
            self.transform = transforms.Compose([
                transforms.ToPILImage(),
                transforms.Resize((64, 64)),
                transforms.ToTensor(),
                transforms.Normalize(
                    [0.5],
                    [0.5]
                )
            ])
        else:
            self.transform = transforms.Compose([
                transforms.ToPILImage(),
                transforms.Resize((64, 64)),
                transforms.ToTensor(),
                transforms.Normalize(
                    (0.4914, 0.4822, 0.4465),
                    (0.2023, 0.1994, 0.2010)
                )
            ])

    def __len__(self):
        return len(self.xs)

    def __getitem__(self, index):
        img = self.xs[index]
        #print(img.shape)
        label = self.ys[index]

        img = img.transpose((1, 2, 0)).astype(np.uint8)
        img = self.transform(img)

        img = torch.FloatTensor(img)
        label = torch.LongTensor([label])[0]
        return img, label

# %%
def create_dataset(train_xs, train_ys):
    tumor_dataset = TumorDataset(train_xs, train_ys, is_train=True)

    return tumor_dataset

# %%
def create_dataloader(dataset):
    dataloader = DataLoader(dataset=dataset, batch_size=128, shuffle=True)

    return dataloader

# %%
# Load in the pickle dataset file
train_xs, train_ys = load_tumor_data('datasets/Tumor/tumor4train.pkl')
#train_xs = train_xs[:, 1, :, :]
#train_xs = np.expand_dims(train_xs, axis=1)
train_xs = train_xs.mean(axis=1, keepdims=True)
print(train_xs.shape)
print(type(train_xs))
# Out:
# (13927, 1, 32, 32)
# <class 'numpy.ndarray'>

# %%
# Create the dataset
tumor_dataset = create_dataset(train_xs, train_ys)

# %%
def visualize_image(image_x):
    # We have to visualize by reverting the normalization (just for visualization).
    mean = torch.tensor([0.5])
    std = torch.tensor([0.5])

    image = image_x * std + mean  # Denormalize the image

    image = torch.clamp(image, 0, 1) # Clip values to [0, 1] to ensure valid range for display

    # Permute the image to (H, W, C) for matplotlib
    
    image = image.permute(1, 2, 0)

    plt.imshow(image, cmap='gray')

# %%
# Visualize the first tumor sample. 
image_x, image_y = tumor_dataset[7000]
print(image_x.shape)
visualize_image(image_x)
# Out:
# torch.Size([1, 64, 64])

# %%
from scipy.spatial.distance import cosine
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 from scipy.spatial.distance import cosine
#
# ModuleNotFoundError: No module named 'scipy'

# %%
# Get the feature embeddings
tfcnn_model = target_model = load_target_model(base_net='TFCNN', n_classes=4, path='saved models/fedavg_global_model.pth').to(device)
model_embeddings = tfcnn_model.encoder.to(device)

# %%
# Preprocessing
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
])

# %%
def get_feature(img):
    with torch.no_grad():
        features = model_embeddings(img).squeeze()
    return features.cpu().numpy()

# %%
# Send an original image through the model
image_x, image_y = tumor_dataset[10]
image_x.shape

# %%
image_x = image_x.unsqueeze(dim=0)

# %%
image_x.shape

# %%
image_x = image_x.repeat(1, 3, 1, 1)
image_x = image_x.to(device)
image_x.shape

# %%
features = get_feature(image_x)
features.shape

# %%
class0_original_images = []
class1_original_images = []
class2_original_images = []
class3_original_images = []
target_num = 20 # 20 images for each class

# %%
for i in range(len(tumor_dataset)):
    img_x, img_y = tumor_dataset[i]

    if img_y == 0:
        if len(class0_original_images) < target_num:
            class0_original_images.append(img_x)
    elif img_y == 1:
        if len(class1_original_images) < target_num:
            class1_original_images.append(img_x)
    elif img_y == 2:
        if len(class2_original_images) < target_num:
            class2_original_images.append(img_x)
    elif img_y == 3:
        if len(class3_original_images) < target_num:
            class3_original_images.append(img_x)

# %%
len(class3_original_images)

# %%
# Testing the cosine similarity
class1_original_image = class1_original_images[8]
class1_original_image = class1_original_image.unsqueeze(dim=0).to(device)
class1_original_image = class1_original_image.repeat(1, 3, 1, 1)
class1_original_image.shape

# %%
fake1 = class1_optimized_latent_vectors[8]
fake1_image = gen(fake1.to(device))
fake1_image = fake1_image.repeat(1, 3, 1, 1)

# %%
fake1_image.shape

# %%
fake = class3_optimized_latent_vectors[3]
fake_img = gen(fake.to(device)).squeeze(dim=0)
print(fake_img.shape)
visualize_image(fake_img.detach().cpu())

# %%
# Get the features of the images
features_original = get_feature(class1_original_image)
features_fake = get_feature(fake1_image)

# %%
# Compute cosine similarity
similarity = 1 - cosine(features_original, features_fake)

# %%
similarity

# %%
def calculate_class0_sim():
    similarities = []
    for i in range(0, 20):
        class0_original = class0_original_images[i].unsqueeze(dim=0).to(device)
        class0_original = class0_original.repeat(1, 3, 1, 1)

        class0_fake = class0_optimized_latent_vectors[i]
        class0_fake_img = gen(class0_fake.to(device))
        class0_fake_img = class0_fake_img.repeat(1, 3, 1, 1)

        features_original = get_feature(class0_original)
        features_fake = get_feature(class0_fake_img)

        cosine_similarity = 1 - cosine(features_original, features_fake)

        similarities.append(cosine_similarity)
        
    return similarities

# %%
def calculate_class1_sim():
    similarities = []
    for i in range(0, 20):
        class1_original = class1_original_images[i].unsqueeze(dim=0).to(device)
        class1_original = class1_original.repeat(1, 3, 1, 1)

        class1_fake = class1_optimized_latent_vectors[i]
        class1_fake_img = gen(class1_fake.to(device))
        class1_fake_img = class1_fake_img.repeat(1, 3, 1, 1)

        features_original = get_feature(class1_original)
        features_fake = get_feature(class1_fake_img)

        cosine_similarity = 1 - cosine(features_original, features_fake)
        similarities.append(cosine_similarity)

    return similarities

# %%
def calculate_class2_sim():
    similarities = []
    for i in range(0, 20):
        class2_original = class2_original_images[i].unsqueeze(dim=0).to(device)
        class2_original = class2_original.repeat(1, 3, 1, 1)

        class2_fake = class2_optimized_latent_vectors[i]
        class2_fake_img = gen(class2_fake.to(device))
        class2_fake_img = class2_fake_img.repeat(1, 3, 1, 1)

        features_original = get_feature(class2_original)
        features_fake = get_feature(class2_fake_img)

        cosine_similarity = 1 - cosine(features_original, features_fake)
        similarities.append(cosine_similarity)

    return similarities

# %%
def calculate_class3_sim():
    similarities = []
    for i in range(0, 20):
        class3_original = class3_original_images[i].unsqueeze(dim=0).to(device)
        class3_original = class3_original.repeat(1, 3, 1, 1)

        class3_fake = class3_optimized_latent_vectors[i]
        class3_fake_img = gen(class3_fake.to(device))
        class3_fake_img = class3_fake_img.repeat(1, 3, 1, 1)

        features_original = get_feature(class3_original)
        features_fake = get_feature(class3_fake_img)

        cosine_similarity = 1 - cosine(features_original, features_fake)
        similarities.append(cosine_similarity)

    return similarities

# %%
class0_sims = calculate_class0_sim()
class1_sims = calculate_class0_sim()
class2_sims = calculate_class0_sim()
class3_sims = calculate_class0_sim()

# %%
class0_sims

# %%
class3_sims

# %%
                                                        # VISUALIZE
# NOTE: Class indexes now start from 1 so, previous class 0 = now class 1 and so on
# FIG 1: Raw similarity plot

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Generate sample similarity data for four classes (each with 20 values in the range 0 to 1)
class1_sim = class0_sims
class2_sim = class1_sims
class3_sim = class2_sims
class4_sim = class3_sims

# Set figure size
plt.figure(figsize=(6.5, 4.2))  # Set the size of the figure (width, height)

# Sample DataFrame with four columns
data=pd.DataFrame({'Class 1':class1_sim,'Class 2':class2_sim,'Class 3':class3_sim,'Class 4':class4_sim})
df = pd.DataFrame(data)

# Plot the probability distributions
#plt.figure(figsize=(10, 6))

# Define colors and line styles for each column
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']
linestyles = ['-.', '--', '-', '-']

# Plot the probability distributions with unique colors and line styles
for column, color, linestyle in zip(df.columns, colors, linestyles):
    sns.kdeplot(df[column], label=column, color=color, linestyle=linestyle)

#plt.title('Probability Distributions of Four Columns')
plt.xlabel('Similarity',fontsize=12)
plt.ylabel('Density',fontsize=12)
plt.yticks(fontsize=12)  # Set y-tick labels font size
plt.legend(loc='upper right',fontsize=12)  # Increase legend font size

# Optimize layout
plt.tight_layout()
# Save the plot to a file
plt.savefig('output/fedvg.png', dpi=300, bbox_inches='tight')  # Save as a PNG file with high resolution

# Show the plot
plt.show()

# %%
# FIG 2: DIFFERENCES IN COSINE SIMILARITY

# For each class, we have 20 similarity values — one per image — showing how similar fake and real versions are.These values are very close across classes
# So, to highlight subtle differences, compute and plot the difference between each pair of classes, value by value.
# This gives you 20 values showing how much the similarity differs for each image between class 0 and class 1.
# It's a magnified view of the gap between classes.
# If the differences are tiny (e.g., 0.003), the plot helps make that visible and comparable.

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Differences between class distributions (pairwise)
diff_12 = np.array(class2_sim) - np.array(class1_sim)
diff_13 = np.array(class3_sim) - np.array(class1_sim)
diff_14 = np.array(class4_sim) - np.array(class1_sim)
diff_23 = np.array(class3_sim) - np.array(class2_sim)
diff_24 = np.array(class4_sim) - np.array(class2_sim)
diff_34 = np.array(class4_sim) - np.array(class3_sim)

# Create a DataFrame
diff_df = pd.DataFrame({
    'Class 2 - Class 1': diff_12,
    'Class 3 - Class 1': diff_13,
    'Class 4 - Class 1': diff_14,
    'Class 3 - Class 2': diff_23,
    'Class 4 - Class 2': diff_24,
    'Class 4 - Class 3': diff_34,
})

# Plot
plt.figure(figsize=(7.5, 5))

colors = sns.color_palette("tab10", n_colors=6)

for column, color in zip(diff_df.columns, colors):
    sns.kdeplot(diff_df[column], label=column, color=color, linestyle='-')

plt.axvline(0, color='black', linestyle='--', linewidth=1)  # reference line at 0
plt.xlabel('Difference in Similarity', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.legend(fontsize=10)
plt.title("Pairwise Differences in Cosine Similarity", fontsize=13)
plt.tight_layout()
plt.show()

# %%
def calculate_interclass_similarity(first, second):
    similarities = []

    first_images = []
    second_images = []
    if first == 'class1':
        first_images = class0_original_images.copy()
    elif first == 'class2':
        first_images = class1_original_images.copy()
    elif first == 'class3':
        first_images = class2_original_images.copy()
    elif first == 'class4':
        first_images = class3_original_images.copy()

    if second == 'class1':
        second_images = class0_original_images.copy()
    elif second == 'class2':
        second_images = class1_original_images.copy()
    elif second == 'class3':
        second_images = class2_original_images.copy()
    elif second == 'class4':
        second_images = class3_original_images.copy()
    
    for i in range(0, 20):
        first_image = first_images[i].unsqueeze(dim=0).to(device)
        first_image = first_image.repeat(1, 3, 1, 1)
        
        second_image = second_images[i].unsqueeze(dim=0).to(device)
        second_image = second_image.repeat(1, 3, 1, 1)
        
        features_first = get_feature(first_image)
        features_second = get_feature(second_image)

        cosine_similarity = 1 - cosine(features_first, features_second)
        similarities.append(cosine_similarity)

    return similarities

# %%
class1class2 = calculate_interclass_similarity('class1', 'class2')

# %%
class1class2

# %%
                                                # FIG: 3 -> INTERCLASS SIMILARITIES

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set figure size
plt.figure(figsize=(6.5, 4.2))  # Set the size of the figure (width, height)

# Generate sample similarity data for four classes (each with 20 values in the range 0 to 1)
np.random.seed(42)  # For reproducibility
class1class2 = calculate_interclass_similarity('class1', 'class2')
class1class3 = calculate_interclass_similarity('class1', 'class3')
class1class4 = calculate_interclass_similarity('class1', 'class4')
class2class3 = calculate_interclass_similarity('class2', 'class3')
class2class4 = calculate_interclass_similarity('class2', 'class4')
class3class4 = calculate_interclass_similarity('class3', 'class4')

# Sample DataFrame with four columns
data=pd.DataFrame({'Class1 vs Class2':class1class2,'Class1 vs Class3':class1class3,'Class1 vs Class4':class1class4,'Class2 vs Class3':class2class3,'Class2 vs Class4':class2class4,'Class3 vs Class4':class3class4})
df = pd.DataFrame(data)

# Plot the probability distributions
#plt.figure(figsize=(10, 6))

# Define colors and line styles for each column
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b']
linestyles = ['-.', '--', '-', '-', '-.', '--']

# Plot the probability distributions with unique colors and line styles
for column, color, linestyle in zip(df.columns, colors, linestyles):
    sns.kdeplot(df[column], label=column, color=color, linestyle=linestyle)

#plt.title('Probability Distributions of Four Columns')
plt.xlabel('Similarity',fontsize=12)
plt.ylabel('Density',fontsize=12)
plt.yticks(fontsize=12)  # Set y-tick labels font size
plt.legend(loc='upper right',fontsize=12)  # Increase legend font size

# Optimize layout
plt.tight_layout()
# Save the plot to a file
plt.savefig('output/VoiceDivergenceD3.png', dpi=300, bbox_inches='tight')  # Save as a PNG file with high resolution

# Show the plot
plt.show()
