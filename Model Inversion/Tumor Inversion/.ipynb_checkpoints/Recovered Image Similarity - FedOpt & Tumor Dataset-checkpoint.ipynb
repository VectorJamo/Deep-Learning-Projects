# %%
# Attempting to recover training data using model's parameters and a DCGAN that was trained on similar data
# Author: Suraj Neupane
# Written from scratch as a part of a Research Project 2025, Concordia University of Edmonton.
import numpy as np

import torch
from torch import nn
from torch.nn import functional

from torch.utils import data
from torch.utils.data import DataLoader

import torchvision
from torchvision import datasets
from torchvision import transforms

import pickle

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
torch.__version__
# Out:
# '2.7.1+cu118'

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
device
# Out:
# 'cuda'

# %%
# DCGAN Implementation Class
# Discriminator
class Discriminator(nn.Module):
    def __init__(self, img_channels, features_d):
        super().__init__()
        self.disc = nn.Sequential(
            # Input shape: img_channels x 64 x 64
            nn.Conv2d(
              in_channels=img_channels, out_channels=features_d, kernel_size=4, stride=2, padding=1
            ), # Output shape: features_d x 32 x 32
            nn.LeakyReLU(0.2),
            self._block(features_d, features_d*2, 4, 2, 1), # Output shape: features_d*2 x 16 x 16
            self._block(features_d*2, features_d*4, 4, 2, 1), # Output shape: features_d*4 x 8 x 8
            self._block(features_d*4, features_d*8, 4, 2, 1), # Output shape: features_d*8 x 4 x 4
           
            nn.Conv2d(in_channels=features_d*8, out_channels=1, kernel_size=4, stride=2, padding=0), # Output shape: 1 x 1
            nn.Sigmoid(),
        )

    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(0.2),
        )

    def forward(self, X):
        return self.disc(X)

# %%
# Generator
class Generator(nn.Module):
    def __init__(self, z_dim, img_channels, features_g):
        super().__init__()
        self.gen = nn.Sequential(
            self._block(z_dim, features_g*16, 4, 1, 0), # z_dim: (batch_size, 100, 1, 1) -> (batch_size, 1024, 4, 4)
            self._block(features_g*16, features_g*8, 4, 2, 1), # z_dim: (batch_size, 1024, 4, 4) -> (batch_size, 512, 8, 8)
            self._block(features_g*8, features_g*4, 4, 2, 1), # z_dim: (batch_size, 512, 8, 8) -> (batch_size, 256, 16, 16)
            self._block(features_g*4, features_g*2, 4, 2, 1), # z_dim: (batch_size, 128, 16, 16) -> (batch_size, 64, 32, 32)
            nn.ConvTranspose2d(
                in_channels=features_g*2, out_channels=img_channels, kernel_size=4, stride=2, padding=1 # z_dim: (batch_size, 64, 32, 32) -> (batch_size, 1, 64, 64)
            ),
            nn.Tanh(),
        )
        
    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.ConvTranspose2d(
                in_channels, out_channels, kernel_size, stride, padding, bias=False,
            ),
            nn.InstanceNorm2d(out_channels, affine=True),
            nn.ReLU(),
        )

    def forward(self, X):
        return self.gen(X)

# %%
# Hyperparams
z_dim = 100
img_channels = 1
features_disc = 64
features_gen = 64

# %%
# Create the model instances
gen = Generator(z_dim, img_channels, features_gen).to(device)
disc = Discriminator(img_channels, features_disc).to(device)

# %%
# Load the trained GAN
gen.load_state_dict(torch.load('saved models/Generator2.pth', weights_only=True))
disc.load_state_dict(torch.load('saved models/Discriminator2.pth', weights_only=True))
# Out:
# <All keys matched successfully>

# %%
# Generate a random fake image
noise = torch.randn(1, z_dim, 1, 1).to(device)
fake_img = gen(noise)

# %%
fake_img.shape
# Out:
# torch.Size([1, 1, 64, 64])

# %%
fake_img = fake_img.squeeze()
print(fake_img.shape)
plt.axis(False)
plt.title('Fake Generated Image:')
plt.imshow(fake_img.cpu().detach(), cmap='gray')
# Out:
# torch.Size([64, 64])

# %%
# Target Model
class TFCNN(nn.Module):
    def __init__(self, n_classes):
        super().__init__()
        self.n_classes = n_classes

        self.encoder = nn.Sequential(
            nn.Conv2d(3, 32, 3, stride=1, padding=1),
            nn.ReLU(True),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, 3, stride=1, padding=1),
            nn.ReLU(True),
            nn.MaxPool2d(2),
            nn.Conv2d(64, 64, 3, stride=1, padding=1),
            nn.ReLU(True),
            nn.MaxPool2d(2),
            Reshape(),
        )

        self.h_size = 64 * 4 * 4

        self.classifier = nn.Sequential(
            nn.Linear(64 * 4 * 4, 128),
            nn.ReLU(True),
            nn.Linear(128, n_classes)
        )

    def forward(self, xs):
        code = self.encoder(xs)
        logits = self.classifier(code)
        return code, logits

# %%
class Reshape(nn.Module):
    def __init__(self,):
        super().__init__()

    def forward(self, xs):
        return xs.reshape((xs.shape[0], -1))

# %%
class ClassifyNet(nn.Module):
    def __init__(self, net, init_way, n_classes, input_size=None):
        super().__init__()
        self.net = net
        self.init_way = init_way
        self.n_classes = n_classes

        model = TFCNN(n_classes)

        self.h_size = model.h_size

        # Convo and pool layers
        self.encoder = model.encoder

        # Classifier layer
        self.classifier = nn.Linear(
            self.h_size, self.n_classes, bias=False
        )

        if self.init_way == "orth":
            ws = get_orth_weights(self.h_size, self.n_classes)
            self.classifier.load_state_dict({"weight": ws})

    def forward(self, xs):
        hs = self.encoder(xs)
        logits = self.classifier(hs)
        return hs, logits

# %%
def load_target_model(base_net, n_classes, path):
    # Create the base model
    model = ClassifyNet(net=base_net, init_way='none', n_classes=n_classes)
    # Load the model
    model.load_state_dict(torch.load(path, weights_only=True))

    return model

# %%
# Target Model Loading
BASE_NET = 'TFCNN'
DATASET = 'tumor4'
N_CLASSES = 4

target_model = load_target_model(base_net=BASE_NET, n_classes=N_CLASSES, path='saved models/fedopt_global_model.path').to(device)
print('Model loaded successfully!')
target_model.eval()

num_params = sum(p.numel() for p in target_model.parameters())
print('Number of parameters in the loaded model:', num_params)
# Out:
# Model loaded successfully!
# Number of parameters in the loaded model: 60416

# %%
# BEGIN BATCH MODEL INVERSION
img_count = 20
latent_vectors = torch.randn(img_count, z_dim, 1, 1, requires_grad=True) # Start with 20 random noises

# %%
def recover_images(count, target_image_class, latent_vectors):
    optimized_latent_vectors = []
    
    for x in range(0, count):
        z = latent_vectors[x].unsqueeze(dim=0).clone().detach().requires_grad_(True)
        
        learning_rate = 0.01
        target_class = 1 # The second class
        
        # Create the optimizer
        optimizer = torch.optim.Adam([z], lr=learning_rate)
        
        # Loss function (e.g., Cross-Entropy with classifier outputs)
        loss_fn = nn.CrossEntropyLoss()
        target_class = torch.tensor([target_image_class])  # Set the target class
    
        # Optimization loop to find the best z
        rounds = 500
        for i in range(rounds):
            optimizer.zero_grad()
            
            generated_image = gen(z.to(device))  # Generate an image from the latent vector
            generated_image = generated_image.repeat(1, 3, 1, 1)
            generated_image = functional.interpolate(generated_image, size=(32, 32), mode='nearest')
            #print(generated_image.shape)
            hs, prediction_logits = target_model(generated_image)  # Classifier output
            #print(prediction_logits)
            #print(type(prediction_logits))
            loss = loss_fn(prediction_logits, target_class.to(device))  # Minimize difference with true class
            loss.backward()
            optimizer.step()
            
            if i % 50 == 0:
                print(f"Generating Image Number: {x+1} for target class {target_class}. Step {i}, Loss: {loss.item()}")
    
        optimized_latent_vectors.append(z)
        
    return optimized_latent_vectors

# %%
class0_optimized_latent_vectors = recover_images(img_count, 0, latent_vectors)
# Out:
# Generating Image Number: 1 for target class tensor([0]). Step 0, Loss: 0.0
# Generating Image Number: 1 for target class tensor([0]). Step 50, Loss: 0.0
# Generating Image Number: 1 for target class tensor([0]). Step 100, Loss: 0.0
# Generating Image Number: 1 for target class tensor([0]). Step 150, Loss: 0.0
# Generating Image Number: 1 for target class tensor([0]). Step 200, Loss: 0.0
# Generating Image Number: 1 for target class tensor([0]). Step 250, Loss: 0.0
# Generating Image Number: 1 for target class tensor([0]). Step 300, Loss: 0.0
# Generating Image Number: 1 for target class tensor([0]). Step 350, Loss: 0.0
# Generating Image Number: 1 for target class tensor([0]). Step 400, Loss: 0.0
# Generating Image Number: 1 for target class tensor([0]). Step 450, Loss: 0.0
# Generating Image Number: 2 for target class tensor([0]). Step 0, Loss: 7.8310747146606445
# Generating Image Number: 2 for target class tensor([0]). Step 50, Loss: 4.629520416259766
# Generating Image Number: 2 for target class tensor([0]). Step 100, Loss: 3.853076219558716
# Generating Image Number: 2 for target class tensor([0]). Step 150, Loss: 3.446113109588623
# Generating Image Number: 2 for target class tensor([0]). Step 200, Loss: 3.0379583835601807
# Generating Image Number: 2 for target class tensor([0]). Step 250, Loss: 2.678889036178589
# Generating Image Number: 2 for target class tensor([0]). Step 300, Loss: 2.4656317234039307
# Generating Image Number: 2 for target class tensor([0]). Step 350, Loss: 2.2843105792999268
# Generating Image Number: 2 for target class tensor([0]). Step 400, Loss: 2.251455783843994
# Generating Image Number: 2 for target class tensor([0]). Step 450, Loss: 2.044572591781616
# Generating Image Number: 3 for target class tensor([0]). Step 0, Loss: 10.641290664672852
# Generating Image Number: 3 for target class tensor([0]). Step 50, Loss: 0.7995918393135071
# Generating Image Number: 3 for target class tensor([0]). Step 100, Loss: 0.2782599627971649
# Generating Image Number: 3 for target class tensor([0]). Step 150, Loss: 0.1899486482143402
# Generating Image Number: 3 for target class tensor([0]). Step 200, Loss: 0.14177867770195007
# Generating Image Number: 3 for target class tensor([0]). Step 250, Loss: 0.10953202098608017
# Generating Image Number: 3 for target class tensor([0]). Step 300, Loss: 0.08861777186393738
# Generating Image Number: 3 for target class tensor([0]). Step 350, Loss: 0.07300800085067749
# Generating Image Number: 3 for target class tensor([0]). Step 400, Loss: 0.06108710169792175
# Generating Image Number: 3 for target class tensor([0]). Step 450, Loss: 0.051628489047288895
# Generating Image Number: 4 for target class tensor([0]). Step 0, Loss: 7.270588397979736
# Generating Image Number: 4 for target class tensor([0]). Step 50, Loss: 2.0189414024353027
# Generating Image Number: 4 for target class tensor([0]). Step 100, Loss: 1.4444167613983154
# Generating Image Number: 4 for target class tensor([0]). Step 150, Loss: 1.1190855503082275
# Generating Image Number: 4 for target class tensor([0]). Step 200, Loss: 0.8592284917831421
# Generating Image Number: 4 for target class tensor([0]). Step 250, Loss: 0.6738839149475098
# Generating Image Number: 4 for target class tensor([0]). Step 300, Loss: 0.5233755707740784
# Generating Image Number: 4 for target class tensor([0]). Step 350, Loss: 0.42986321449279785
# Generating Image Number: 4 for target class tensor([0]). Step 400, Loss: 0.36270445585250854
# Generating Image Number: 4 for target class tensor([0]). Step 450, Loss: 0.31521284580230713
# Generating Image Number: 5 for target class tensor([0]). Step 0, Loss: 11.440503120422363
# Generating Image Number: 5 for target class tensor([0]). Step 50, Loss: 5.1612420082092285
# Generating Image Number: 5 for target class tensor([0]). Step 100, Loss: 4.255650520324707
# Generating Image Number: 5 for target class tensor([0]). Step 150, Loss: 3.515411376953125
# Generating Image Number: 5 for target class tensor([0]). Step 200, Loss: 2.7037575244903564
# Generating Image Number: 5 for target class tensor([0]). Step 250, Loss: 1.9582351446151733
# Generating Image Number: 5 for target class tensor([0]). Step 300, Loss: 1.5799925327301025
# Generating Image Number: 5 for target class tensor([0]). Step 350, Loss: 1.1821691989898682
# Generating Image Number: 5 for target class tensor([0]). Step 400, Loss: 0.8594850301742554
# Generating Image Number: 5 for target class tensor([0]). Step 450, Loss: 0.6311913132667542
# Generating Image Number: 6 for target class tensor([0]). Step 0, Loss: 8.44920539855957
# Generating Image Number: 6 for target class tensor([0]). Step 50, Loss: 1.117440938949585
# Generating Image Number: 6 for target class tensor([0]). Step 100, Loss: 0.3831467628479004
# Generating Image Number: 6 for target class tensor([0]). Step 150, Loss: 0.2630664110183716
# Generating Image Number: 6 for target class tensor([0]). Step 200, Loss: 0.212208092212677
# Generating Image Number: 6 for target class tensor([0]). Step 250, Loss: 0.17363975942134857
# Generating Image Number: 6 for target class tensor([0]). Step 300, Loss: 0.14336054027080536
# Generating Image Number: 6 for target class tensor([0]). Step 350, Loss: 0.11975614726543427
# Generating Image Number: 6 for target class tensor([0]). Step 400, Loss: 0.10344911366701126
# Generating Image Number: 6 for target class tensor([0]). Step 450, Loss: 0.09051202237606049
# Generating Image Number: 7 for target class tensor([0]). Step 0, Loss: 3.5668447017669678
# Generating Image Number: 7 for target class tensor([0]). Step 50, Loss: 0.4041467308998108
# Generating Image Number: 7 for target class tensor([0]). Step 100, Loss: 0.2546631693840027
# Generating Image Number: 7 for target class tensor([0]). Step 150, Loss: 0.1811542510986328
# Generating Image Number: 7 for target class tensor([0]). Step 200, Loss: 0.14143618941307068
# Generating Image Number: 7 for target class tensor([0]). Step 250, Loss: 0.10784003138542175
# Generating Image Number: 7 for target class tensor([0]). Step 300, Loss: 0.08627603948116302
# Generating Image Number: 7 for target class tensor([0]). Step 350, Loss: 0.07326982915401459
# Generating Image Number: 7 for target class tensor([0]). Step 400, Loss: 0.06352563947439194
# Generating Image Number: 7 for target class tensor([0]). Step 450, Loss: 0.05679519474506378
# Generating Image Number: 8 for target class tensor([0]). Step 0, Loss: 8.08059024810791
# Generating Image Number: 8 for target class tensor([0]). Step 50, Loss: 0.2963029146194458
# Generating Image Number: 8 for target class tensor([0]). Step 100, Loss: 0.12862560153007507
# Generating Image Number: 8 for target class tensor([0]). Step 150, Loss: 0.09470497816801071
# Generating Image Number: 8 for target class tensor([0]). Step 200, Loss: 0.07821276783943176
# Generating Image Number: 8 for target class tensor([0]). Step 250, Loss: 0.0679798424243927
# Generating Image Number: 8 for target class tensor([0]). Step 300, Loss: 0.05997591093182564
# Generating Image Number: 8 for target class tensor([0]). Step 350, Loss: 0.05383875221014023
# Generating Image Number: 8 for target class tensor([0]). Step 400, Loss: 0.048445943742990494
# Generating Image Number: 8 for target class tensor([0]). Step 450, Loss: 0.044730931520462036
# Generating Image Number: 9 for target class tensor([0]). Step 0, Loss: 7.784374237060547
# Generating Image Number: 9 for target class tensor([0]). Step 50, Loss: 6.421647548675537
# Generating Image Number: 9 for target class tensor([0]). Step 100, Loss: 6.173656463623047
# Generating Image Number: 9 for target class tensor([0]). Step 150, Loss: 5.896439552307129
# Generating Image Number: 9 for target class tensor([0]). Step 200, Loss: 5.726881504058838
# Generating Image Number: 9 for target class tensor([0]). Step 250, Loss: 5.595077991485596
# Generating Image Number: 9 for target class tensor([0]). Step 300, Loss: 5.496563911437988
# Generating Image Number: 9 for target class tensor([0]). Step 350, Loss: 5.409475803375244
# Generating Image Number: 9 for target class tensor([0]). Step 400, Loss: 5.304074287414551
# Generating Image Number: 9 for target class tensor([0]). Step 450, Loss: 5.198559284210205
# Generating Image Number: 10 for target class tensor([0]). Step 0, Loss: 3.9357643127441406
# Generating Image Number: 10 for target class tensor([0]). Step 50, Loss: 1.6092870235443115
# Generating Image Number: 10 for target class tensor([0]). Step 100, Loss: 0.8431654572486877
# Generating Image Number: 10 for target class tensor([0]). Step 150, Loss: 0.5411185026168823
# Generating Image Number: 10 for target class tensor([0]). Step 200, Loss: 0.4164394736289978
# Generating Image Number: 10 for target class tensor([0]). Step 250, Loss: 0.3470863699913025
# Generating Image Number: 10 for target class tensor([0]). Step 300, Loss: 0.28928467631340027
# Generating Image Number: 10 for target class tensor([0]). Step 350, Loss: 0.24693138897418976
# Generating Image Number: 10 for target class tensor([0]). Step 400, Loss: 0.20742562413215637
# Generating Image Number: 10 for target class tensor([0]). Step 450, Loss: 0.1792931705713272
# Generating Image Number: 11 for target class tensor([0]). Step 0, Loss: 0.0
# Generating Image Number: 11 for target class tensor([0]). Step 50, Loss: 0.0
# Generating Image Number: 11 for target class tensor([0]). Step 100, Loss: 0.0
# Generating Image Number: 11 for target class tensor([0]). Step 150, Loss: 0.0
# Generating Image Number: 11 for target class tensor([0]). Step 200, Loss: 0.0
# Generating Image Number: 11 for target class tensor([0]). Step 250, Loss: 0.0
# Generating Image Number: 11 for target class tensor([0]). Step 300, Loss: 0.0
# Generating Image Number: 11 for target class tensor([0]). Step 350, Loss: 0.0
# Generating Image Number: 11 for target class tensor([0]). Step 400, Loss: 0.0
# Generating Image Number: 11 for target class tensor([0]). Step 450, Loss: 0.0
# Generating Image Number: 12 for target class tensor([0]). Step 0, Loss: 0.0
# Generating Image Number: 12 for target class tensor([0]). Step 50, Loss: 0.0
# Generating Image Number: 12 for target class tensor([0]). Step 100, Loss: 0.0
# Generating Image Number: 12 for target class tensor([0]). Step 150, Loss: 0.0
# Generating Image Number: 12 for target class tensor([0]). Step 200, Loss: 0.0
# Generating Image Number: 12 for target class tensor([0]). Step 250, Loss: 0.0
# Generating Image Number: 12 for target class tensor([0]). Step 300, Loss: 0.0
# Generating Image Number: 12 for target class tensor([0]). Step 350, Loss: 0.0
# Generating Image Number: 12 for target class tensor([0]). Step 400, Loss: 0.0
# Generating Image Number: 12 for target class tensor([0]). Step 450, Loss: 0.0
# Generating Image Number: 13 for target class tensor([0]). Step 0, Loss: 12.398011207580566
# Generating Image Number: 13 for target class tensor([0]). Step 50, Loss: 4.44165563583374
# Generating Image Number: 13 for target class tensor([0]). Step 100, Loss: 3.4205613136291504
# Generating Image Number: 13 for target class tensor([0]). Step 150, Loss: 2.4997220039367676
# Generating Image Number: 13 for target class tensor([0]). Step 200, Loss: 1.6168651580810547
# Generating Image Number: 13 for target class tensor([0]). Step 250, Loss: 0.9669075012207031
# Generating Image Number: 13 for target class tensor([0]). Step 300, Loss: 0.6744616031646729
# Generating Image Number: 13 for target class tensor([0]). Step 350, Loss: 0.4815690219402313
# Generating Image Number: 13 for target class tensor([0]). Step 400, Loss: 0.3881740868091583
# Generating Image Number: 13 for target class tensor([0]). Step 450, Loss: 0.33012524247169495
# Generating Image Number: 14 for target class tensor([0]). Step 0, Loss: 1.1130520105361938
# Generating Image Number: 14 for target class tensor([0]). Step 50, Loss: 0.09376872330904007
# Generating Image Number: 14 for target class tensor([0]). Step 100, Loss: 0.05886651948094368
# Generating Image Number: 14 for target class tensor([0]). Step 150, Loss: 0.04332861676812172
# Generating Image Number: 14 for target class tensor([0]). Step 200, Loss: 0.03303514048457146
# Generating Image Number: 14 for target class tensor([0]). Step 250, Loss: 0.026820622384548187
# Generating Image Number: 14 for target class tensor([0]). Step 300, Loss: 0.022057676687836647
# Generating Image Number: 14 for target class tensor([0]). Step 350, Loss: 0.01888006366789341
# Generating Image Number: 14 for target class tensor([0]). Step 400, Loss: 0.016811244189739227
# Generating Image Number: 14 for target class tensor([0]). Step 450, Loss: 0.015458526089787483
# Generating Image Number: 15 for target class tensor([0]). Step 0, Loss: 0.0
# Generating Image Number: 15 for target class tensor([0]). Step 50, Loss: 0.0
# Generating Image Number: 15 for target class tensor([0]). Step 100, Loss: 0.0
# Generating Image Number: 15 for target class tensor([0]). Step 150, Loss: 0.0
# Generating Image Number: 15 for target class tensor([0]). Step 200, Loss: 0.0
# Generating Image Number: 15 for target class tensor([0]). Step 250, Loss: 0.0
# Generating Image Number: 15 for target class tensor([0]). Step 300, Loss: 0.0
# Generating Image Number: 15 for target class tensor([0]). Step 350, Loss: 0.0
# Generating Image Number: 15 for target class tensor([0]). Step 400, Loss: 0.0
# Generating Image Number: 15 for target class tensor([0]). Step 450, Loss: 0.0
# Generating Image Number: 16 for target class tensor([0]). Step 0, Loss: 9.158768653869629
# Generating Image Number: 16 for target class tensor([0]). Step 50, Loss: 5.9847517013549805
# Generating Image Number: 16 for target class tensor([0]). Step 100, Loss: 4.915310859680176
# Generating Image Number: 16 for target class tensor([0]). Step 150, Loss: 3.794220447540283
# Generating Image Number: 16 for target class tensor([0]). Step 200, Loss: 3.2497851848602295
# Generating Image Number: 16 for target class tensor([0]). Step 250, Loss: 2.8074960708618164
# Generating Image Number: 16 for target class tensor([0]). Step 300, Loss: 2.3956165313720703
# Generating Image Number: 16 for target class tensor([0]). Step 350, Loss: 2.1113293170928955
# Generating Image Number: 16 for target class tensor([0]). Step 400, Loss: 1.9138396978378296
# Generating Image Number: 16 for target class tensor([0]). Step 450, Loss: 1.7636555433273315
# Generating Image Number: 17 for target class tensor([0]). Step 0, Loss: 5.236698150634766
# Generating Image Number: 17 for target class tensor([0]). Step 50, Loss: 2.248457193374634
# Generating Image Number: 17 for target class tensor([0]). Step 100, Loss: 2.0822250843048096
# Generating Image Number: 17 for target class tensor([0]). Step 150, Loss: 1.9392362833023071
# Generating Image Number: 17 for target class tensor([0]). Step 200, Loss: 1.8263016939163208
# Generating Image Number: 17 for target class tensor([0]). Step 250, Loss: 1.7269142866134644
# Generating Image Number: 17 for target class tensor([0]). Step 300, Loss: 1.6080539226531982
# Generating Image Number: 17 for target class tensor([0]). Step 350, Loss: 1.5158907175064087
# Generating Image Number: 17 for target class tensor([0]). Step 400, Loss: 1.459313154220581
# Generating Image Number: 17 for target class tensor([0]). Step 450, Loss: 1.4142767190933228
# Generating Image Number: 18 for target class tensor([0]). Step 0, Loss: 4.330653667449951
# Generating Image Number: 18 for target class tensor([0]). Step 50, Loss: 0.37754330039024353
# Generating Image Number: 18 for target class tensor([0]). Step 100, Loss: 0.22377678751945496
# Generating Image Number: 18 for target class tensor([0]). Step 150, Loss: 0.1487124115228653
# Generating Image Number: 18 for target class tensor([0]). Step 200, Loss: 0.10716342180967331
# Generating Image Number: 18 for target class tensor([0]). Step 250, Loss: 0.0856226459145546
# Generating Image Number: 18 for target class tensor([0]). Step 300, Loss: 0.07387996464967728
# Generating Image Number: 18 for target class tensor([0]). Step 350, Loss: 0.06353257596492767
# Generating Image Number: 18 for target class tensor([0]). Step 400, Loss: 0.052330490201711655
# Generating Image Number: 18 for target class tensor([0]). Step 450, Loss: 0.04500094801187515
# Generating Image Number: 19 for target class tensor([0]). Step 0, Loss: 7.263913154602051
# Generating Image Number: 19 for target class tensor([0]). Step 50, Loss: 0.42728787660598755
# Generating Image Number: 19 for target class tensor([0]). Step 100, Loss: 0.25593289732933044
# Generating Image Number: 19 for target class tensor([0]). Step 150, Loss: 0.20333869755268097
# Generating Image Number: 19 for target class tensor([0]). Step 200, Loss: 0.17026369273662567
# Generating Image Number: 19 for target class tensor([0]). Step 250, Loss: 0.14598731696605682
# Generating Image Number: 19 for target class tensor([0]). Step 300, Loss: 0.12720216810703278
# Generating Image Number: 19 for target class tensor([0]). Step 350, Loss: 0.11149320751428604
# Generating Image Number: 19 for target class tensor([0]). Step 400, Loss: 0.10064324736595154
# Generating Image Number: 19 for target class tensor([0]). Step 450, Loss: 0.09073468297719955
# Generating Image Number: 20 for target class tensor([0]). Step 0, Loss: 8.135878562927246
# Generating Image Number: 20 for target class tensor([0]). Step 50, Loss: 2.3122916221618652
# Generating Image Number: 20 for target class tensor([0]). Step 100, Loss: 2.0769643783569336
# Generating Image Number: 20 for target class tensor([0]). Step 150, Loss: 1.9937102794647217
# Generating Image Number: 20 for target class tensor([0]). Step 200, Loss: 1.9181629419326782
# Generating Image Number: 20 for target class tensor([0]). Step 250, Loss: 1.8515040874481201
# Generating Image Number: 20 for target class tensor([0]). Step 300, Loss: 1.8067009449005127
# Generating Image Number: 20 for target class tensor([0]). Step 350, Loss: 1.7688546180725098
# Generating Image Number: 20 for target class tensor([0]). Step 400, Loss: 1.7302873134613037
# Generating Image Number: 20 for target class tensor([0]). Step 450, Loss: 1.6901946067810059

# %%
torch.manual_seed(100)
latent_vectors = torch.randn(img_count, z_dim, 1, 1, requires_grad=True) # Start with 20 random noises
class1_optimized_latent_vectors = recover_images(img_count, 1, latent_vectors)
# Out:
# Generating Image Number: 1 for target class tensor([1]). Step 0, Loss: 11.434466361999512
# Generating Image Number: 1 for target class tensor([1]). Step 50, Loss: 6.294295310974121
# Generating Image Number: 1 for target class tensor([1]). Step 100, Loss: 5.311086177825928
# Generating Image Number: 1 for target class tensor([1]). Step 150, Loss: 4.809354305267334
# Generating Image Number: 1 for target class tensor([1]). Step 200, Loss: 4.44625186920166
# Generating Image Number: 1 for target class tensor([1]). Step 250, Loss: 4.1841020584106445
# Generating Image Number: 1 for target class tensor([1]). Step 300, Loss: 4.032792568206787
# Generating Image Number: 1 for target class tensor([1]). Step 350, Loss: 3.8222813606262207
# Generating Image Number: 1 for target class tensor([1]). Step 400, Loss: 3.7179434299468994
# Generating Image Number: 1 for target class tensor([1]). Step 450, Loss: 3.5463008880615234
# Generating Image Number: 2 for target class tensor([1]). Step 0, Loss: 9.023519515991211
# Generating Image Number: 2 for target class tensor([1]). Step 50, Loss: 6.081384181976318
# Generating Image Number: 2 for target class tensor([1]). Step 100, Loss: 5.262702941894531
# Generating Image Number: 2 for target class tensor([1]). Step 150, Loss: 4.817764759063721
# Generating Image Number: 2 for target class tensor([1]). Step 200, Loss: 4.6379170417785645
# Generating Image Number: 2 for target class tensor([1]). Step 250, Loss: 4.463134765625
# Generating Image Number: 2 for target class tensor([1]). Step 300, Loss: 4.318542957305908
# Generating Image Number: 2 for target class tensor([1]). Step 350, Loss: 4.214190483093262
# Generating Image Number: 2 for target class tensor([1]). Step 400, Loss: 4.088359832763672
# Generating Image Number: 2 for target class tensor([1]). Step 450, Loss: 4.021607398986816
# Generating Image Number: 3 for target class tensor([1]). Step 0, Loss: 10.19532585144043
# Generating Image Number: 3 for target class tensor([1]). Step 50, Loss: 4.459558486938477
# Generating Image Number: 3 for target class tensor([1]). Step 100, Loss: 3.8328664302825928
# Generating Image Number: 3 for target class tensor([1]). Step 150, Loss: 3.4907963275909424
# Generating Image Number: 3 for target class tensor([1]). Step 200, Loss: 3.2262325286865234
# Generating Image Number: 3 for target class tensor([1]). Step 250, Loss: 2.981126546859741
# Generating Image Number: 3 for target class tensor([1]). Step 300, Loss: 2.735616683959961
# Generating Image Number: 3 for target class tensor([1]). Step 350, Loss: 2.536067008972168
# Generating Image Number: 3 for target class tensor([1]). Step 400, Loss: 2.3727307319641113
# Generating Image Number: 3 for target class tensor([1]). Step 450, Loss: 2.2182493209838867
# Generating Image Number: 4 for target class tensor([1]). Step 0, Loss: 10.547179222106934
# Generating Image Number: 4 for target class tensor([1]). Step 50, Loss: 7.398762226104736
# Generating Image Number: 4 for target class tensor([1]). Step 100, Loss: 7.213514804840088
# Generating Image Number: 4 for target class tensor([1]). Step 150, Loss: 7.038138389587402
# Generating Image Number: 4 for target class tensor([1]). Step 200, Loss: 6.911629676818848
# Generating Image Number: 4 for target class tensor([1]). Step 250, Loss: 6.836580276489258
# Generating Image Number: 4 for target class tensor([1]). Step 300, Loss: 6.7750959396362305
# Generating Image Number: 4 for target class tensor([1]). Step 350, Loss: 6.7260355949401855
# Generating Image Number: 4 for target class tensor([1]). Step 400, Loss: 6.674201011657715
# Generating Image Number: 4 for target class tensor([1]). Step 450, Loss: 6.592368125915527
# Generating Image Number: 5 for target class tensor([1]). Step 0, Loss: 6.1768622398376465
# Generating Image Number: 5 for target class tensor([1]). Step 50, Loss: 4.000662326812744
# Generating Image Number: 5 for target class tensor([1]). Step 100, Loss: 3.4159295558929443
# Generating Image Number: 5 for target class tensor([1]). Step 150, Loss: 3.052506446838379
# Generating Image Number: 5 for target class tensor([1]). Step 200, Loss: 2.7529172897338867
# Generating Image Number: 5 for target class tensor([1]). Step 250, Loss: 2.5541813373565674
# Generating Image Number: 5 for target class tensor([1]). Step 300, Loss: 2.3752923011779785
# Generating Image Number: 5 for target class tensor([1]). Step 350, Loss: 2.228780746459961
# Generating Image Number: 5 for target class tensor([1]). Step 400, Loss: 2.0808424949645996
# Generating Image Number: 5 for target class tensor([1]). Step 450, Loss: 1.9866812229156494
# Generating Image Number: 6 for target class tensor([1]). Step 0, Loss: 8.25727653503418
# Generating Image Number: 6 for target class tensor([1]). Step 50, Loss: 4.708192825317383
# Generating Image Number: 6 for target class tensor([1]). Step 100, Loss: 3.2783970832824707
# Generating Image Number: 6 for target class tensor([1]). Step 150, Loss: 2.7817447185516357
# Generating Image Number: 6 for target class tensor([1]). Step 200, Loss: 2.518829107284546
# Generating Image Number: 6 for target class tensor([1]). Step 250, Loss: 2.3163065910339355
# Generating Image Number: 6 for target class tensor([1]). Step 300, Loss: 2.158078670501709
# Generating Image Number: 6 for target class tensor([1]). Step 350, Loss: 2.042022228240967
# Generating Image Number: 6 for target class tensor([1]). Step 400, Loss: 1.9479323625564575
# Generating Image Number: 6 for target class tensor([1]). Step 450, Loss: 1.847231388092041
# Generating Image Number: 7 for target class tensor([1]). Step 0, Loss: 68.47048950195312
# Generating Image Number: 7 for target class tensor([1]). Step 50, Loss: 1.1621204614639282
# Generating Image Number: 7 for target class tensor([1]). Step 100, Loss: 0.8004248738288879
# Generating Image Number: 7 for target class tensor([1]). Step 150, Loss: 0.6054482460021973
# Generating Image Number: 7 for target class tensor([1]). Step 200, Loss: 0.5088732838630676
# Generating Image Number: 7 for target class tensor([1]). Step 250, Loss: 0.4239881634712219
# Generating Image Number: 7 for target class tensor([1]). Step 300, Loss: 0.3358632028102875
# Generating Image Number: 7 for target class tensor([1]). Step 350, Loss: 0.2912064790725708
# Generating Image Number: 7 for target class tensor([1]). Step 400, Loss: 0.2638891339302063
# Generating Image Number: 7 for target class tensor([1]). Step 450, Loss: 0.2401653230190277
# Generating Image Number: 8 for target class tensor([1]). Step 0, Loss: 84.89286041259766
# Generating Image Number: 8 for target class tensor([1]). Step 50, Loss: 58.33740234375
# Generating Image Number: 8 for target class tensor([1]). Step 100, Loss: 5.050681114196777
# Generating Image Number: 8 for target class tensor([1]). Step 150, Loss: 4.718477249145508
# Generating Image Number: 8 for target class tensor([1]). Step 200, Loss: 4.453521728515625
# Generating Image Number: 8 for target class tensor([1]). Step 250, Loss: 4.1980695724487305
# Generating Image Number: 8 for target class tensor([1]). Step 300, Loss: 3.5819644927978516
# Generating Image Number: 8 for target class tensor([1]). Step 350, Loss: 3.346198320388794
# Generating Image Number: 8 for target class tensor([1]). Step 400, Loss: 3.173933506011963
# Generating Image Number: 8 for target class tensor([1]). Step 450, Loss: 3.022549629211426
# Generating Image Number: 9 for target class tensor([1]). Step 0, Loss: 13.320047378540039
# Generating Image Number: 9 for target class tensor([1]). Step 50, Loss: 11.976995468139648
# Generating Image Number: 9 for target class tensor([1]). Step 100, Loss: 11.669593811035156
# Generating Image Number: 9 for target class tensor([1]). Step 150, Loss: 11.47230052947998
# Generating Image Number: 9 for target class tensor([1]). Step 200, Loss: 11.243229866027832
# Generating Image Number: 9 for target class tensor([1]). Step 250, Loss: 11.053458213806152
# Generating Image Number: 9 for target class tensor([1]). Step 300, Loss: 10.883709907531738
# Generating Image Number: 9 for target class tensor([1]). Step 350, Loss: 10.76500129699707
# Generating Image Number: 9 for target class tensor([1]). Step 400, Loss: 10.674016952514648
# Generating Image Number: 9 for target class tensor([1]). Step 450, Loss: 10.559403419494629
# Generating Image Number: 10 for target class tensor([1]). Step 0, Loss: 14.056669235229492
# Generating Image Number: 10 for target class tensor([1]). Step 50, Loss: 3.349257230758667
# Generating Image Number: 10 for target class tensor([1]). Step 100, Loss: 2.403261423110962
# Generating Image Number: 10 for target class tensor([1]). Step 150, Loss: 1.7500249147415161
# Generating Image Number: 10 for target class tensor([1]). Step 200, Loss: 1.1810941696166992
# Generating Image Number: 10 for target class tensor([1]). Step 250, Loss: 0.8216130137443542
# Generating Image Number: 10 for target class tensor([1]). Step 300, Loss: 0.6121335029602051
# Generating Image Number: 10 for target class tensor([1]). Step 350, Loss: 0.4585087299346924
# Generating Image Number: 10 for target class tensor([1]). Step 400, Loss: 0.367326557636261
# Generating Image Number: 10 for target class tensor([1]). Step 450, Loss: 0.30860963463783264
# Generating Image Number: 11 for target class tensor([1]). Step 0, Loss: 11.765071868896484
# Generating Image Number: 11 for target class tensor([1]). Step 50, Loss: 7.932448863983154
# Generating Image Number: 11 for target class tensor([1]). Step 100, Loss: 6.091048717498779
# Generating Image Number: 11 for target class tensor([1]). Step 150, Loss: 4.769497871398926
# Generating Image Number: 11 for target class tensor([1]). Step 200, Loss: 3.8285181522369385
# Generating Image Number: 11 for target class tensor([1]). Step 250, Loss: 3.5919899940490723
# Generating Image Number: 11 for target class tensor([1]). Step 300, Loss: 2.6609010696411133
# Generating Image Number: 11 for target class tensor([1]). Step 350, Loss: 2.3325486183166504
# Generating Image Number: 11 for target class tensor([1]). Step 400, Loss: 2.074336051940918
# Generating Image Number: 11 for target class tensor([1]). Step 450, Loss: 1.8811755180358887
# Generating Image Number: 12 for target class tensor([1]). Step 0, Loss: 16.840055465698242
# Generating Image Number: 12 for target class tensor([1]). Step 50, Loss: 13.160523414611816
# Generating Image Number: 12 for target class tensor([1]). Step 100, Loss: 12.80996322631836
# Generating Image Number: 12 for target class tensor([1]). Step 150, Loss: 12.4685640335083
# Generating Image Number: 12 for target class tensor([1]). Step 200, Loss: 12.291203498840332
# Generating Image Number: 12 for target class tensor([1]). Step 250, Loss: 11.982725143432617
# Generating Image Number: 12 for target class tensor([1]). Step 300, Loss: 11.611542701721191
# Generating Image Number: 12 for target class tensor([1]). Step 350, Loss: 11.395956039428711
# Generating Image Number: 12 for target class tensor([1]). Step 400, Loss: 11.282151222229004
# Generating Image Number: 12 for target class tensor([1]). Step 450, Loss: 11.204146385192871
# Generating Image Number: 13 for target class tensor([1]). Step 0, Loss: 10.322843551635742
# Generating Image Number: 13 for target class tensor([1]). Step 50, Loss: 5.696824073791504
# Generating Image Number: 13 for target class tensor([1]). Step 100, Loss: 5.2768073081970215
# Generating Image Number: 13 for target class tensor([1]). Step 150, Loss: 5.011919021606445
# Generating Image Number: 13 for target class tensor([1]). Step 200, Loss: 4.770998001098633
# Generating Image Number: 13 for target class tensor([1]). Step 250, Loss: 4.514997959136963
# Generating Image Number: 13 for target class tensor([1]). Step 300, Loss: 4.281954288482666
# Generating Image Number: 13 for target class tensor([1]). Step 350, Loss: 4.1104230880737305
# Generating Image Number: 13 for target class tensor([1]). Step 400, Loss: 4.010011672973633
# Generating Image Number: 13 for target class tensor([1]). Step 450, Loss: 3.8940036296844482
# Generating Image Number: 14 for target class tensor([1]). Step 0, Loss: 7.284477233886719
# Generating Image Number: 14 for target class tensor([1]). Step 50, Loss: 5.447082996368408
# Generating Image Number: 14 for target class tensor([1]). Step 100, Loss: 4.592103004455566
# Generating Image Number: 14 for target class tensor([1]). Step 150, Loss: 3.723083257675171
# Generating Image Number: 14 for target class tensor([1]). Step 200, Loss: 3.184757709503174
# Generating Image Number: 14 for target class tensor([1]). Step 250, Loss: 2.7594995498657227
# Generating Image Number: 14 for target class tensor([1]). Step 300, Loss: 2.555302858352661
# Generating Image Number: 14 for target class tensor([1]). Step 350, Loss: 2.427145481109619
# Generating Image Number: 14 for target class tensor([1]). Step 400, Loss: 2.253333568572998
# Generating Image Number: 14 for target class tensor([1]). Step 450, Loss: 1.9835129976272583
# Generating Image Number: 15 for target class tensor([1]). Step 0, Loss: 11.446282386779785
# Generating Image Number: 15 for target class tensor([1]). Step 50, Loss: 3.640385150909424
# Generating Image Number: 15 for target class tensor([1]). Step 100, Loss: 3.1801505088806152
# Generating Image Number: 15 for target class tensor([1]). Step 150, Loss: 2.7978830337524414
# Generating Image Number: 15 for target class tensor([1]). Step 200, Loss: 2.5371217727661133
# Generating Image Number: 15 for target class tensor([1]). Step 250, Loss: 2.4081666469573975
# Generating Image Number: 15 for target class tensor([1]). Step 300, Loss: 2.1957931518554688
# Generating Image Number: 15 for target class tensor([1]). Step 350, Loss: 2.0831668376922607
# Generating Image Number: 15 for target class tensor([1]). Step 400, Loss: 1.974294662475586
# Generating Image Number: 15 for target class tensor([1]). Step 450, Loss: 1.8662893772125244
# Generating Image Number: 16 for target class tensor([1]). Step 0, Loss: 66.75973510742188
# Generating Image Number: 16 for target class tensor([1]). Step 50, Loss: 11.477094650268555
# Generating Image Number: 16 for target class tensor([1]). Step 100, Loss: 10.707390785217285
# Generating Image Number: 16 for target class tensor([1]). Step 150, Loss: 10.201634407043457
# Generating Image Number: 16 for target class tensor([1]). Step 200, Loss: 9.642410278320312
# Generating Image Number: 16 for target class tensor([1]). Step 250, Loss: 9.087385177612305
# Generating Image Number: 16 for target class tensor([1]). Step 300, Loss: 8.421490669250488
# Generating Image Number: 16 for target class tensor([1]). Step 350, Loss: 7.721899032592773
# Generating Image Number: 16 for target class tensor([1]). Step 400, Loss: 7.152801990509033
# Generating Image Number: 16 for target class tensor([1]). Step 450, Loss: 6.295383930206299
# Generating Image Number: 17 for target class tensor([1]). Step 0, Loss: 6.427404403686523
# Generating Image Number: 17 for target class tensor([1]). Step 50, Loss: 5.197246551513672
# Generating Image Number: 17 for target class tensor([1]). Step 100, Loss: 4.271266460418701
# Generating Image Number: 17 for target class tensor([1]). Step 150, Loss: 3.7529237270355225
# Generating Image Number: 17 for target class tensor([1]). Step 200, Loss: 3.3595285415649414
# Generating Image Number: 17 for target class tensor([1]). Step 250, Loss: 3.0981671810150146
# Generating Image Number: 17 for target class tensor([1]). Step 300, Loss: 2.9246714115142822
# Generating Image Number: 17 for target class tensor([1]). Step 350, Loss: 2.745948314666748
# Generating Image Number: 17 for target class tensor([1]). Step 400, Loss: 2.642981767654419
# Generating Image Number: 17 for target class tensor([1]). Step 450, Loss: 2.546725273132324
# Generating Image Number: 18 for target class tensor([1]). Step 0, Loss: 13.771781921386719
# Generating Image Number: 18 for target class tensor([1]). Step 50, Loss: 9.471155166625977
# Generating Image Number: 18 for target class tensor([1]). Step 100, Loss: 7.582542896270752
# Generating Image Number: 18 for target class tensor([1]). Step 150, Loss: 6.06447172164917
# Generating Image Number: 18 for target class tensor([1]). Step 200, Loss: 4.9102582931518555
# Generating Image Number: 18 for target class tensor([1]). Step 250, Loss: 3.9688563346862793
# Generating Image Number: 18 for target class tensor([1]). Step 300, Loss: 3.352457046508789
# Generating Image Number: 18 for target class tensor([1]). Step 350, Loss: 3.0357565879821777
# Generating Image Number: 18 for target class tensor([1]). Step 400, Loss: 2.829878568649292
# Generating Image Number: 18 for target class tensor([1]). Step 450, Loss: 2.662020444869995
# Generating Image Number: 19 for target class tensor([1]). Step 0, Loss: 9.090455055236816
# Generating Image Number: 19 for target class tensor([1]). Step 50, Loss: 6.817751407623291
# Generating Image Number: 19 for target class tensor([1]). Step 100, Loss: 6.35455846786499
# Generating Image Number: 19 for target class tensor([1]). Step 150, Loss: 6.028252124786377
# Generating Image Number: 19 for target class tensor([1]). Step 200, Loss: 5.862258434295654
# Generating Image Number: 19 for target class tensor([1]). Step 250, Loss: 5.61394739151001
# Generating Image Number: 19 for target class tensor([1]). Step 300, Loss: 5.381782531738281
# Generating Image Number: 19 for target class tensor([1]). Step 350, Loss: 5.59749698638916
# Generating Image Number: 19 for target class tensor([1]). Step 400, Loss: 4.866870880126953
# Generating Image Number: 19 for target class tensor([1]). Step 450, Loss: 4.578887939453125
# Generating Image Number: 20 for target class tensor([1]). Step 0, Loss: 9.27383041381836
# Generating Image Number: 20 for target class tensor([1]). Step 50, Loss: 5.967663288116455
# Generating Image Number: 20 for target class tensor([1]). Step 100, Loss: 5.323091506958008
# Generating Image Number: 20 for target class tensor([1]). Step 150, Loss: 4.878597259521484
# Generating Image Number: 20 for target class tensor([1]). Step 200, Loss: 4.529767036437988
# Generating Image Number: 20 for target class tensor([1]). Step 250, Loss: 4.290497779846191
# Generating Image Number: 20 for target class tensor([1]). Step 300, Loss: 3.9486052989959717
# Generating Image Number: 20 for target class tensor([1]). Step 350, Loss: 3.6374351978302
# Generating Image Number: 20 for target class tensor([1]). Step 400, Loss: 1.692237377166748
# Generating Image Number: 20 for target class tensor([1]). Step 450, Loss: 1.2821744680404663

# %%
torch.manual_seed(200)
latent_vectors = torch.randn(img_count, z_dim, 1, 1, requires_grad=True) # Start with 20 random noises
class2_optimized_latent_vectors = recover_images(img_count, 2, latent_vectors)
# Out:
# Generating Image Number: 1 for target class tensor([2]). Step 0, Loss: 6.261673450469971
# Generating Image Number: 1 for target class tensor([2]). Step 50, Loss: 0.5458775162696838
# Generating Image Number: 1 for target class tensor([2]). Step 100, Loss: 0.3101137578487396
# Generating Image Number: 1 for target class tensor([2]). Step 150, Loss: 0.1669897884130478
# Generating Image Number: 1 for target class tensor([2]). Step 200, Loss: 0.10558648407459259
# Generating Image Number: 1 for target class tensor([2]). Step 250, Loss: 0.07449471205472946
# Generating Image Number: 1 for target class tensor([2]). Step 300, Loss: 0.054061826318502426
# Generating Image Number: 1 for target class tensor([2]). Step 350, Loss: 0.041372839361429214
# Generating Image Number: 1 for target class tensor([2]). Step 400, Loss: 0.03241155669093132
# Generating Image Number: 1 for target class tensor([2]). Step 450, Loss: 0.025719238445162773
# Generating Image Number: 2 for target class tensor([2]). Step 0, Loss: 5.459306240081787
# Generating Image Number: 2 for target class tensor([2]). Step 50, Loss: 0.6277146339416504
# Generating Image Number: 2 for target class tensor([2]). Step 100, Loss: 0.33267679810523987
# Generating Image Number: 2 for target class tensor([2]). Step 150, Loss: 0.2427206188440323
# Generating Image Number: 2 for target class tensor([2]). Step 200, Loss: 0.19344845414161682
# Generating Image Number: 2 for target class tensor([2]). Step 250, Loss: 0.16711083054542542
# Generating Image Number: 2 for target class tensor([2]). Step 300, Loss: 0.14769089221954346
# Generating Image Number: 2 for target class tensor([2]). Step 350, Loss: 0.13394075632095337
# Generating Image Number: 2 for target class tensor([2]). Step 400, Loss: 0.12197306007146835
# Generating Image Number: 2 for target class tensor([2]). Step 450, Loss: 0.10815548151731491
# Generating Image Number: 3 for target class tensor([2]). Step 0, Loss: 2.2627336978912354
# Generating Image Number: 3 for target class tensor([2]). Step 50, Loss: 0.09481232613325119
# Generating Image Number: 3 for target class tensor([2]). Step 100, Loss: 0.05150802806019783
# Generating Image Number: 3 for target class tensor([2]). Step 150, Loss: 0.03714347630739212
# Generating Image Number: 3 for target class tensor([2]). Step 200, Loss: 0.028751760721206665
# Generating Image Number: 3 for target class tensor([2]). Step 250, Loss: 0.023490935564041138
# Generating Image Number: 3 for target class tensor([2]). Step 300, Loss: 0.01982387900352478
# Generating Image Number: 3 for target class tensor([2]). Step 350, Loss: 0.015583294443786144
# Generating Image Number: 3 for target class tensor([2]). Step 400, Loss: 0.013206038624048233
# Generating Image Number: 3 for target class tensor([2]). Step 450, Loss: 0.01173497922718525
# Generating Image Number: 4 for target class tensor([2]). Step 0, Loss: 5.751474380493164
# Generating Image Number: 4 for target class tensor([2]). Step 50, Loss: 2.984551429748535
# Generating Image Number: 4 for target class tensor([2]). Step 100, Loss: 2.752182722091675
# Generating Image Number: 4 for target class tensor([2]). Step 150, Loss: 2.569772720336914
# Generating Image Number: 4 for target class tensor([2]). Step 200, Loss: 2.4034504890441895
# Generating Image Number: 4 for target class tensor([2]). Step 250, Loss: 2.2258718013763428
# Generating Image Number: 4 for target class tensor([2]). Step 300, Loss: 2.0561130046844482
# Generating Image Number: 4 for target class tensor([2]). Step 350, Loss: 1.9495199918746948
# Generating Image Number: 4 for target class tensor([2]). Step 400, Loss: 1.8019015789031982
# Generating Image Number: 4 for target class tensor([2]). Step 450, Loss: 1.5053701400756836
# Generating Image Number: 5 for target class tensor([2]). Step 0, Loss: 6.630196571350098
# Generating Image Number: 5 for target class tensor([2]). Step 50, Loss: 1.443863868713379
# Generating Image Number: 5 for target class tensor([2]). Step 100, Loss: 0.567893385887146
# Generating Image Number: 5 for target class tensor([2]). Step 150, Loss: 0.34022825956344604
# Generating Image Number: 5 for target class tensor([2]). Step 200, Loss: 0.24092325568199158
# Generating Image Number: 5 for target class tensor([2]). Step 250, Loss: 0.17129607498645782
# Generating Image Number: 5 for target class tensor([2]). Step 300, Loss: 0.12955492734909058
# Generating Image Number: 5 for target class tensor([2]). Step 350, Loss: 0.10585235804319382
# Generating Image Number: 5 for target class tensor([2]). Step 400, Loss: 0.09074948728084564
# Generating Image Number: 5 for target class tensor([2]). Step 450, Loss: 0.0770607441663742
# Generating Image Number: 6 for target class tensor([2]). Step 0, Loss: 2.529541254043579
# Generating Image Number: 6 for target class tensor([2]). Step 50, Loss: 0.2916105091571808
# Generating Image Number: 6 for target class tensor([2]). Step 100, Loss: 0.14824813604354858
# Generating Image Number: 6 for target class tensor([2]). Step 150, Loss: 0.09117452800273895
# Generating Image Number: 6 for target class tensor([2]). Step 200, Loss: 0.06747429817914963
# Generating Image Number: 6 for target class tensor([2]). Step 250, Loss: 0.051604263484478
# Generating Image Number: 6 for target class tensor([2]). Step 300, Loss: 0.041588302701711655
# Generating Image Number: 6 for target class tensor([2]). Step 350, Loss: 0.03512042388319969
# Generating Image Number: 6 for target class tensor([2]). Step 400, Loss: 0.028641367331147194
# Generating Image Number: 6 for target class tensor([2]). Step 450, Loss: 0.024357816204428673
# Generating Image Number: 7 for target class tensor([2]). Step 0, Loss: 5.587636947631836
# Generating Image Number: 7 for target class tensor([2]). Step 50, Loss: 1.208785891532898
# Generating Image Number: 7 for target class tensor([2]). Step 100, Loss: 0.5675761699676514
# Generating Image Number: 7 for target class tensor([2]). Step 150, Loss: 0.2863377630710602
# Generating Image Number: 7 for target class tensor([2]). Step 200, Loss: 0.19434724748134613
# Generating Image Number: 7 for target class tensor([2]). Step 250, Loss: 0.14454464614391327
# Generating Image Number: 7 for target class tensor([2]). Step 300, Loss: 0.11199979484081268
# Generating Image Number: 7 for target class tensor([2]). Step 350, Loss: 0.09017124027013779
# Generating Image Number: 7 for target class tensor([2]). Step 400, Loss: 0.07659345120191574
# Generating Image Number: 7 for target class tensor([2]). Step 450, Loss: 0.06740186363458633
# Generating Image Number: 8 for target class tensor([2]). Step 0, Loss: 6.722355842590332
# Generating Image Number: 8 for target class tensor([2]). Step 50, Loss: 0.09790289402008057
# Generating Image Number: 8 for target class tensor([2]). Step 100, Loss: 0.04142773896455765
# Generating Image Number: 8 for target class tensor([2]). Step 150, Loss: 0.034909315407276154
# Generating Image Number: 8 for target class tensor([2]). Step 200, Loss: 0.029476134106516838
# Generating Image Number: 8 for target class tensor([2]). Step 250, Loss: 0.02444402128458023
# Generating Image Number: 8 for target class tensor([2]). Step 300, Loss: 0.02028166875243187
# Generating Image Number: 8 for target class tensor([2]). Step 350, Loss: 0.017058083787560463
# Generating Image Number: 8 for target class tensor([2]). Step 400, Loss: 0.014899755828082561
# Generating Image Number: 8 for target class tensor([2]). Step 450, Loss: 0.01350316684693098
# Generating Image Number: 9 for target class tensor([2]). Step 0, Loss: 2.4788684844970703
# Generating Image Number: 9 for target class tensor([2]). Step 50, Loss: 0.19452695548534393
# Generating Image Number: 9 for target class tensor([2]). Step 100, Loss: 0.11290445178747177
# Generating Image Number: 9 for target class tensor([2]). Step 150, Loss: 0.079490527510643
# Generating Image Number: 9 for target class tensor([2]). Step 200, Loss: 0.06096777319908142
# Generating Image Number: 9 for target class tensor([2]). Step 250, Loss: 0.04829147085547447
# Generating Image Number: 9 for target class tensor([2]). Step 300, Loss: 0.040600258857011795
# Generating Image Number: 9 for target class tensor([2]). Step 350, Loss: 0.03335491567850113
# Generating Image Number: 9 for target class tensor([2]). Step 400, Loss: 0.028366781771183014
# Generating Image Number: 9 for target class tensor([2]). Step 450, Loss: 0.024648509919643402
# Generating Image Number: 10 for target class tensor([2]). Step 0, Loss: 5.390788555145264
# Generating Image Number: 10 for target class tensor([2]). Step 50, Loss: 0.15583936870098114
# Generating Image Number: 10 for target class tensor([2]). Step 100, Loss: 0.08133267611265182
# Generating Image Number: 10 for target class tensor([2]). Step 150, Loss: 0.06272678077220917
# Generating Image Number: 10 for target class tensor([2]). Step 200, Loss: 0.0515434667468071
# Generating Image Number: 10 for target class tensor([2]). Step 250, Loss: 0.04300527647137642
# Generating Image Number: 10 for target class tensor([2]). Step 300, Loss: 0.03637417405843735
# Generating Image Number: 10 for target class tensor([2]). Step 350, Loss: 0.0317581370472908
# Generating Image Number: 10 for target class tensor([2]). Step 400, Loss: 0.02861599810421467
# Generating Image Number: 10 for target class tensor([2]). Step 450, Loss: 0.02590801753103733
# Generating Image Number: 11 for target class tensor([2]). Step 0, Loss: 3.8424041271209717
# Generating Image Number: 11 for target class tensor([2]). Step 50, Loss: 3.0326428413391113
# Generating Image Number: 11 for target class tensor([2]). Step 100, Loss: 2.7652227878570557
# Generating Image Number: 11 for target class tensor([2]). Step 150, Loss: 2.6015355587005615
# Generating Image Number: 11 for target class tensor([2]). Step 200, Loss: 2.494715452194214
# Generating Image Number: 11 for target class tensor([2]). Step 250, Loss: 2.361910820007324
# Generating Image Number: 11 for target class tensor([2]). Step 300, Loss: 2.2129743099212646
# Generating Image Number: 11 for target class tensor([2]). Step 350, Loss: 2.0957751274108887
# Generating Image Number: 11 for target class tensor([2]). Step 400, Loss: 1.992520809173584
# Generating Image Number: 11 for target class tensor([2]). Step 450, Loss: 1.8562898635864258
# Generating Image Number: 12 for target class tensor([2]). Step 0, Loss: 69.60516357421875
# Generating Image Number: 12 for target class tensor([2]). Step 50, Loss: 48.988739013671875
# Generating Image Number: 12 for target class tensor([2]). Step 100, Loss: 0.905448853969574
# Generating Image Number: 12 for target class tensor([2]). Step 150, Loss: 0.9460036754608154
# Generating Image Number: 12 for target class tensor([2]). Step 200, Loss: 0.8971530795097351
# Generating Image Number: 12 for target class tensor([2]). Step 250, Loss: 0.842731773853302
# Generating Image Number: 12 for target class tensor([2]). Step 300, Loss: 0.7848644852638245
# Generating Image Number: 12 for target class tensor([2]). Step 350, Loss: 0.7124857306480408
# Generating Image Number: 12 for target class tensor([2]). Step 400, Loss: 0.6513833999633789
# Generating Image Number: 12 for target class tensor([2]). Step 450, Loss: 0.6024569272994995
# Generating Image Number: 13 for target class tensor([2]). Step 0, Loss: 9.789824485778809
# Generating Image Number: 13 for target class tensor([2]). Step 50, Loss: 1.0302577018737793
# Generating Image Number: 13 for target class tensor([2]). Step 100, Loss: 0.33620116114616394
# Generating Image Number: 13 for target class tensor([2]). Step 150, Loss: 0.1767728328704834
# Generating Image Number: 13 for target class tensor([2]). Step 200, Loss: 0.12083204835653305
# Generating Image Number: 13 for target class tensor([2]). Step 250, Loss: 0.09301593899726868
# Generating Image Number: 13 for target class tensor([2]). Step 300, Loss: 0.07560084015130997
# Generating Image Number: 13 for target class tensor([2]). Step 350, Loss: 0.06511139869689941
# Generating Image Number: 13 for target class tensor([2]). Step 400, Loss: 0.057831618934869766
# Generating Image Number: 13 for target class tensor([2]). Step 450, Loss: 0.050339434295892715
# Generating Image Number: 14 for target class tensor([2]). Step 0, Loss: 5.107755661010742
# Generating Image Number: 14 for target class tensor([2]). Step 50, Loss: 0.011622220277786255
# Generating Image Number: 14 for target class tensor([2]). Step 100, Loss: 0.0053903949446976185
# Generating Image Number: 14 for target class tensor([2]). Step 150, Loss: 0.004981843288987875
# Generating Image Number: 14 for target class tensor([2]). Step 200, Loss: 0.004588313400745392
# Generating Image Number: 14 for target class tensor([2]). Step 250, Loss: 0.004244011361151934
# Generating Image Number: 14 for target class tensor([2]). Step 300, Loss: 0.003980808891355991
# Generating Image Number: 14 for target class tensor([2]). Step 350, Loss: 0.003718368476256728
# Generating Image Number: 14 for target class tensor([2]). Step 400, Loss: 0.0035129995085299015
# Generating Image Number: 14 for target class tensor([2]). Step 450, Loss: 0.0032835875172168016
# Generating Image Number: 15 for target class tensor([2]). Step 0, Loss: 3.4220023155212402
# Generating Image Number: 15 for target class tensor([2]). Step 50, Loss: 0.002501931507140398
# Generating Image Number: 15 for target class tensor([2]). Step 100, Loss: 0.002248261356726289
# Generating Image Number: 15 for target class tensor([2]). Step 150, Loss: 0.002058174693956971
# Generating Image Number: 15 for target class tensor([2]). Step 200, Loss: 0.0019175490597262979
# Generating Image Number: 15 for target class tensor([2]). Step 250, Loss: 0.0017538178944960237
# Generating Image Number: 15 for target class tensor([2]). Step 300, Loss: 0.001622075797058642
# Generating Image Number: 15 for target class tensor([2]). Step 350, Loss: 0.0014994817320257425
# Generating Image Number: 15 for target class tensor([2]). Step 400, Loss: 0.0013994909822940826
# Generating Image Number: 15 for target class tensor([2]). Step 450, Loss: 0.0012897277483716607
# Generating Image Number: 16 for target class tensor([2]). Step 0, Loss: 3.86283802986145
# Generating Image Number: 16 for target class tensor([2]). Step 50, Loss: 0.06699502468109131
# Generating Image Number: 16 for target class tensor([2]). Step 100, Loss: 0.0014587724581360817
# Generating Image Number: 16 for target class tensor([2]). Step 150, Loss: 0.0013649680186063051
# Generating Image Number: 16 for target class tensor([2]). Step 200, Loss: 0.0013516347389668226
# Generating Image Number: 16 for target class tensor([2]). Step 250, Loss: 0.0013169910525903106
# Generating Image Number: 16 for target class tensor([2]). Step 300, Loss: 0.0013067525578662753
# Generating Image Number: 16 for target class tensor([2]). Step 350, Loss: 0.0012860370334237814
# Generating Image Number: 16 for target class tensor([2]). Step 400, Loss: 0.001261153956875205
# Generating Image Number: 16 for target class tensor([2]). Step 450, Loss: 0.0012269833823665977
# Generating Image Number: 17 for target class tensor([2]). Step 0, Loss: 0.48356425762176514
# Generating Image Number: 17 for target class tensor([2]). Step 50, Loss: 0.04344071075320244
# Generating Image Number: 17 for target class tensor([2]). Step 100, Loss: 0.02736419066786766
# Generating Image Number: 17 for target class tensor([2]). Step 150, Loss: 0.017434202134609222
# Generating Image Number: 17 for target class tensor([2]). Step 200, Loss: 0.011652620509266853
# Generating Image Number: 17 for target class tensor([2]). Step 250, Loss: 0.008656831458210945
# Generating Image Number: 17 for target class tensor([2]). Step 300, Loss: 0.006457889452576637
# Generating Image Number: 17 for target class tensor([2]). Step 350, Loss: 0.005270989146083593
# Generating Image Number: 17 for target class tensor([2]). Step 400, Loss: 0.00451604463160038
# Generating Image Number: 17 for target class tensor([2]). Step 450, Loss: 0.003975940868258476
# Generating Image Number: 18 for target class tensor([2]). Step 0, Loss: 64.85803985595703
# Generating Image Number: 18 for target class tensor([2]). Step 50, Loss: 58.65972137451172
# Generating Image Number: 18 for target class tensor([2]). Step 100, Loss: 56.32364273071289
# Generating Image Number: 18 for target class tensor([2]). Step 150, Loss: 54.131988525390625
# Generating Image Number: 18 for target class tensor([2]). Step 200, Loss: 0.060066286474466324
# Generating Image Number: 18 for target class tensor([2]). Step 250, Loss: 0.25181636214256287
# Generating Image Number: 18 for target class tensor([2]). Step 300, Loss: 0.1411585956811905
# Generating Image Number: 18 for target class tensor([2]). Step 350, Loss: 0.1305045336484909
# Generating Image Number: 18 for target class tensor([2]). Step 400, Loss: 0.1227644681930542
# Generating Image Number: 18 for target class tensor([2]). Step 450, Loss: 0.11713454127311707
# Generating Image Number: 19 for target class tensor([2]). Step 0, Loss: 0.4528157114982605
# Generating Image Number: 19 for target class tensor([2]). Step 50, Loss: 0.011229291558265686
# Generating Image Number: 19 for target class tensor([2]). Step 100, Loss: 0.007800119463354349
# Generating Image Number: 19 for target class tensor([2]). Step 150, Loss: 0.006138992961496115
# Generating Image Number: 19 for target class tensor([2]). Step 200, Loss: 0.004821223206818104
# Generating Image Number: 19 for target class tensor([2]). Step 250, Loss: 0.0038585036527365446
# Generating Image Number: 19 for target class tensor([2]). Step 300, Loss: 0.003304855665192008
# Generating Image Number: 19 for target class tensor([2]). Step 350, Loss: 0.0029403807129710913
# Generating Image Number: 19 for target class tensor([2]). Step 400, Loss: 0.0025718489196151495
# Generating Image Number: 19 for target class tensor([2]). Step 450, Loss: 0.002303329762071371
# Generating Image Number: 20 for target class tensor([2]). Step 0, Loss: 2.2951040267944336
# Generating Image Number: 20 for target class tensor([2]). Step 50, Loss: 0.035116277635097504
# Generating Image Number: 20 for target class tensor([2]). Step 100, Loss: 0.025187911465764046
# Generating Image Number: 20 for target class tensor([2]). Step 150, Loss: 0.019142765551805496
# Generating Image Number: 20 for target class tensor([2]). Step 200, Loss: 0.015029055997729301
# Generating Image Number: 20 for target class tensor([2]). Step 250, Loss: 0.012503095902502537
# Generating Image Number: 20 for target class tensor([2]). Step 300, Loss: 0.010576269589364529
# Generating Image Number: 20 for target class tensor([2]). Step 350, Loss: 0.009265164844691753
# Generating Image Number: 20 for target class tensor([2]). Step 400, Loss: 0.008292765356600285
# Generating Image Number: 20 for target class tensor([2]). Step 450, Loss: 0.007386161480098963

# %%
torch.manual_seed(300)
latent_vectors = torch.randn(img_count, z_dim, 1, 1, requires_grad=True) # Start with 20 random noises
class3_optimized_latent_vectors = recover_images(img_count, 3, latent_vectors)
# Out:
# Generating Image Number: 1 for target class tensor([3]). Step 0, Loss: 0.00011717586312443018
# Generating Image Number: 1 for target class tensor([3]). Step 50, Loss: 1.6689286894688848e-06
# Generating Image Number: 1 for target class tensor([3]). Step 100, Loss: 1.5497195136049413e-06
# Generating Image Number: 1 for target class tensor([3]). Step 150, Loss: 1.311301275563892e-06
# Generating Image Number: 1 for target class tensor([3]). Step 200, Loss: 1.1920922133867862e-06
# Generating Image Number: 1 for target class tensor([3]). Step 250, Loss: 1.0728830375228426e-06
# Generating Image Number: 1 for target class tensor([3]). Step 300, Loss: 9.536738616588991e-07
# Generating Image Number: 1 for target class tensor([3]). Step 350, Loss: 7.152555099310121e-07
# Generating Image Number: 1 for target class tensor([3]). Step 400, Loss: 7.152555099310121e-07
# Generating Image Number: 1 for target class tensor([3]). Step 450, Loss: 5.960462772236497e-07
# Generating Image Number: 2 for target class tensor([3]). Step 0, Loss: 0.24034635722637177
# Generating Image Number: 2 for target class tensor([3]). Step 50, Loss: 0.05604425072669983
# Generating Image Number: 2 for target class tensor([3]). Step 100, Loss: 0.0008743754005990922
# Generating Image Number: 2 for target class tensor([3]). Step 150, Loss: 0.00036149643710814416
# Generating Image Number: 2 for target class tensor([3]). Step 200, Loss: 0.0002787916746456176
# Generating Image Number: 2 for target class tensor([3]). Step 250, Loss: 0.00026258357684127986
# Generating Image Number: 2 for target class tensor([3]). Step 300, Loss: 0.00025328766787424684
# Generating Image Number: 2 for target class tensor([3]). Step 350, Loss: 0.00024863966973498464
# Generating Image Number: 2 for target class tensor([3]). Step 400, Loss: 0.0002431573811918497
# Generating Image Number: 2 for target class tensor([3]). Step 450, Loss: 0.00022825974156148732
# Generating Image Number: 3 for target class tensor([3]). Step 0, Loss: 0.9704069495201111
# Generating Image Number: 3 for target class tensor([3]). Step 50, Loss: 0.015317894518375397
# Generating Image Number: 3 for target class tensor([3]). Step 100, Loss: 0.010554329492151737
# Generating Image Number: 3 for target class tensor([3]). Step 150, Loss: 0.007585176266729832
# Generating Image Number: 3 for target class tensor([3]). Step 200, Loss: 0.006147878710180521
# Generating Image Number: 3 for target class tensor([3]). Step 250, Loss: 0.005217862781137228
# Generating Image Number: 3 for target class tensor([3]). Step 300, Loss: 0.004508568439632654
# Generating Image Number: 3 for target class tensor([3]). Step 350, Loss: 0.003937944304198027
# Generating Image Number: 3 for target class tensor([3]). Step 400, Loss: 0.0035254727117717266
# Generating Image Number: 3 for target class tensor([3]). Step 450, Loss: 0.0031386183109134436
# Generating Image Number: 4 for target class tensor([3]). Step 0, Loss: 0.06605967879295349
# Generating Image Number: 4 for target class tensor([3]). Step 50, Loss: 0.020289260894060135
# Generating Image Number: 4 for target class tensor([3]). Step 100, Loss: 0.013968207873404026
# Generating Image Number: 4 for target class tensor([3]). Step 150, Loss: 0.010783141478896141
# Generating Image Number: 4 for target class tensor([3]). Step 200, Loss: 0.009014857932925224
# Generating Image Number: 4 for target class tensor([3]). Step 250, Loss: 0.007678398862481117
# Generating Image Number: 4 for target class tensor([3]). Step 300, Loss: 0.006927993148565292
# Generating Image Number: 4 for target class tensor([3]). Step 350, Loss: 0.006347613874822855
# Generating Image Number: 4 for target class tensor([3]). Step 400, Loss: 0.005640424322336912
# Generating Image Number: 4 for target class tensor([3]). Step 450, Loss: 0.004916127305477858
# Generating Image Number: 5 for target class tensor([3]). Step 0, Loss: 0.00016819016309455037
# Generating Image Number: 5 for target class tensor([3]). Step 50, Loss: 2.682172998902388e-05
# Generating Image Number: 5 for target class tensor([3]). Step 100, Loss: 1.5139465176616795e-05
# Generating Image Number: 5 for target class tensor([3]). Step 150, Loss: 1.1324817933200393e-05
# Generating Image Number: 5 for target class tensor([3]). Step 200, Loss: 8.940656698541716e-06
# Generating Image Number: 5 for target class tensor([3]). Step 250, Loss: 7.510157047363464e-06
# Generating Image Number: 5 for target class tensor([3]). Step 300, Loss: 6.437280717364047e-06
# Generating Image Number: 5 for target class tensor([3]). Step 350, Loss: 5.602820692729438e-06
# Generating Image Number: 5 for target class tensor([3]). Step 400, Loss: 4.887569048150908e-06
# Generating Image Number: 5 for target class tensor([3]). Step 450, Loss: 4.291525328881107e-06
# Generating Image Number: 6 for target class tensor([3]). Step 0, Loss: 0.023343859240412712
# Generating Image Number: 6 for target class tensor([3]). Step 50, Loss: 2.5033637939486653e-05
# Generating Image Number: 6 for target class tensor([3]). Step 100, Loss: 2.1219027985353023e-05
# Generating Image Number: 6 for target class tensor([3]). Step 150, Loss: 1.966933996300213e-05
# Generating Image Number: 6 for target class tensor([3]). Step 200, Loss: 1.883488948806189e-05
# Generating Image Number: 6 for target class tensor([3]). Step 250, Loss: 1.764281842042692e-05
# Generating Image Number: 6 for target class tensor([3]). Step 300, Loss: 1.680836794548668e-05
# Generating Image Number: 6 for target class tensor([3]). Step 350, Loss: 1.6093124941107817e-05
# Generating Image Number: 6 for target class tensor([3]). Step 400, Loss: 1.5139465176616795e-05
# Generating Image Number: 6 for target class tensor([3]). Step 450, Loss: 1.4185804502631072e-05
# Generating Image Number: 7 for target class tensor([3]). Step 0, Loss: 0.0008017186191864312
# Generating Image Number: 7 for target class tensor([3]). Step 50, Loss: 1.597391747054644e-05
# Generating Image Number: 7 for target class tensor([3]). Step 100, Loss: 6.198863957251888e-06
# Generating Image Number: 7 for target class tensor([3]). Step 150, Loss: 4.0531076592742465e-06
# Generating Image Number: 7 for target class tensor([3]). Step 200, Loss: 2.861018856492592e-06
# Generating Image Number: 7 for target class tensor([3]). Step 250, Loss: 2.264974000354414e-06
# Generating Image Number: 7 for target class tensor([3]). Step 300, Loss: 1.7881377516459906e-06
# Generating Image Number: 7 for target class tensor([3]). Step 350, Loss: 1.5497195136049413e-06
# Generating Image Number: 7 for target class tensor([3]). Step 400, Loss: 1.311301275563892e-06
# Generating Image Number: 7 for target class tensor([3]). Step 450, Loss: 1.1920922133867862e-06
# Generating Image Number: 8 for target class tensor([3]). Step 0, Loss: 0.15582610666751862
# Generating Image Number: 8 for target class tensor([3]). Step 50, Loss: 0.00042632073746062815
# Generating Image Number: 8 for target class tensor([3]). Step 100, Loss: 0.0002824861148837954
# Generating Image Number: 8 for target class tensor([3]). Step 150, Loss: 0.0002734287118073553
# Generating Image Number: 8 for target class tensor([3]). Step 200, Loss: 0.00026675479602999985
# Generating Image Number: 8 for target class tensor([3]). Step 250, Loss: 0.000259723310591653
# Generating Image Number: 8 for target class tensor([3]). Step 300, Loss: 0.0002536452084314078
# Generating Image Number: 8 for target class tensor([3]). Step 350, Loss: 0.00024732868769206107
# Generating Image Number: 8 for target class tensor([3]). Step 400, Loss: 0.00023993951617740095
# Generating Image Number: 8 for target class tensor([3]). Step 450, Loss: 0.00023278864682652056
# Generating Image Number: 9 for target class tensor([3]). Step 0, Loss: 0.07429065555334091
# Generating Image Number: 9 for target class tensor([3]). Step 50, Loss: 0.03492462635040283
# Generating Image Number: 9 for target class tensor([3]). Step 100, Loss: 0.026854626834392548
# Generating Image Number: 9 for target class tensor([3]). Step 150, Loss: 0.023160653188824654
# Generating Image Number: 9 for target class tensor([3]). Step 200, Loss: 0.019975798204541206
# Generating Image Number: 9 for target class tensor([3]). Step 250, Loss: 0.017336612567305565
# Generating Image Number: 9 for target class tensor([3]). Step 300, Loss: 0.01529394555836916
# Generating Image Number: 9 for target class tensor([3]). Step 350, Loss: 0.013845707289874554
# Generating Image Number: 9 for target class tensor([3]). Step 400, Loss: 0.013119683600962162
# Generating Image Number: 9 for target class tensor([3]). Step 450, Loss: 0.012306000106036663
# Generating Image Number: 10 for target class tensor([3]). Step 0, Loss: 0.07061716914176941
# Generating Image Number: 10 for target class tensor([3]). Step 50, Loss: 0.00023636408150196075
# Generating Image Number: 10 for target class tensor([3]). Step 100, Loss: 0.00018320789968129247
# Generating Image Number: 10 for target class tensor([3]). Step 150, Loss: 0.00017438798386137933
# Generating Image Number: 10 for target class tensor([3]). Step 200, Loss: 0.00016735584358684719
# Generating Image Number: 10 for target class tensor([3]). Step 250, Loss: 0.00015579440514557064
# Generating Image Number: 10 for target class tensor([3]). Step 300, Loss: 0.0001463782973587513
# Generating Image Number: 10 for target class tensor([3]). Step 350, Loss: 0.00014006110723130405
# Generating Image Number: 10 for target class tensor([3]). Step 400, Loss: 0.00013445904187392443
# Generating Image Number: 10 for target class tensor([3]). Step 450, Loss: 0.0001287377526750788
# Generating Image Number: 11 for target class tensor([3]). Step 0, Loss: 0.17907492816448212
# Generating Image Number: 11 for target class tensor([3]). Step 50, Loss: 0.049468133598566055
# Generating Image Number: 11 for target class tensor([3]). Step 100, Loss: 0.037761133164167404
# Generating Image Number: 11 for target class tensor([3]). Step 150, Loss: 0.032244663685560226
# Generating Image Number: 11 for target class tensor([3]). Step 200, Loss: 0.02858506701886654
# Generating Image Number: 11 for target class tensor([3]). Step 250, Loss: 0.025653477758169174
# Generating Image Number: 11 for target class tensor([3]). Step 300, Loss: 0.023096119984984398
# Generating Image Number: 11 for target class tensor([3]). Step 350, Loss: 0.021290799602866173
# Generating Image Number: 11 for target class tensor([3]). Step 400, Loss: 0.019943546503782272
# Generating Image Number: 11 for target class tensor([3]). Step 450, Loss: 0.018968848511576653
# Generating Image Number: 12 for target class tensor([3]). Step 0, Loss: 3.9218897819519043
# Generating Image Number: 12 for target class tensor([3]). Step 50, Loss: 0.0755484476685524
# Generating Image Number: 12 for target class tensor([3]). Step 100, Loss: 0.03700953722000122
# Generating Image Number: 12 for target class tensor([3]). Step 150, Loss: 0.02861877903342247
# Generating Image Number: 12 for target class tensor([3]). Step 200, Loss: 0.023341530933976173
# Generating Image Number: 12 for target class tensor([3]). Step 250, Loss: 0.019228018820285797
# Generating Image Number: 12 for target class tensor([3]). Step 300, Loss: 0.01622730866074562
# Generating Image Number: 12 for target class tensor([3]). Step 350, Loss: 0.014009234495460987
# Generating Image Number: 12 for target class tensor([3]). Step 400, Loss: 0.011591936461627483
# Generating Image Number: 12 for target class tensor([3]). Step 450, Loss: 0.010150832124054432
# Generating Image Number: 13 for target class tensor([3]). Step 0, Loss: 0.15397129952907562
# Generating Image Number: 13 for target class tensor([3]). Step 50, Loss: 0.00010156115604331717
# Generating Image Number: 13 for target class tensor([3]). Step 100, Loss: 8.964136941358447e-05
# Generating Image Number: 13 for target class tensor([3]). Step 150, Loss: 8.070142939686775e-05
# Generating Image Number: 13 for target class tensor([3]). Step 200, Loss: 7.772143726469949e-05
# Generating Image Number: 13 for target class tensor([3]). Step 250, Loss: 7.70062324590981e-05
# Generating Image Number: 13 for target class tensor([3]). Step 300, Loss: 7.593343616463244e-05
# Generating Image Number: 13 for target class tensor([3]). Step 350, Loss: 7.533743337262422e-05
# Generating Image Number: 13 for target class tensor([3]). Step 400, Loss: 7.402622577501461e-05
# Generating Image Number: 13 for target class tensor([3]). Step 450, Loss: 7.295342220459133e-05
# Generating Image Number: 14 for target class tensor([3]). Step 0, Loss: 0.16584327816963196
# Generating Image Number: 14 for target class tensor([3]). Step 50, Loss: 0.059747304767370224
# Generating Image Number: 14 for target class tensor([3]). Step 100, Loss: 0.03641900420188904
# Generating Image Number: 14 for target class tensor([3]). Step 150, Loss: 0.02609141916036606
# Generating Image Number: 14 for target class tensor([3]). Step 200, Loss: 0.019886987283825874
# Generating Image Number: 14 for target class tensor([3]). Step 250, Loss: 0.01529007125645876
# Generating Image Number: 14 for target class tensor([3]). Step 300, Loss: 0.012677672319114208
# Generating Image Number: 14 for target class tensor([3]). Step 350, Loss: 0.01088950876146555
# Generating Image Number: 14 for target class tensor([3]). Step 400, Loss: 0.009478329680860043
# Generating Image Number: 14 for target class tensor([3]). Step 450, Loss: 0.008483798243105412
# Generating Image Number: 15 for target class tensor([3]). Step 0, Loss: 0.0012401993153616786
# Generating Image Number: 15 for target class tensor([3]). Step 50, Loss: 0.00028224775451235473
# Generating Image Number: 15 for target class tensor([3]). Step 100, Loss: 0.00017426878912374377
# Generating Image Number: 15 for target class tensor([3]). Step 150, Loss: 0.0001232548092957586
# Generating Image Number: 15 for target class tensor([3]). Step 200, Loss: 0.00010001159535022452
# Generating Image Number: 15 for target class tensor([3]). Step 250, Loss: 8.49926145747304e-05
# Generating Image Number: 15 for target class tensor([3]). Step 300, Loss: 7.354942499659956e-05
# Generating Image Number: 15 for target class tensor([3]). Step 350, Loss: 6.48477507638745e-05
# Generating Image Number: 15 for target class tensor([3]). Step 400, Loss: 5.757642793469131e-05
# Generating Image Number: 15 for target class tensor([3]). Step 450, Loss: 4.494089080253616e-05
# Generating Image Number: 16 for target class tensor([3]). Step 0, Loss: 4.160147190093994
# Generating Image Number: 16 for target class tensor([3]). Step 50, Loss: 0.7538390159606934
# Generating Image Number: 16 for target class tensor([3]). Step 100, Loss: 0.3548094630241394
# Generating Image Number: 16 for target class tensor([3]). Step 150, Loss: 0.2755486071109772
# Generating Image Number: 16 for target class tensor([3]). Step 200, Loss: 0.2084634155035019
# Generating Image Number: 16 for target class tensor([3]). Step 250, Loss: 0.18006151914596558
# Generating Image Number: 16 for target class tensor([3]). Step 300, Loss: 0.14728447794914246
# Generating Image Number: 16 for target class tensor([3]). Step 350, Loss: 0.09033995866775513
# Generating Image Number: 16 for target class tensor([3]). Step 400, Loss: 0.06063640117645264
# Generating Image Number: 16 for target class tensor([3]). Step 450, Loss: 0.051143039017915726
# Generating Image Number: 17 for target class tensor([3]). Step 0, Loss: 0.09377284348011017
# Generating Image Number: 17 for target class tensor([3]). Step 50, Loss: 0.0015862513100728393
# Generating Image Number: 17 for target class tensor([3]). Step 100, Loss: 0.0010807631770148873
# Generating Image Number: 17 for target class tensor([3]). Step 150, Loss: 0.0009419057168997824
# Generating Image Number: 17 for target class tensor([3]). Step 200, Loss: 0.0008295908919535577
# Generating Image Number: 17 for target class tensor([3]). Step 250, Loss: 0.0007340597221627831
# Generating Image Number: 17 for target class tensor([3]). Step 300, Loss: 0.0006173135479912162
# Generating Image Number: 17 for target class tensor([3]). Step 350, Loss: 0.0005465444410219789
# Generating Image Number: 17 for target class tensor([3]). Step 400, Loss: 0.0004998388467356563
# Generating Image Number: 17 for target class tensor([3]). Step 450, Loss: 0.0004542034293990582
# Generating Image Number: 18 for target class tensor([3]). Step 0, Loss: 1.417107105255127
# Generating Image Number: 18 for target class tensor([3]). Step 50, Loss: 0.197652205824852
# Generating Image Number: 18 for target class tensor([3]). Step 100, Loss: 0.11795775592327118
# Generating Image Number: 18 for target class tensor([3]). Step 150, Loss: 0.08375418931245804
# Generating Image Number: 18 for target class tensor([3]). Step 200, Loss: 0.06490720063447952
# Generating Image Number: 18 for target class tensor([3]). Step 250, Loss: 0.05113023892045021
# Generating Image Number: 18 for target class tensor([3]). Step 300, Loss: 0.04133211821317673
# Generating Image Number: 18 for target class tensor([3]). Step 350, Loss: 0.03417907655239105
# Generating Image Number: 18 for target class tensor([3]). Step 400, Loss: 0.030102822929620743
# Generating Image Number: 18 for target class tensor([3]). Step 450, Loss: 0.02691090852022171
# Generating Image Number: 19 for target class tensor([3]). Step 0, Loss: 1.8908522129058838
# Generating Image Number: 19 for target class tensor([3]). Step 50, Loss: 0.2530674934387207
# Generating Image Number: 19 for target class tensor([3]). Step 100, Loss: 0.1180926114320755
# Generating Image Number: 19 for target class tensor([3]). Step 150, Loss: 0.07384087890386581
# Generating Image Number: 19 for target class tensor([3]). Step 200, Loss: 0.05701851099729538
# Generating Image Number: 19 for target class tensor([3]). Step 250, Loss: 0.04463346302509308
# Generating Image Number: 19 for target class tensor([3]). Step 300, Loss: 0.03707639500498772
# Generating Image Number: 19 for target class tensor([3]). Step 350, Loss: 0.030480889603495598
# Generating Image Number: 19 for target class tensor([3]). Step 400, Loss: 0.026437336578965187
# Generating Image Number: 19 for target class tensor([3]). Step 450, Loss: 0.02334246225655079
# Generating Image Number: 20 for target class tensor([3]). Step 0, Loss: 1.8476067781448364
# Generating Image Number: 20 for target class tensor([3]). Step 50, Loss: 0.0005759726045653224
# Generating Image Number: 20 for target class tensor([3]). Step 100, Loss: 0.0004493180604185909
# Generating Image Number: 20 for target class tensor([3]). Step 150, Loss: 0.0003923600015696138
# Generating Image Number: 20 for target class tensor([3]). Step 200, Loss: 0.0003721021639648825
# Generating Image Number: 20 for target class tensor([3]). Step 250, Loss: 0.00035553809721022844
# Generating Image Number: 20 for target class tensor([3]). Step 300, Loss: 0.00033706706017255783
# Generating Image Number: 20 for target class tensor([3]). Step 350, Loss: 0.00032228996860794723
# Generating Image Number: 20 for target class tensor([3]). Step 400, Loss: 0.00030727434204891324
# Generating Image Number: 20 for target class tensor([3]). Step 450, Loss: 0.00029273517429828644

# %%
# Send the images through the model and get the probabilities
def get_probability(latent_vector, target_class):
    img = gen(latent_vector.to(device))

    img = img.repeat(1, 3, 1, 1) # Increase the color channels from 1 to 3 by repeating the color channel
    img = functional.interpolate(img, size=(32, 32), mode='nearest') # Change the image shape from 64x64(DCGAN output) to 32x32(Model input)

    hs, logits = target_model(img)
    probs = functional.softmax(logits, dim=1)

    return probs[:, target_class]
    
def get_class_probabilities(optimized_latent_vectors, target_class):
    probs = []
    for lv in optimized_latent_vectors:
        probs.append(get_probability(lv, target_class))

    return probs

# %%
def get_confidence_accuracy(probs_list, prob_threshold):
    size = len(probs_list)
    counter = 0
    for prob in probs_list:
        p = prob.item()
        if p > prob_threshold:
            counter += 1

    return ((counter/size)*100.0)

# %%
probability_confidence_threshold = 0.6

# %%
probs_class0 = get_class_probabilities(class0_optimized_latent_vectors, 0)
len(probs_class0)
for prob in probs_class0:
    print(prob)
    
print('Confidence percentage:', get_confidence_accuracy(probs_class0, probability_confidence_threshold))
# Out:
# tensor([1.], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.1514], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9571], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.7600], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.6091], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9229], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9501], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9599], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.0058], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.8568], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([1.], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([1.], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.7513], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9857], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([1.], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.2079], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.2525], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9612], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9207], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.1923], device='cuda:0', grad_fn=<SelectBackward0>)
# Confidence percentage: 75.0

# %%
probs_class1 = get_class_probabilities(class1_optimized_latent_vectors, 1)
len(probs_class1)
for prob in probs_class1:
    print(prob)

print('Confidence percentage:', get_confidence_accuracy(probs_class1, probability_confidence_threshold))
# Out:
# tensor([0.0308], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.0191], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.1260], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.0015], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.1470], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.1791], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.8060], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.0550], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([2.7953e-05], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.7737], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.1865], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([1.4634e-05], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.0238], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.1605], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.1668], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.0041], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.0838], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.0804], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.0130], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.3665], device='cuda:0', grad_fn=<SelectBackward0>)
# Confidence percentage: 10.0

# %%
probs_class2 = get_class_probabilities(class2_optimized_latent_vectors, 2)
len(probs_class2)
for prob in probs_class2:
    print(prob)
    
print('Confidence percentage:', get_confidence_accuracy(probs_class2, probability_confidence_threshold))
# Out:
# tensor([0.9788], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9063], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9895], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.6613], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9356], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9784], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9421], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9881], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9787], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9767], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.1660], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.5751], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9556], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9969], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9988], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9988], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9964], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.8939], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9979], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9933], device='cuda:0', grad_fn=<SelectBackward0>)
# Confidence percentage: 90.0

# %%
probs_class3 = get_class_probabilities(class3_optimized_latent_vectors, 3)
len(probs_class3)
for prob in probs_class3:
    print(prob)

print('Confidence percentage:', get_confidence_accuracy(probs_class3, probability_confidence_threshold))
# Out:
# tensor([1.0000], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9998], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9972], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9956], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([1.0000], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([1.0000], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([1.0000], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9998], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9883], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9999], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9821], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9910], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9999], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9924], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([1.0000], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9570], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9996], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9759], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9792], device='cuda:0', grad_fn=<SelectBackward0>)
# tensor([0.9997], device='cuda:0', grad_fn=<SelectBackward0>)
# Confidence percentage: 100.0

# %%
z0_1 = class0_optimized_latent_vectors[0]
z0_2 = class0_optimized_latent_vectors[1]
z0_3 = class0_optimized_latent_vectors[2]

# %%
# Display the generated image
img = gen(z0_1.to(device)).squeeze(dim=0).squeeze(dim=0)
print(img.shape)
# Out:
# torch.Size([64, 64])

# %%
plt.axis(False)
plt.title('Recovered Image:')
plt.imshow(img.cpu().detach(), cmap='gray')

# %%
z1 = class1_optimized_latent_vectors[0]
z2 = class1_optimized_latent_vectors[1]
z3 = class1_optimized_latent_vectors[2]

# %%
# Display the generated image
img = gen(z1.to(device)).squeeze(dim=0).squeeze(dim=0)
print(img.shape)
# Out:
# torch.Size([64, 64])

# %%
plt.axis(False)
plt.title('Recovered Image:')
plt.imshow(img.cpu().detach(), cmap='gray')

# %%
                                                            # Dataset Loading
# Load the .pkl files in as numpy arrays of pixels
def load_tumor_data(file_path):
    train_xs = []
    train_ys = []
    """ Load Digits Data from pickle data
    return:
    @xs: numpy.array, (n, c, w, h) 
    @ys: numpy.array, (n, ), 0-9
    """
    with open(file_path, 'rb') as file:
        data = pickle.load(file)
        train_xs.append(data["data"])
        train_ys.append(data["labels"])
    train_xs = np.concatenate(train_xs, axis=0)
    train_ys = np.concatenate(train_ys, axis=0)
    
    return train_xs, train_ys

# %%
# Custom Tumor Dataset
class TumorDataset(data.Dataset):
    def __init__(self, xs, ys, is_train=True):
        self.xs = xs
        self.ys = ys

        if is_train is True:
            self.transform = transforms.Compose([
                transforms.ToPILImage(),
                transforms.Resize((64, 64)),
                transforms.ToTensor(),
                transforms.Normalize(
                    [0.5],
                    [0.5]
                )
            ])
        else:
            self.transform = transforms.Compose([
                transforms.ToPILImage(),
                transforms.Resize((64, 64)),
                transforms.ToTensor(),
                transforms.Normalize(
                    (0.4914, 0.4822, 0.4465),
                    (0.2023, 0.1994, 0.2010)
                )
            ])

    def __len__(self):
        return len(self.xs)

    def __getitem__(self, index):
        img = self.xs[index]
        #print(img.shape)
        label = self.ys[index]

        img = img.transpose((1, 2, 0)).astype(np.uint8)
        img = self.transform(img)

        img = torch.FloatTensor(img)
        label = torch.LongTensor([label])[0]
        return img, label

# %%
def create_dataset(train_xs, train_ys):
    tumor_dataset = TumorDataset(train_xs, train_ys, is_train=True)

    return tumor_dataset

# %%
def create_dataloader(dataset):
    dataloader = DataLoader(dataset=dataset, batch_size=128, shuffle=True)

    return dataloader

# %%
# Load in the pickle dataset file
train_xs, train_ys = load_tumor_data('datasets/Tumor/tumor4train.pkl')
#train_xs = train_xs[:, 1, :, :]
#train_xs = np.expand_dims(train_xs, axis=1)
train_xs = train_xs.mean(axis=1, keepdims=True)
print(train_xs.shape)
print(type(train_xs))
# Out:
# (13927, 1, 32, 32)
# <class 'numpy.ndarray'>

# %%
# Create the dataset
tumor_dataset = create_dataset(train_xs, train_ys)

# %%
def visualize_image(image_x):
    # We have to visualize by reverting the normalization (just for visualization).
    mean = torch.tensor([0.5])
    std = torch.tensor([0.5])

    image = image_x * std + mean  # Denormalize the image

    image = torch.clamp(image, 0, 1) # Clip values to [0, 1] to ensure valid range for display

    # Permute the image to (H, W, C) for matplotlib
    
    image = image.permute(1, 2, 0)

    plt.imshow(image, cmap='gray')

# %%
# Visualize the first tumor sample. 
image_x, image_y = tumor_dataset[7000]
print(image_x.shape)
visualize_image(image_x)
# Out:
# torch.Size([1, 64, 64])

# %%
from scipy.spatial.distance import cosine
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 from scipy.spatial.distance import cosine
#
# ModuleNotFoundError: No module named 'scipy'

# %%
# Get the feature embeddings
tfcnn_model = target_model = load_target_model(base_net='TFCNN', n_classes=4, path='saved models/fedavg_global_model.pth').to(device)
model_embeddings = tfcnn_model.encoder.to(device)

# %%
# Preprocessing
preprocess = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
])

# %%
def get_feature(img):
    with torch.no_grad():
        features = model_embeddings(img).squeeze()
    return features.cpu().numpy()

# %%
# Send an original image through the model
image_x, image_y = tumor_dataset[10]
image_x.shape

# %%
image_x = image_x.unsqueeze(dim=0)

# %%
image_x.shape

# %%
image_x = image_x.repeat(1, 3, 1, 1)
image_x = image_x.to(device)
image_x.shape

# %%
features = get_feature(image_x)
features.shape

# %%
class0_original_images = []
class1_original_images = []
class2_original_images = []
class3_original_images = []
target_num = 20 # 20 images for each class

# %%
for i in range(len(tumor_dataset)):
    img_x, img_y = tumor_dataset[i]

    if img_y == 0:
        if len(class0_original_images) < target_num:
            class0_original_images.append(img_x)
    elif img_y == 1:
        if len(class1_original_images) < target_num:
            class1_original_images.append(img_x)
    elif img_y == 2:
        if len(class2_original_images) < target_num:
            class2_original_images.append(img_x)
    elif img_y == 3:
        if len(class3_original_images) < target_num:
            class3_original_images.append(img_x)

# %%
len(class3_original_images)

# %%
# Testing the cosine similarity
class1_original_image = class1_original_images[8]
class1_original_image = class1_original_image.unsqueeze(dim=0).to(device)
class1_original_image = class1_original_image.repeat(1, 3, 1, 1)
class1_original_image.shape

# %%
fake1 = class0_optimized_latent_vectors[8]
fake1_image = gen(fake1.to(device))
fake1_image = fake1_image.repeat(1, 3, 1, 1)

# %%
fake1_image.shape

# %%
fake = class0_optimized_latent_vectors[13]
fake_img = gen(fake.to(device)).squeeze(dim=0)
print(fake_img.shape)
visualize_image(fake_img.detach().cpu())

# %%
# Get the features of the images
features_original = get_feature(class1_original_image)
features_fake = get_feature(fake1_image)

# %%
# Compute cosine similarity
similarity = 1 - cosine(features_original, features_fake)

# %%
similarity

# %%
def calculate_class0_sim():
    similarities = []
    for i in range(0, 20):
        class0_original = class0_original_images[i].unsqueeze(dim=0).to(device)
        class0_original = class0_original.repeat(1, 3, 1, 1)

        class0_fake = class0_optimized_latent_vectors[i]
        class0_fake_img = gen(class0_fake.to(device))
        class0_fake_img = class0_fake_img.repeat(1, 3, 1, 1)

        features_original = get_feature(class0_original)
        features_fake = get_feature(class0_fake_img)

        cosine_similarity = 1 - cosine(features_original, features_fake)

        similarities.append(cosine_similarity)
        
    return similarities

# %%
def calculate_class1_sim():
    similarities = []
    for i in range(0, 20):
        class1_original = class1_original_images[i].unsqueeze(dim=0).to(device)
        class1_original = class1_original.repeat(1, 3, 1, 1)

        class1_fake = class1_optimized_latent_vectors[i]
        class1_fake_img = gen(class1_fake.to(device))
        class1_fake_img = class1_fake_img.repeat(1, 3, 1, 1)

        features_original = get_feature(class1_original)
        features_fake = get_feature(class1_fake_img)

        cosine_similarity = 1 - cosine(features_original, features_fake)
        similarities.append(cosine_similarity)

    return similarities

# %%
def calculate_class2_sim():
    similarities = []
    for i in range(0, 20):
        class2_original = class2_original_images[i].unsqueeze(dim=0).to(device)
        class2_original = class2_original.repeat(1, 3, 1, 1)

        class2_fake = class2_optimized_latent_vectors[i]
        class2_fake_img = gen(class2_fake.to(device))
        class2_fake_img = class2_fake_img.repeat(1, 3, 1, 1)

        features_original = get_feature(class2_original)
        features_fake = get_feature(class2_fake_img)

        cosine_similarity = 1 - cosine(features_original, features_fake)
        similarities.append(cosine_similarity)

    return similarities

# %%
def calculate_class3_sim():
    similarities = []
    for i in range(0, 20):
        class3_original = class3_original_images[i].unsqueeze(dim=0).to(device)
        class3_original = class3_original.repeat(1, 3, 1, 1)

        class3_fake = class3_optimized_latent_vectors[i]
        class3_fake_img = gen(class3_fake.to(device))
        class3_fake_img = class3_fake_img.repeat(1, 3, 1, 1)

        features_original = get_feature(class3_original)
        features_fake = get_feature(class3_fake_img)

        cosine_similarity = 1 - cosine(features_original, features_fake)
        similarities.append(cosine_similarity)

    return similarities

# %%
class0_sims = calculate_class0_sim()
class1_sims = calculate_class0_sim()
class2_sims = calculate_class0_sim()
class3_sims = calculate_class0_sim()

# %%
class0_sims

# %%
class3_sims

# %%
                                                        # VISUALIZE
# NOTE: Class indexes now start from 1 so, previous class 0 = now class 1 and so on
# FIG 1: Raw similarity plot

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Generate sample similarity data for four classes (each with 20 values in the range 0 to 1)
class1_sim = class0_sims
class2_sim = class1_sims
class3_sim = class2_sims
class4_sim = class3_sims

# Set figure size
plt.figure(figsize=(6.5, 4.2))  # Set the size of the figure (width, height)

# Sample DataFrame with four columns
data=pd.DataFrame({'Class 1':class1_sim,'Class 2':class2_sim,'Class 3':class3_sim,'Class 4':class4_sim})
df = pd.DataFrame(data)

# Plot the probability distributions
#plt.figure(figsize=(10, 6))

# Define colors and line styles for each column
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']
linestyles = ['-.', '--', '-', '-']

# Plot the probability distributions with unique colors and line styles
for column, color, linestyle in zip(df.columns, colors, linestyles):
    sns.kdeplot(df[column], label=column, color=color, linestyle=linestyle)

#plt.title('Probability Distributions of Four Columns')
plt.xlabel('Similarity',fontsize=12)
plt.ylabel('Density',fontsize=12)
plt.yticks(fontsize=12)  # Set y-tick labels font size
plt.legend(loc='upper right',fontsize=12)  # Increase legend font size

# Optimize layout
plt.tight_layout()
# Save the plot to a file
plt.savefig('output/fedvg.png', dpi=300, bbox_inches='tight')  # Save as a PNG file with high resolution

# Show the plot
plt.show()

# %%
# FIG 2: DIFFERENCES IN COSINE SIMILARITY

# For each class, we have 20 similarity values — one per image — showing how similar fake and real versions are.These values are very close across classes
# So, to highlight subtle differences, compute and plot the difference between each pair of classes, value by value.
# This gives you 20 values showing how much the similarity differs for each image between class 0 and class 1.
# It's a magnified view of the gap between classes.
# If the differences are tiny (e.g., 0.003), the plot helps make that visible and comparable.

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Differences between class distributions (pairwise)
diff_12 = np.array(class2_sim) - np.array(class1_sim)
diff_13 = np.array(class3_sim) - np.array(class1_sim)
diff_14 = np.array(class4_sim) - np.array(class1_sim)
diff_23 = np.array(class3_sim) - np.array(class2_sim)
diff_24 = np.array(class4_sim) - np.array(class2_sim)
diff_34 = np.array(class4_sim) - np.array(class3_sim)

# Create a DataFrame
diff_df = pd.DataFrame({
    'Class 2 - Class 1': diff_12,
    'Class 3 - Class 1': diff_13,
    'Class 4 - Class 1': diff_14,
    'Class 3 - Class 2': diff_23,
    'Class 4 - Class 2': diff_24,
    'Class 4 - Class 3': diff_34,
})

# Plot
plt.figure(figsize=(7.5, 5))

colors = sns.color_palette("tab10", n_colors=6)

for column, color in zip(diff_df.columns, colors):
    sns.kdeplot(diff_df[column], label=column, color=color, linestyle='-')

plt.axvline(0, color='black', linestyle='--', linewidth=1)  # reference line at 0
plt.xlabel('Difference in Similarity', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.legend(fontsize=10)
plt.title("Pairwise Differences in Cosine Similarity", fontsize=13)
plt.tight_layout()
plt.show()

# %%
def calculate_interclass_similarity(first, second):
    similarities = []

    first_images = []
    second_images = []
    if first == 'class1':
        first_images = class0_original_images.copy()
    elif first == 'class2':
        first_images = class1_original_images.copy()
    elif first == 'class3':
        first_images = class2_original_images.copy()
    elif first == 'class4':
        first_images = class3_original_images.copy()

    if second == 'class1':
        second_images = class0_original_images.copy()
    elif second == 'class2':
        second_images = class1_original_images.copy()
    elif second == 'class3':
        second_images = class2_original_images.copy()
    elif second == 'class4':
        second_images = class3_original_images.copy()
    
    for i in range(0, 20):
        first_image = first_images[i].unsqueeze(dim=0).to(device)
        first_image = first_image.repeat(1, 3, 1, 1)
        
        second_image = second_images[i].unsqueeze(dim=0).to(device)
        second_image = second_image.repeat(1, 3, 1, 1)
        
        features_first = get_feature(first_image)
        features_second = get_feature(second_image)

        cosine_similarity = 1 - cosine(features_first, features_second)
        similarities.append(cosine_similarity)

    return similarities

# %%
class1class2 = calculate_interclass_similarity('class1', 'class2')

# %%
class1class2

# %%
                                                # FIG: 3 -> INTERCLASS SIMILARITIES

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set figure size
plt.figure(figsize=(6.5, 4.2))  # Set the size of the figure (width, height)

# Generate sample similarity data for four classes (each with 20 values in the range 0 to 1)
np.random.seed(42)  # For reproducibility
class1class2 = calculate_interclass_similarity('class1', 'class2')
class1class3 = calculate_interclass_similarity('class1', 'class3')
class1class4 = calculate_interclass_similarity('class1', 'class4')
class2class3 = calculate_interclass_similarity('class2', 'class3')
class2class4 = calculate_interclass_similarity('class2', 'class4')
class3class4 = calculate_interclass_similarity('class3', 'class4')

# Sample DataFrame with four columns
data=pd.DataFrame({'Class1 vs Class2':class1class2,'Class1 vs Class3':class1class3,'Class1 vs Class4':class1class4,'Class2 vs Class3':class2class3,'Class2 vs Class4':class2class4,'Class3 vs Class4':class3class4})
df = pd.DataFrame(data)

# Plot the probability distributions
#plt.figure(figsize=(10, 6))

# Define colors and line styles for each column
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b']
linestyles = ['-.', '--', '-', '-', '-.', '--']

# Plot the probability distributions with unique colors and line styles
for column, color, linestyle in zip(df.columns, colors, linestyles):
    sns.kdeplot(df[column], label=column, color=color, linestyle=linestyle)

#plt.title('Probability Distributions of Four Columns')
plt.xlabel('Similarity',fontsize=12)
plt.ylabel('Density',fontsize=12)
plt.yticks(fontsize=12)  # Set y-tick labels font size
plt.legend(loc='upper right',fontsize=12)  # Increase legend font size

# Optimize layout
plt.tight_layout()
# Save the plot to a file
plt.savefig('output/VoiceDivergenceD3.png', dpi=300, bbox_inches='tight')  # Save as a PNG file with high resolution

# Show the plot
plt.show()
