# %%
# Attempting to recover training data using model's parameters and a DCGAN that was trained on similar data
# Author: Suraj Neupane
# Written from scratch as a part of a Research Project 2025, Concordia University of Edmonton.
import numpy as np

import torch
from torch import nn
from torch.nn import functional

from torch.utils import data
from torch.utils.data import DataLoader

import torchvision
from torchvision import datasets
from torchvision import transforms

import pickle

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
torch.__version__
# Out:
# '2.5.1+cu118'

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
device
# Out:
# 'cuda'

# %%
# DCGAN Implementation Class
# Discriminator
class Discriminator(nn.Module):
    def __init__(self, img_channels, features_d):
        super().__init__()
        self.disc = nn.Sequential(
            # Input shape: img_channels x 64 x 64
            nn.Conv2d(
              in_channels=img_channels, out_channels=features_d, kernel_size=4, stride=2, padding=1
            ), # Output shape: features_d x 32 x 32
            nn.LeakyReLU(0.2),
            self._block(features_d, features_d*2, 4, 2, 1), # Output shape: features_d*2 x 16 x 16
            self._block(features_d*2, features_d*4, 4, 2, 1), # Output shape: features_d*4 x 8 x 8
            self._block(features_d*4, features_d*8, 4, 2, 1), # Output shape: features_d*8 x 4 x 4
           
            nn.Conv2d(in_channels=features_d*8, out_channels=1, kernel_size=4, stride=2, padding=0), # Output shape: 1 x 1
            nn.Sigmoid(),
        )

    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(0.2),
        )

    def forward(self, X):
        return self.disc(X)

# %%
# Generator
class Generator(nn.Module):
    def __init__(self, z_dim, img_channels, features_g):
        super().__init__()
        self.gen = nn.Sequential(
            self._block(z_dim, features_g*16, 4, 1, 0), # z_dim: (batch_size, 100, 1, 1) -> (batch_size, 1024, 4, 4)
            self._block(features_g*16, features_g*8, 4, 2, 1), # z_dim: (batch_size, 1024, 4, 4) -> (batch_size, 512, 8, 8)
            self._block(features_g*8, features_g*4, 4, 2, 1), # z_dim: (batch_size, 512, 8, 8) -> (batch_size, 256, 16, 16)
            self._block(features_g*4, features_g*2, 4, 2, 1), # z_dim: (batch_size, 128, 16, 16) -> (batch_size, 64, 32, 32)
            nn.ConvTranspose2d(
                in_channels=features_g*2, out_channels=img_channels, kernel_size=4, stride=2, padding=1 # z_dim: (batch_size, 64, 32, 32) -> (batch_size, 1, 64, 64)
            ),
            nn.Tanh(),
        )
        
    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.ConvTranspose2d(
                in_channels, out_channels, kernel_size, stride, padding, bias=False,
            ),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
        )

    def forward(self, X):
        return self.gen(X)

# %%
# Hyperparams
z_dim = 100
img_channels = 1
features_disc = 64
features_gen = 64

# %%
# Create the model instances
gen = Generator(z_dim, img_channels, features_gen).to(device)
disc = Discriminator(img_channels, features_disc).to(device)

# %%
# Load the trained GAN
gen.load_state_dict(torch.load('saved models/Generator.pth', weights_only=True))
disc.load_state_dict(torch.load('saved models/Discriminator.pth', weights_only=True))
# Out:
# <All keys matched successfully>

# %%
# Generate a random fake image
noise = torch.randn(1, z_dim, 1, 1).to(device)
fake_img = gen(noise)

# %%
fake_img.shape
# Out:
# torch.Size([1, 1, 64, 64])

# %%
fake_img = fake_img.squeeze()
print(fake_img.shape)
plt.axis(False)
plt.title('Fake Generated Image:')
plt.imshow(fake_img.cpu().detach(), cmap='gray')
# Out:
# torch.Size([64, 64])

# %%
# Target Model
class TFCNN(nn.Module):
    def __init__(self, n_classes):
        super().__init__()
        self.n_classes = n_classes

        self.encoder = nn.Sequential(
            nn.Conv2d(1, 32, 3, stride=1, padding=1),
            nn.ReLU(True),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, 3, stride=1, padding=1),
            nn.ReLU(True),
            nn.MaxPool2d(2),
            nn.Conv2d(64, 64, 3, stride=1, padding=1),
            nn.ReLU(True),
            nn.MaxPool2d(2),
            Reshape(),
        )

        self.h_size = 64 * 4 * 4

        self.classifier = nn.Sequential(
            nn.Linear(64 * 4 * 4, 128),
            nn.ReLU(True),
            nn.Linear(128, n_classes)
        )

    def forward(self, xs):
        code = self.encoder(xs)
        logits = self.classifier(code)
        return code, logits

# %%
class Reshape(nn.Module):
    def __init__(self,):
        super().__init__()

    def forward(self, xs):
        return xs.reshape((xs.shape[0], -1))

# %%
class ClassifyNet(nn.Module):
    def __init__(self, net, init_way, n_classes, input_size=None):
        super().__init__()
        self.net = net
        self.init_way = init_way
        self.n_classes = n_classes

        model = TFCNN(n_classes)

        self.h_size = model.h_size

        # Convo and pool layers
        self.encoder = model.encoder

        # Classifier layer
        self.classifier = nn.Linear(
            self.h_size, self.n_classes, bias=False
        )

        if self.init_way == "orth":
            ws = get_orth_weights(self.h_size, self.n_classes)
            self.classifier.load_state_dict({"weight": ws})

    def forward(self, xs):
        hs = self.encoder(xs)
        logits = self.classifier(hs)
        return hs, logits

# %%
def load_target_model(base_net, n_classes, path):
    # Create the base model
    model = ClassifyNet(net=base_net, init_way='none', n_classes=n_classes)
    # Load the model
    model.load_state_dict(torch.load(path, weights_only=True))

    return model

# %%
# Target Model Loading
BASE_NET = 'TFCNN'
DATASET = 'face'
N_CLASSES = 40

target_model = load_target_model(base_net=BASE_NET, n_classes=N_CLASSES, path='saved models/fedavg_global_model.pth').to(device)
print('Model loaded successfully!')
target_model.eval()

num_params = sum(p.numel() for p in target_model.parameters())
print('Number of parameters in the loaded model:', num_params)
# Out:
# Model loaded successfully!
# Number of parameters in the loaded model: 96704

# %%
# Do Model Inversion
# Define a learnable latent vector
z = torch.randn(1, z_dim, 1, 1, requires_grad=True)  # Start with random noise
z.shape
# Out:
# torch.Size([1, 100, 1, 1])

# %%
learning_rate = 0.01
target_class = 1 # The second class

# Create the optimizer
optimizer = torch.optim.Adam([z], lr=learning_rate)

# Loss function (e.g., Cross-Entropy with classifier outputs)
loss_fn = nn.CrossEntropyLoss()
target_class = torch.tensor([target_class])  # Set the target class

# %%
# Optimization loop to find the best z
rounds = 1000
for i in range(rounds):
    optimizer.zero_grad()
    
    generated_image = gen(z.to(device))  # Generate an image from the latent vector
    #generated_image = generated_image.repeat(1, 1, 1, 1)
    generated_image = functional.interpolate(generated_image, size=(32, 32), mode='nearest')
    #print(generated_image.shape)
    hs, prediction_logits = target_model(generated_image)  # Classifier output
    #print(prediction_logits)
    #print(type(prediction_logits))
    loss = loss_fn(prediction_logits, target_class.to(device))  # Minimize difference with true class
    loss.backward()
    optimizer.step()

    if i % 50 == 0:
        print(f"Step {i}, Loss: {loss.item()}")
# Out:
# Step 0, Loss: 5.004085540771484
# Step 50, Loss: 1.1879459619522095
# Step 100, Loss: 0.9611392021179199
# Step 150, Loss: 0.8500491380691528
# Step 200, Loss: 0.7634919285774231
# Step 250, Loss: 0.721161961555481
# Step 300, Loss: 0.6916366815567017
# Step 350, Loss: 0.6562550067901611
# Step 400, Loss: 0.6253031492233276
# Step 450, Loss: 0.6033793687820435
# Step 500, Loss: 0.5899810194969177
# Step 550, Loss: 0.5789024233818054
# Step 600, Loss: 0.5686887502670288
# Step 650, Loss: 0.5597172975540161
# Step 700, Loss: 0.5513051152229309
# Step 750, Loss: 0.5436245799064636
# Step 800, Loss: 0.5352572202682495
# Step 850, Loss: 0.5261714458465576
# Step 900, Loss: 0.5182775259017944
# Step 950, Loss: 0.5098947286605835

# %%
# Display the generated image
img = gen(z.to(device)).squeeze(dim=0).squeeze(dim=0)
print(img.shape)
# Out:
# torch.Size([64, 64])

# %%
plt.axis(False)
plt.title('Recovered Image:')
plt.imshow(img.cpu().detach(), cmap='gray')

# %%
recovered_images = []

# %%
# Generate a series of recovered images 
# 1. Rotate over the 4 classes randomly 0, 1, 2, 3
# 2. Have a random seed initialization for the latent vector z in every iteration
# 3. Optimize the latent vector and recover a potential training data
# 4. Store each of the recovered images in their own list
target_classes = 20
latent_vectors = []
for x in range(0, target_classes):
    target_class = x
    target_class = torch.tensor([target_class])

    learning_rate = 0.01

    # Define a learnable latent vector
    z = torch.randn(1, z_dim, 1, 1, requires_grad=True)  # Start with random noise
    # Create the optimizer
    optimizer = torch.optim.Adam([z], lr=learning_rate)
    
    # Loss function (e.g., Cross-Entropy with classifier outputs)
    loss_fn = nn.CrossEntropyLoss()
    
    rounds = 1000
    for i in range(rounds):
        optimizer.zero_grad()
        
        generated_image = gen(z.to(device))  # Generate an image from the latent vector
        #generated_image = generated_image.repeat(1, 3, 1, 1)
        generated_image = functional.interpolate(generated_image, size=(32, 32), mode='nearest')
        #print(generated_image.shape)
        hs, prediction_logits = target_model(generated_image)  # Classifier output
        #print(prediction_logits)
        #print(type(prediction_logits))
        loss = loss_fn(prediction_logits, target_class.to(device))  # Minimize difference with true class
        loss.backward()
        optimizer.step()
    
        if i % 50 == 0:
            print(f"Class: {target_class}")
            print(f"Step {i}, Loss: {loss.item()}")
            
    latent_vectors.append(z)
# Out:
# Class: tensor([0])
# Step 0, Loss: 6.450937271118164
# Class: tensor([0])
# Step 50, Loss: 4.169942855834961
# Class: tensor([0])
# Step 100, Loss: 3.426431179046631
# Class: tensor([0])
# Step 150, Loss: 2.802267551422119
# Class: tensor([0])
# Step 200, Loss: 2.5766422748565674
# Class: tensor([0])
# Step 250, Loss: 2.421018600463867
# Class: tensor([0])
# Step 300, Loss: 2.303966760635376
# Class: tensor([0])
# Step 350, Loss: 2.2445855140686035
# Class: tensor([0])
# Step 400, Loss: 2.203500509262085
# Class: tensor([0])
# Step 450, Loss: 2.158602476119995
# Class: tensor([0])
# Step 500, Loss: 2.1043972969055176
# Class: tensor([0])
# Step 550, Loss: 2.0612735748291016
# Class: tensor([0])
# Step 600, Loss: 2.0339834690093994
# Class: tensor([0])
# Step 650, Loss: 2.0171449184417725
# Class: tensor([0])
# Step 700, Loss: 2.004889488220215
# Class: tensor([0])
# Step 750, Loss: 1.9956238269805908
# Class: tensor([0])
# Step 800, Loss: 1.9834128618240356
# Class: tensor([0])
# Step 850, Loss: 1.9704432487487793
# Class: tensor([0])
# Step 900, Loss: 1.9595345258712769
# Class: tensor([0])
# Step 950, Loss: 1.9425723552703857
# Step 450, Loss: 2.3736672401428223
# Class: tensor([3])
# Step 500, Loss: 2.3258883953094482
# Class: tensor([3])
# Step 550, Loss: 2.2864131927490234
# Class: tensor([3])
# Step 600, Loss: 2.2122039794921875
# Class: tensor([3])
# Step 650, Loss: 2.1716442108154297
# Class: tensor([3])
# Step 700, Loss: 2.151146411895752
# Class: tensor([3])
# Step 750, Loss: 2.12851881980896
# Class: tensor([3])
# Step 800, Loss: 2.115360736846924
# Class: tensor([3])
# Step 850, Loss: 2.1055774688720703
# Class: tensor([3])
# Step 900, Loss: 2.0964226722717285
# Class: tensor([3])
# Step 950, Loss: 2.0945942401885986
# Class: tensor([4])
# Step 0, Loss: 9.1422758102417
# Class: tensor([4])
# Step 50, Loss: 5.889095306396484
# Class: tensor([4])
# Step 100, Loss: 4.792888641357422
# Class: tensor([4])
# Step 150, Loss: 3.915437698364258
# Class: tensor([4])
# Step 200, Loss: 3.316801071166992
# Class: tensor([4])
# Step 250, Loss: 2.986279010772705
# Class: tensor([4])
# Step 300, Loss: 2.825197696685791
# Class: tensor([4])
# Step 350, Loss: 2.7109124660491943
# Class: tensor([4])
# Step 400, Loss: 2.6587510108947754
# Class: tensor([4])
# Step 450, Loss: 2.6152071952819824
# Class: tensor([4])
# Step 500, Loss: 2.5790047645568848
# Class: tensor([4])
# Step 550, Loss: 2.5521297454833984
# Class: tensor([4])
# Step 600, Loss: 2.538604497909546
# Class: tensor([4])
# Step 650, Loss: 2.5213279724121094
# Class: tensor([4])
# Step 700, Loss: 2.5121779441833496
# Class: tensor([4])
# Step 750, Loss: 2.491830825805664
# Class: tensor([4])
# Step 800, Loss: 2.4864070415496826
# Class: tensor([4])
# Step 850, Loss: 2.479640007019043
# Class: tensor([4])
# Step 900, Loss: 2.4715943336486816
# Class: tensor([4])
# Step 950, Loss: 2.4648661613464355
# Class: tensor([5])
# Step 0, Loss: 7.046877861022949
# Class: tensor([5])
# Step 50, Loss: 3.756861686706543
# Class: tensor([5])
# Step 100, Loss: 2.7740912437438965
# Class: tensor([5])
# Step 150, Loss: 2.2759838104248047
# Class: tensor([5])
# Step 200, Loss: 2.0388104915618896
# Class: tensor([5])
# Step 250, Loss: 1.9453526735305786
# Class: tensor([5])
# Step 300, Loss: 1.8575737476348877
# Class: tensor([5])
# Step 350, Loss: 1.770538091659546
# Class: tensor([5])
# Step 400, Loss: 1.694744348526001
# Class: tensor([5])
# Step 450, Loss: 1.6272995471954346
# Class: tensor([5])
# Step 500, Loss: 1.5686445236206055
# Class: tensor([5])
# Step 550, Loss: 1.530153512954712
# Class: tensor([5])
# Step 600, Loss: 1.4915629625320435
# Class: tensor([5])
# Step 650, Loss: 1.4547580480575562
# Class: tensor([5])
# Step 700, Loss: 1.4270070791244507
# Class: tensor([5])
# Step 750, Loss: 1.4009075164794922
# Class: tensor([5])
# Step 800, Loss: 1.3723552227020264
# Class: tensor([5])
# Step 850, Loss: 1.3401026725769043
# Class: tensor([5])
# Step 900, Loss: 1.311766505241394
# Class: tensor([5])
# Step 950, Loss: 1.2847362756729126
# Class: tensor([6])
# Step 0, Loss: 2.573928117752075
# Class: tensor([6])
# Step 50, Loss: 1.6482489109039307
# Class: tensor([6])
# Step 100, Loss: 1.4373334646224976
# Class: tensor([6])
# Step 150, Loss: 1.360947847366333
# Class: tensor([6])
# Step 200, Loss: 1.3250564336776733
# Class: tensor([6])
# Step 250, Loss: 1.284898281097412
# Class: tensor([6])
# Step 300, Loss: 1.2489650249481201
# Class: tensor([6])
# Step 350, Loss: 1.210195541381836
# Class: tensor([6])
# Step 400, Loss: 1.1554100513458252
# Class: tensor([6])
# Step 450, Loss: 1.1004310846328735
# Class: tensor([6])
# Step 500, Loss: 1.0449304580688477
# Class: tensor([6])
# Step 550, Loss: 0.9776573777198792
# Class: tensor([6])
# Step 600, Loss: 0.8738227486610413
# Class: tensor([6])
# Step 650, Loss: 0.7406374216079712
# Class: tensor([6])
# Step 700, Loss: 0.6789768934249878
# Class: tensor([6])
# Step 750, Loss: 0.6423725485801697
# Class: tensor([6])
# Step 800, Loss: 0.6267814040184021
# Class: tensor([6])
# Step 850, Loss: 0.6085948944091797
# Class: tensor([6])
# Step 900, Loss: 0.5898246169090271
# Class: tensor([6])
# Step 950, Loss: 0.5000229477882385
# Class: tensor([7])
# Step 0, Loss: 6.017674446105957
# Class: tensor([7])
# Step 50, Loss: 4.3083906173706055
# Class: tensor([7])
# Step 100, Loss: 3.7138397693634033
# Class: tensor([7])
# Step 150, Loss: 3.175745725631714
# Class: tensor([7])
# Step 200, Loss: 2.5061025619506836
# Class: tensor([7])
# Step 250, Loss: 2.2075655460357666
# Class: tensor([7])
# Step 300, Loss: 2.01716947555542
# Class: tensor([7])
# Step 350, Loss: 1.8805053234100342
# Class: tensor([7])
# Step 400, Loss: 1.7813416719436646
# Class: tensor([7])
# Step 450, Loss: 1.7052685022354126
# Class: tensor([7])
# Step 500, Loss: 1.6490612030029297
# Class: tensor([7])
# Step 550, Loss: 1.6196521520614624
# Class: tensor([7])
# Step 600, Loss: 1.5927653312683105
# Class: tensor([7])
# Step 650, Loss: 1.5856504440307617
# Class: tensor([7])
# Step 700, Loss: 1.5168800354003906
# Class: tensor([7])
# Step 750, Loss: 1.4861390590667725
# Class: tensor([7])
# Step 800, Loss: 1.472598671913147
# Class: tensor([7])
# Step 850, Loss: 1.456244707107544
# Class: tensor([7])
# Step 900, Loss: 1.4262058734893799
# Class: tensor([7])
# Step 950, Loss: 1.4079647064208984
# Class: tensor([8])
# Step 0, Loss: 5.598208427429199
# Class: tensor([8])
# Step 50, Loss: 3.891012668609619
# Class: tensor([8])
# Step 100, Loss: 3.5764050483703613
# Class: tensor([8])
# Step 150, Loss: 3.3513739109039307
# Class: tensor([8])
# Step 200, Loss: 2.963738441467285
# Class: tensor([8])
# Step 250, Loss: 2.811547040939331
# Class: tensor([8])
# Step 300, Loss: 2.71940279006958
# Class: tensor([8])
# Step 350, Loss: 2.573045492172241
# Step 300, Loss: 1.1507699489593506
# Class: tensor([13])
# Step 350, Loss: 1.1322736740112305
# Class: tensor([13])
# Step 400, Loss: 1.1171683073043823
# Class: tensor([13])
# Step 450, Loss: 1.0998637676239014
# Class: tensor([13])
# Step 500, Loss: 1.0792737007141113
# Class: tensor([13])
# Step 550, Loss: 1.065857172012329
# Class: tensor([13])
# Step 600, Loss: 1.0497212409973145
# Class: tensor([13])
# Step 650, Loss: 1.0285828113555908
# Class: tensor([13])
# Step 700, Loss: 1.0133565664291382
# Class: tensor([13])
# Step 750, Loss: 0.9968679547309875
# Class: tensor([13])
# Step 800, Loss: 0.9794521331787109
# Class: tensor([13])
# Step 850, Loss: 0.9578173160552979
# Class: tensor([13])
# Step 900, Loss: 0.9408930540084839
# Class: tensor([13])
# Step 950, Loss: 0.924041748046875
# Class: tensor([14])
# Step 0, Loss: 6.547420501708984
# Class: tensor([14])
# Step 50, Loss: 3.3194894790649414
# Class: tensor([14])
# Step 100, Loss: 2.8859376907348633
# Class: tensor([14])
# Step 150, Loss: 2.605588912963867
# Class: tensor([14])
# Step 200, Loss: 2.414447784423828
# Class: tensor([14])
# Step 250, Loss: 2.2845418453216553
# Class: tensor([14])
# Step 300, Loss: 2.193086862564087
# Class: tensor([14])
# Step 350, Loss: 2.138089895248413
# Class: tensor([14])
# Step 400, Loss: 2.1128246784210205
# Class: tensor([14])
# Step 450, Loss: 2.089418649673462
# Class: tensor([14])
# Step 500, Loss: 2.0664432048797607
# Class: tensor([14])
# Step 550, Loss: 2.0450692176818848
# Class: tensor([14])
# Step 600, Loss: 2.021796464920044
# Class: tensor([14])
# Step 650, Loss: 1.996622085571289
# Class: tensor([14])
# Step 700, Loss: 1.9806021451950073
# Class: tensor([14])
# Step 750, Loss: 1.9681512117385864
# Class: tensor([14])
# Step 800, Loss: 1.9576126337051392
# Class: tensor([14])
# Step 850, Loss: 1.9425127506256104
# Class: tensor([14])
# Step 900, Loss: 1.9295655488967896
# Class: tensor([14])
# Step 950, Loss: 1.9162369966506958
# Class: tensor([15])
# Step 0, Loss: 3.8940463066101074
# Class: tensor([15])
# Step 50, Loss: 1.7314621210098267
# Class: tensor([15])
# Step 100, Loss: 1.5173158645629883
# Class: tensor([15])
# Step 150, Loss: 1.435783863067627
# Class: tensor([15])
# Step 200, Loss: 1.3306654691696167
# Class: tensor([15])
# Step 250, Loss: 1.2382508516311646
# Class: tensor([15])
# Step 300, Loss: 1.1789709329605103
# Class: tensor([15])
# Step 350, Loss: 1.1358880996704102
# Class: tensor([15])
# Step 400, Loss: 1.0462877750396729
# Class: tensor([15])
# Step 450, Loss: 0.9823931455612183
# Class: tensor([15])
# Step 500, Loss: 0.9591876268386841
# Class: tensor([15])
# Step 550, Loss: 0.9295505285263062
# Class: tensor([15])
# Step 600, Loss: 0.9048335552215576
# Class: tensor([15])
# Step 650, Loss: 0.8898369669914246
# Class: tensor([15])
# Step 700, Loss: 0.8774470686912537
# Class: tensor([15])
# Step 750, Loss: 0.8655988574028015
# Class: tensor([15])
# Step 800, Loss: 0.8524585366249084
# Class: tensor([15])
# Step 850, Loss: 0.8417074084281921
# Class: tensor([15])
# Step 900, Loss: 0.8300918936729431
# Class: tensor([15])
# Step 950, Loss: 0.8216243386268616
# Class: tensor([16])
# Step 0, Loss: 5.448016166687012
# Class: tensor([16])
# Step 50, Loss: 3.3698716163635254
# Class: tensor([16])
# Step 100, Loss: 2.965811252593994
# Class: tensor([16])
# Step 150, Loss: 2.6856603622436523
# Class: tensor([16])
# Step 200, Loss: 2.4967236518859863
# Class: tensor([16])
# Step 250, Loss: 2.3641226291656494
# Class: tensor([16])
# Step 300, Loss: 2.268343448638916
# Class: tensor([16])
# Step 350, Loss: 2.202786684036255
# Class: tensor([16])
# Step 400, Loss: 2.1483845710754395
# Class: tensor([16])
# Step 450, Loss: 2.0904228687286377
# Class: tensor([16])
# Step 500, Loss: 2.036362648010254
# Class: tensor([16])
# Step 550, Loss: 2.0025291442871094
# Class: tensor([16])
# Step 600, Loss: 1.9608126878738403
# Class: tensor([16])
# Step 650, Loss: 1.9059429168701172
# Class: tensor([16])
# Step 700, Loss: 1.8330879211425781
# Class: tensor([16])
# Step 750, Loss: 1.7777959108352661
# Class: tensor([16])
# Step 800, Loss: 1.717797875404358
# Class: tensor([16])
# Step 850, Loss: 1.633004903793335
# Class: tensor([16])
# Step 900, Loss: 1.5755048990249634
# Class: tensor([16])
# Step 950, Loss: 1.5385897159576416
# Class: tensor([17])
# Step 0, Loss: 4.811136245727539
# Class: tensor([17])
# Step 50, Loss: 4.059565544128418
# Class: tensor([17])
# Step 100, Loss: 3.1427974700927734
# Class: tensor([17])
# Step 150, Loss: 2.9282565116882324
# Class: tensor([17])
# Step 200, Loss: 2.863779067993164
# Class: tensor([17])
# Step 250, Loss: 2.8043572902679443
# Class: tensor([17])
# Step 300, Loss: 2.7645697593688965
# Class: tensor([17])
# Step 350, Loss: 2.739287853240967
# Class: tensor([17])
# Step 400, Loss: 2.633927822113037
# Class: tensor([17])
# Step 450, Loss: 2.5632615089416504
# Class: tensor([17])
# Step 500, Loss: 2.5050055980682373
# Class: tensor([17])
# Step 550, Loss: 2.4317855834960938
# Class: tensor([17])
# Step 600, Loss: 2.3827409744262695
# Class: tensor([17])
# Step 650, Loss: 2.3474433422088623
# Class: tensor([17])
# Step 700, Loss: 2.330948829650879
# Class: tensor([17])
# Step 750, Loss: 2.3156418800354004
# Class: tensor([17])
# Step 800, Loss: 2.301875352859497
# Class: tensor([17])
# Step 850, Loss: 2.2923662662506104
# Class: tensor([17])
# Step 900, Loss: 2.284637928009033
# Class: tensor([17])
# Step 950, Loss: 2.274358034133911
# Class: tensor([18])
# Step 0, Loss: 3.0867581367492676
# Class: tensor([18])
# Step 50, Loss: 2.3153586387634277
# Class: tensor([18])
# Step 100, Loss: 2.2146120071411133
# Class: tensor([18])
# Step 150, Loss: 2.126068592071533
# Class: tensor([18])
# Step 200, Loss: 1.9868531227111816
# Class: tensor([18])
# Step 250, Loss: 1.7872563600540161
# Class: tensor([18])
# Step 300, Loss: 1.640798807144165
# Class: tensor([18])
# Step 350, Loss: 1.5613446235656738
# Class: tensor([18])
# Step 400, Loss: 1.5173206329345703
# Class: tensor([18])
# Step 450, Loss: 1.4937403202056885
# Class: tensor([18])
# Step 500, Loss: 1.470049262046814
# Class: tensor([18])
# Step 550, Loss: 1.4491413831710815
# Class: tensor([18])
# Step 600, Loss: 1.4200822114944458
# Class: tensor([18])
# Step 650, Loss: 1.4025511741638184
# Class: tensor([18])
# Step 700, Loss: 1.387822151184082
# Class: tensor([18])
# Step 750, Loss: 1.3691089153289795
# Class: tensor([18])
# Step 800, Loss: 1.3506519794464111
# Class: tensor([18])
# Step 850, Loss: 1.3320902585983276
# Class: tensor([18])
# Step 900, Loss: 1.3152053356170654
# Class: tensor([18])
# Step 950, Loss: 1.3099970817565918
# Class: tensor([19])
# Step 0, Loss: 4.476457595825195
# Class: tensor([19])
# Step 50, Loss: 2.4650843143463135
# Class: tensor([19])
# Step 100, Loss: 1.7183504104614258
# Class: tensor([19])
# Step 150, Loss: 0.8778508901596069
# Class: tensor([19])
# Step 200, Loss: 0.6770095825195312
# Class: tensor([19])
# Step 250, Loss: 0.49089139699935913
# Class: tensor([19])
# Step 300, Loss: 0.4223785400390625
# Class: tensor([19])
# Step 350, Loss: 0.36383989453315735
# Class: tensor([19])
# Step 400, Loss: 0.30552592873573303
# Class: tensor([19])
# Step 450, Loss: 0.2624591290950775
# Class: tensor([19])
# Step 500, Loss: 0.2438438981771469
# Class: tensor([19])
# Step 550, Loss: 0.22384606301784515
# Class: tensor([19])
# Step 600, Loss: 0.21040047705173492
# Class: tensor([19])
# Step 650, Loss: 0.1983150839805603
# Class: tensor([19])
# Step 700, Loss: 0.18498049676418304
# Class: tensor([19])
# Step 750, Loss: 0.17584629356861115
# Class: tensor([19])
# Step 800, Loss: 0.16685278713703156
# Class: tensor([19])
# Step 850, Loss: 0.15816009044647217
# Class: tensor([19])
# Step 900, Loss: 0.15078984200954437
# Class: tensor([19])
# Step 950, Loss: 0.14330114424228668

# %%
# Display the generated image
img = gen(latent_vectors[0].to(device)).squeeze(dim=0).squeeze(dim=0)
print(img.shape)
# Out:
# torch.Size([64, 64])

# %%
plt.imshow(img.cpu().detach(), cmap='gray')

# %%
recovered_1 = []
for lv in latent_vectors:
    recovered_1.append(lv)

# %%
len(recovered_1)
# Out:
# 20

# %%
for i in range(0, len(recovered_1)):
    img = gen(recovered_1[i].to(device)).squeeze(dim=0).squeeze(dim=0)
    recovered_images.append(img)

# %%
len(recovered_images)
# Out:
# 20

# %%
# Create a figure with 2 rows and 4 columns
fig, axes = plt.subplots(4, 5, figsize=(8, 4))

# Flatten the 2D axes array and iterate over it
for ax, img in zip(axes.flatten(), recovered_images):
    ax.imshow(img.cpu().detach(), cmap='gray')  # Display the image
    ax.axis('off')  # Hide axes

plt.tight_layout()  # Adjust layout to avoid overlap
plt.show()
