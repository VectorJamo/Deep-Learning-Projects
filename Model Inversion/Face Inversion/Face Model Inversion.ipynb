# %%
# Attempting to recover training data using model's parameters and a DCGAN that was trained on similar data
# Author: Suraj Neupane
# Written from scratch as a part of a Research Project 2025, Concordia University of Edmonton.
import numpy as np

import torch
from torch import nn
from torch.nn import functional

from torch.utils import data
from torch.utils.data import DataLoader

import torchvision
from torchvision import datasets
from torchvision import transforms

import pickle

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
torch.__version__
# Out:
# '2.5.1+cu118'

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
device
# Out:
# 'cuda'

# %%
# DCGAN Implementation Class
# Discriminator
class Discriminator(nn.Module):
    def __init__(self, img_channels, features_d):
        super().__init__()
        self.disc = nn.Sequential(
            # Input shape: img_channels x 64 x 64
            nn.Conv2d(
              in_channels=img_channels, out_channels=features_d, kernel_size=4, stride=2, padding=1
            ), # Output shape: features_d x 32 x 32
            nn.LeakyReLU(0.2),
            self._block(features_d, features_d*2, 4, 2, 1), # Output shape: features_d*2 x 16 x 16
            self._block(features_d*2, features_d*4, 4, 2, 1), # Output shape: features_d*4 x 8 x 8
            self._block(features_d*4, features_d*8, 4, 2, 1), # Output shape: features_d*8 x 4 x 4
           
            nn.Conv2d(in_channels=features_d*8, out_channels=1, kernel_size=4, stride=2, padding=0), # Output shape: 1 x 1
            nn.Sigmoid(),
        )

    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(0.2),
        )

    def forward(self, X):
        return self.disc(X)

# %%
# Generator
class Generator(nn.Module):
    def __init__(self, z_dim, img_channels, features_g):
        super().__init__()
        self.gen = nn.Sequential(
            self._block(z_dim, features_g*16, 4, 1, 0), # z_dim: (batch_size, 100, 1, 1) -> (batch_size, 1024, 4, 4)
            self._block(features_g*16, features_g*8, 4, 2, 1), # z_dim: (batch_size, 1024, 4, 4) -> (batch_size, 512, 8, 8)
            self._block(features_g*8, features_g*4, 4, 2, 1), # z_dim: (batch_size, 512, 8, 8) -> (batch_size, 256, 16, 16)
            self._block(features_g*4, features_g*2, 4, 2, 1), # z_dim: (batch_size, 128, 16, 16) -> (batch_size, 64, 32, 32)
            nn.ConvTranspose2d(
                in_channels=features_g*2, out_channels=img_channels, kernel_size=4, stride=2, padding=1 # z_dim: (batch_size, 64, 32, 32) -> (batch_size, 1, 64, 64)
            ),
            nn.Tanh(),
        )
        
    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.ConvTranspose2d(
                in_channels, out_channels, kernel_size, stride, padding, bias=False,
            ),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
        )

    def forward(self, X):
        return self.gen(X)

# %%
# Hyperparams
z_dim = 100
img_channels = 1
features_disc = 64
features_gen = 64

# %%
# Create the model instances
gen = Generator(z_dim, img_channels, features_gen).to(device)
disc = Discriminator(img_channels, features_disc).to(device)

# %%
# Load the trained GAN
gen.load_state_dict(torch.load('saved models/Generator.pth', weights_only=True))
disc.load_state_dict(torch.load('saved models/Discriminator.pth', weights_only=True))
# Out:
# <All keys matched successfully>

# %%
# Generate a random fake image
noise = torch.randn(1, z_dim, 1, 1).to(device)
fake_img = gen(noise)

# %%
fake_img.shape
# Out:
# torch.Size([1, 1, 64, 64])

# %%
fake_img = fake_img.squeeze()
print(fake_img.shape)
plt.axis(False)
plt.title('Fake Generated Image:')
plt.imshow(fake_img.cpu().detach(), cmap='gray')
# Out:
# torch.Size([64, 64])

# %%
# Target Model
class TFCNN(nn.Module):
    def __init__(self, n_classes):
        super().__init__()
        self.n_classes = n_classes

        self.encoder = nn.Sequential(
            nn.Conv2d(1, 32, 3, stride=1, padding=1),
            nn.ReLU(True),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, 3, stride=1, padding=1),
            nn.ReLU(True),
            nn.MaxPool2d(2),
            nn.Conv2d(64, 64, 3, stride=1, padding=1),
            nn.ReLU(True),
            nn.MaxPool2d(2),
            Reshape(),
        )

        self.h_size = 64 * 4 * 4

        self.classifier = nn.Sequential(
            nn.Linear(64 * 4 * 4, 128),
            nn.ReLU(True),
            nn.Linear(128, n_classes)
        )

    def forward(self, xs):
        code = self.encoder(xs)
        logits = self.classifier(code)
        return code, logits

# %%
class Reshape(nn.Module):
    def __init__(self,):
        super().__init__()

    def forward(self, xs):
        return xs.reshape((xs.shape[0], -1))

# %%
class ClassifyNet(nn.Module):
    def __init__(self, net, init_way, n_classes, input_size=None):
        super().__init__()
        self.net = net
        self.init_way = init_way
        self.n_classes = n_classes

        model = TFCNN(n_classes)

        self.h_size = model.h_size

        # Convo and pool layers
        self.encoder = model.encoder

        # Classifier layer
        self.classifier = nn.Linear(
            self.h_size, self.n_classes, bias=False
        )

        if self.init_way == "orth":
            ws = get_orth_weights(self.h_size, self.n_classes)
            self.classifier.load_state_dict({"weight": ws})

    def forward(self, xs):
        hs = self.encoder(xs)
        logits = self.classifier(hs)
        return hs, logits

# %%
def load_target_model(base_net, n_classes, path):
    # Create the base model
    model = ClassifyNet(net=base_net, init_way='none', n_classes=n_classes)
    # Load the model
    model.load_state_dict(torch.load(path, weights_only=True))

    return model

# %%
# Target Model Loading
BASE_NET = 'TFCNN'
DATASET = 'face'
N_CLASSES = 40

target_model = load_target_model(base_net=BASE_NET, n_classes=N_CLASSES, path='saved models/fedavg_global_model.pth').to(device)
print('Model loaded successfully!')
target_model.eval()

num_params = sum(p.numel() for p in target_model.parameters())
print('Number of parameters in the loaded model:', num_params)
# Out:
# Model loaded successfully!
# Number of parameters in the loaded model: 96704

# %%
# Do Model Inversion
# Define a learnable latent vector
z = torch.randn(1, z_dim, 1, 1, requires_grad=True)  # Start with random noise
z.shape
# Out:
# torch.Size([1, 100, 1, 1])

# %%
learning_rate = 0.01
target_class = 1 # The second class

# Create the optimizer
optimizer = torch.optim.Adam([z], lr=learning_rate)

# Loss function (e.g., Cross-Entropy with classifier outputs)
loss_fn = nn.CrossEntropyLoss()
target_class = torch.tensor([target_class])  # Set the target class

# %%
# Optimization loop to find the best z
rounds = 1000
for i in range(rounds):
    optimizer.zero_grad()
    
    generated_image = gen(z.to(device))  # Generate an image from the latent vector
    #generated_image = generated_image.repeat(1, 1, 1, 1)
    generated_image = functional.interpolate(generated_image, size=(32, 32), mode='nearest')
    #print(generated_image.shape)
    hs, prediction_logits = target_model(generated_image)  # Classifier output
    #print(prediction_logits)
    #print(type(prediction_logits))
    loss = loss_fn(prediction_logits, target_class.to(device))  # Minimize difference with true class
    loss.backward()
    optimizer.step()

    if i % 50 == 0:
        print(f"Step {i}, Loss: {loss.item()}")
# Out:
# Step 0, Loss: 4.481307029724121
# Step 50, Loss: 2.3635330200195312
# Step 100, Loss: 1.480263113975525
# Step 150, Loss: 1.0058743953704834
# Step 200, Loss: 0.7937294244766235
# Step 250, Loss: 0.695699155330658
# Step 300, Loss: 0.6522149443626404
# Step 350, Loss: 0.6246617436408997
# Step 400, Loss: 0.606539785861969
# Step 450, Loss: 0.5890454053878784
# Step 500, Loss: 0.5680529475212097
# Step 550, Loss: 0.5492509603500366
# Step 600, Loss: 0.5370818972587585
# Step 650, Loss: 0.5275996923446655
# Step 700, Loss: 0.5142940282821655
# Step 750, Loss: 0.5016738176345825
# Step 800, Loss: 0.4935735762119293
# Step 850, Loss: 0.4856188893318176
# Step 900, Loss: 0.47314032912254333
# Step 950, Loss: 0.45823508501052856

# %%
# Display the generated image
img = gen(z.to(device)).squeeze(dim=0).squeeze(dim=0)
print(img.shape)
# Out:
# torch.Size([64, 64])

# %%
plt.axis(False)
plt.title('Recovered Image:')
plt.imshow(img.cpu().detach(), cmap='gray')

# %%
recovered_images = []

# %%
# Generate a series of recovered images 
# 1. Rotate over the 4 classes randomly 0, 1, 2, 3
# 2. Have a random seed initialization for the latent vector z in every iteration
# 3. Optimize the latent vector and recover a potential training data
# 4. Store each of the recovered images in their own list
target_classes = 16
latent_vectors = []
for x in range(0, target_classes):
    target_class = x
    target_class = torch.tensor([target_class])

    learning_rate = 0.01

    # Define a learnable latent vector
    z = torch.randn(1, z_dim, 1, 1, requires_grad=True)  # Start with random noise
    # Create the optimizer
    optimizer = torch.optim.Adam([z], lr=learning_rate)
    
    # Loss function (e.g., Cross-Entropy with classifier outputs)
    loss_fn = nn.CrossEntropyLoss()
    
    rounds = 1000
    for i in range(rounds):
        optimizer.zero_grad()
        
        generated_image = gen(z.to(device))  # Generate an image from the latent vector
        #generated_image = generated_image.repeat(1, 3, 1, 1)
        generated_image = functional.interpolate(generated_image, size=(32, 32), mode='nearest')
        #print(generated_image.shape)
        hs, prediction_logits = target_model(generated_image)  # Classifier output
        #print(prediction_logits)
        #print(type(prediction_logits))
        loss = loss_fn(prediction_logits, target_class.to(device))  # Minimize difference with true class
        loss.backward()
        optimizer.step()
    
        if i % 50 == 0:
            print(f"Class: {target_class}")
            print(f"Step {i}, Loss: {loss.item()}")
            
    latent_vectors.append(z)
# Out:
# Class: tensor([0])
# Step 0, Loss: 9.280211448669434
# Class: tensor([0])
# Step 50, Loss: 4.637145042419434
# Class: tensor([0])
# Step 100, Loss: 4.0070929527282715
# Class: tensor([0])
# Step 150, Loss: 3.6364572048187256
# Class: tensor([0])
# Step 200, Loss: 3.438758373260498
# Class: tensor([0])
# Step 250, Loss: 3.2065234184265137
# Class: tensor([0])
# Step 300, Loss: 3.054699420928955
# Class: tensor([0])
# Step 350, Loss: 2.935415744781494
# Class: tensor([0])
# Step 400, Loss: 2.8459746837615967
# Class: tensor([0])
# Step 450, Loss: 2.7778258323669434
# Class: tensor([0])
# Step 500, Loss: 2.726529121398926
# Class: tensor([0])
# Step 550, Loss: 2.6747288703918457
# Class: tensor([0])
# Step 600, Loss: 2.616159200668335
# Class: tensor([0])
# Step 650, Loss: 2.554938793182373
# Class: tensor([0])
# Step 700, Loss: 2.507932662963867
# Class: tensor([0])
# Step 750, Loss: 2.457726001739502
# Class: tensor([0])
# Step 800, Loss: 2.4148991107940674
# Class: tensor([0])
# Step 850, Loss: 2.3819868564605713
# Class: tensor([0])
# Step 900, Loss: 2.354659080505371
# Class: tensor([0])
# Step 950, Loss: 2.3340821266174316
# Class: tensor([1])
# Step 0, Loss: 3.644984483718872
# Class: tensor([1])
# Step 50, Loss: 1.3795263767242432
# Class: tensor([1])
# Step 100, Loss: 1.1459311246871948
# Class: tensor([1])
# Step 150, Loss: 0.9712867736816406
# Class: tensor([1])
# Step 200, Loss: 0.755730390548706
# Class: tensor([1])
# Step 250, Loss: 0.6317964196205139
# Class: tensor([1])
# Class: tensor([3])
# Step 900, Loss: 2.2760415077209473
# Class: tensor([3])
# Step 950, Loss: 2.252110004425049
# Class: tensor([4])
# Step 0, Loss: 8.310098648071289
# Class: tensor([4])
# Step 50, Loss: 3.8400745391845703
# Class: tensor([4])
# Step 100, Loss: 3.3294055461883545
# Class: tensor([4])
# Step 150, Loss: 3.148777961730957
# Class: tensor([4])
# Step 200, Loss: 3.0187156200408936
# Class: tensor([4])
# Step 250, Loss: 2.9206953048706055
# Class: tensor([4])
# Step 300, Loss: 2.841325521469116
# Class: tensor([4])
# Step 350, Loss: 2.7902331352233887
# Class: tensor([4])
# Step 400, Loss: 2.752855062484741
# Class: tensor([4])
# Step 450, Loss: 2.72065806388855
# Class: tensor([4])
# Step 500, Loss: 2.692868709564209
# Class: tensor([4])
# Step 550, Loss: 2.6606924533843994
# Class: tensor([4])
# Step 600, Loss: 2.6283457279205322
# Class: tensor([4])
# Step 650, Loss: 2.6021108627319336
# Class: tensor([4])
# Step 700, Loss: 2.560473918914795
# Class: tensor([4])
# Step 750, Loss: 2.5084941387176514
# Class: tensor([4])
# Step 800, Loss: 2.458982467651367
# Class: tensor([4])
# Step 850, Loss: 2.3992795944213867
# Class: tensor([4])
# Step 900, Loss: 2.3752875328063965
# Class: tensor([4])
# Step 950, Loss: 2.3260087966918945
# Class: tensor([5])
# Step 0, Loss: 7.1815385818481445
# Class: tensor([5])
# Step 50, Loss: 3.550436496734619
# Class: tensor([5])
# Step 100, Loss: 2.553229331970215
# Class: tensor([5])
# Step 150, Loss: 2.4439778327941895
# Class: tensor([5])
# Step 200, Loss: 2.3669979572296143
# Class: tensor([5])
# Step 250, Loss: 2.2939963340759277
# Class: tensor([5])
# Step 300, Loss: 2.2101614475250244
# Class: tensor([5])
# Step 350, Loss: 2.149658441543579
# Class: tensor([5])
# Step 400, Loss: 2.097931146621704
# Class: tensor([5])
# Step 450, Loss: 2.0519096851348877
# Class: tensor([5])
# Step 500, Loss: 2.014511823654175
# Class: tensor([5])
# Step 550, Loss: 1.9596787691116333
# Class: tensor([5])
# Step 600, Loss: 1.8349684476852417
# Class: tensor([5])
# Step 650, Loss: 1.6737682819366455
# Class: tensor([5])
# Step 700, Loss: 1.5956268310546875
# Class: tensor([5])
# Step 750, Loss: 1.5155531167984009
# Class: tensor([5])
# Step 800, Loss: 1.2419395446777344
# Class: tensor([5])
# Step 850, Loss: 1.11411452293396
# Class: tensor([5])
# Step 900, Loss: 1.0555753707885742
# Class: tensor([5])
# Step 950, Loss: 1.024117112159729
# Class: tensor([6])
# Step 0, Loss: 3.093832492828369
# Class: tensor([6])
# Step 50, Loss: 1.7164175510406494
# Class: tensor([6])
# Step 100, Loss: 1.2455530166625977
# Class: tensor([6])
# Step 150, Loss: 1.098241925239563
# Class: tensor([6])
# Step 200, Loss: 1.0411694049835205
# Class: tensor([6])
# Step 250, Loss: 0.9924993515014648
# Class: tensor([6])
# Step 300, Loss: 0.9560160040855408
# Class: tensor([6])
# Step 350, Loss: 0.9098870754241943
# Class: tensor([6])
# Step 400, Loss: 0.8534024953842163
# Class: tensor([6])
# Step 450, Loss: 0.8141623735427856
# Class: tensor([6])
# Step 500, Loss: 0.7248857021331787
# Class: tensor([6])
# Step 550, Loss: 0.6783808469772339
# Class: tensor([6])
# Step 600, Loss: 0.6552891731262207
# Class: tensor([6])
# Step 650, Loss: 0.6386675834655762
# Class: tensor([6])
# Step 700, Loss: 0.6251937747001648
# Class: tensor([6])
# Step 750, Loss: 0.6157525181770325
# Class: tensor([6])
# Step 800, Loss: 0.6092116832733154
# Class: tensor([6])
# Step 850, Loss: 0.600717306137085
# Class: tensor([6])
# Step 900, Loss: 0.5947443246841431
# Class: tensor([6])
# Step 950, Loss: 0.5862941741943359
# Class: tensor([7])
# Step 0, Loss: 6.31025505065918
# Class: tensor([7])
# Step 50, Loss: 3.8094449043273926
# Class: tensor([7])
# Step 100, Loss: 3.2291102409362793
# Class: tensor([7])
# Step 150, Loss: 2.731326103210449
# Class: tensor([7])
# Step 200, Loss: 2.507956027984619
# Class: tensor([7])
# Step 250, Loss: 2.4313857555389404
# Class: tensor([7])
# Step 300, Loss: 2.354536294937134
# Class: tensor([7])
# Step 350, Loss: 2.291363477706909
# Class: tensor([7])
# Step 400, Loss: 2.2534055709838867
# Class: tensor([7])
# Step 450, Loss: 2.226970911026001
# Class: tensor([7])
# Step 500, Loss: 2.2016537189483643
# Class: tensor([7])
# Step 550, Loss: 2.181196928024292
# Class: tensor([7])
# Step 600, Loss: 2.163503885269165
# Class: tensor([7])
# Step 650, Loss: 2.1534852981567383
# Class: tensor([7])
# Step 700, Loss: 2.1457440853118896
# Class: tensor([7])
# Step 750, Loss: 2.1364946365356445
# Class: tensor([7])
# Step 800, Loss: 2.127452850341797
# Class: tensor([7])
# Step 850, Loss: 2.1181721687316895
# Class: tensor([7])
# Step 900, Loss: 2.1088778972625732
# Class: tensor([7])
# Step 950, Loss: 2.1006436347961426
# Class: tensor([8])
# Step 0, Loss: 5.054905891418457
# Class: tensor([8])
# Step 50, Loss: 3.6984643936157227
# Class: tensor([8])
# Step 100, Loss: 2.8706908226013184
# Class: tensor([8])
# Step 150, Loss: 2.2531211376190186
# Class: tensor([8])
# Step 200, Loss: 2.0665550231933594
# Class: tensor([8])
# Step 250, Loss: 1.9595099687576294
# Class: tensor([8])
# Step 300, Loss: 1.8825528621673584
# Class: tensor([8])
# Step 350, Loss: 1.8110190629959106
# Class: tensor([8])
# Step 400, Loss: 1.7467739582061768
# Class: tensor([8])
# Step 450, Loss: 1.7120903730392456
# Class: tensor([8])
# Step 500, Loss: 1.6896498203277588
# Class: tensor([8])
# Step 550, Loss: 1.672545313835144
# Class: tensor([8])
# Step 600, Loss: 1.6543991565704346
# Class: tensor([8])
# Step 650, Loss: 1.6356513500213623
# Class: tensor([8])
# Step 700, Loss: 1.6135852336883545
# Class: tensor([8])
# Step 750, Loss: 1.5928395986557007
# Class: tensor([8])
# Step 800, Loss: 1.5758845806121826
# Class: tensor([8])
# Step 850, Loss: 1.5584913492202759
# Class: tensor([8])
# Step 900, Loss: 1.542093276977539
# Class: tensor([8])
# Step 950, Loss: 1.523255467414856
# Class: tensor([9])
# Class: tensor([11])
# Step 600, Loss: 1.6383390426635742
# Class: tensor([11])
# Step 650, Loss: 1.6209008693695068
# Class: tensor([11])
# Step 700, Loss: 1.6102123260498047
# Class: tensor([11])
# Step 750, Loss: 1.6037189960479736
# Class: tensor([11])
# Step 800, Loss: 1.5999512672424316
# Class: tensor([11])
# Step 850, Loss: 1.595623254776001
# Class: tensor([11])
# Step 900, Loss: 1.5919430255889893
# Class: tensor([11])
# Step 950, Loss: 1.5879156589508057
# Class: tensor([12])
# Step 0, Loss: 6.850091457366943
# Class: tensor([12])
# Step 50, Loss: 3.7138681411743164
# Class: tensor([12])
# Step 100, Loss: 3.3893980979919434
# Class: tensor([12])
# Step 150, Loss: 3.2346558570861816
# Class: tensor([12])
# Step 200, Loss: 3.0770320892333984
# Class: tensor([12])
# Step 250, Loss: 2.9429616928100586
# Class: tensor([12])
# Step 300, Loss: 2.8422670364379883
# Class: tensor([12])
# Step 350, Loss: 2.7482073307037354
# Class: tensor([12])
# Step 400, Loss: 2.6745707988739014
# Class: tensor([12])
# Step 450, Loss: 2.5920586585998535
# Class: tensor([12])
# Step 500, Loss: 2.4840054512023926
# Class: tensor([12])
# Step 550, Loss: 2.402965545654297
# Class: tensor([12])
# Step 600, Loss: 2.2945122718811035
# Class: tensor([12])
# Step 650, Loss: 2.2538716793060303
# Class: tensor([12])
# Step 700, Loss: 2.2222118377685547
# Class: tensor([12])
# Step 750, Loss: 2.2008488178253174
# Class: tensor([12])
# Step 800, Loss: 2.1795783042907715
# Class: tensor([12])
# Step 850, Loss: 2.1573073863983154
# Class: tensor([12])
# Step 900, Loss: 2.1254496574401855
# Class: tensor([12])
# Step 950, Loss: 2.0903115272521973
# Class: tensor([13])
# Step 0, Loss: 2.8747639656066895
# Class: tensor([13])
# Step 50, Loss: 2.4573259353637695
# Class: tensor([13])
# Step 100, Loss: 2.0586695671081543
# Class: tensor([13])
# Step 150, Loss: 1.2759469747543335
# Class: tensor([13])
# Step 200, Loss: 1.1323484182357788
# Class: tensor([13])
# Step 250, Loss: 1.063017725944519
# Class: tensor([13])
# Step 300, Loss: 1.0245277881622314
# Class: tensor([13])
# Step 350, Loss: 0.9949902892112732
# Class: tensor([13])
# Step 400, Loss: 0.9539437294006348
# Class: tensor([13])
# Step 450, Loss: 0.9197753667831421
# Class: tensor([13])
# Step 500, Loss: 0.8902627229690552
# Class: tensor([13])
# Step 550, Loss: 0.8693901300430298
# Class: tensor([13])
# Step 600, Loss: 0.8412736058235168
# Class: tensor([13])
# Step 650, Loss: 0.8088730573654175
# Class: tensor([13])
# Step 700, Loss: 0.7875093221664429
# Class: tensor([13])
# Step 750, Loss: 0.764904260635376
# Class: tensor([13])
# Step 800, Loss: 0.743521511554718
# Class: tensor([13])
# Step 850, Loss: 0.728296160697937
# Class: tensor([13])
# Step 900, Loss: 0.7191402316093445
# Class: tensor([13])
# Step 950, Loss: 0.7074618935585022
# Class: tensor([14])
# Step 0, Loss: 4.72941780090332
# Class: tensor([14])
# Step 50, Loss: 3.909733533859253
# Class: tensor([14])
# Step 100, Loss: 3.333806276321411
# Class: tensor([14])
# Step 150, Loss: 2.7210922241210938
# Class: tensor([14])
# Step 200, Loss: 2.576977252960205
# Class: tensor([14])
# Step 250, Loss: 2.511385917663574
# Class: tensor([14])
# Step 300, Loss: 2.447384834289551
# Class: tensor([14])
# Step 350, Loss: 2.3905673027038574
# Class: tensor([14])
# Step 400, Loss: 2.342012643814087
# Class: tensor([14])
# Step 450, Loss: 2.295496702194214
# Class: tensor([14])
# Step 500, Loss: 2.2674176692962646
# Class: tensor([14])
# Step 550, Loss: 2.2462637424468994
# Class: tensor([14])
# Step 600, Loss: 2.2233059406280518
# Class: tensor([14])
# Step 650, Loss: 2.199169874191284
# Class: tensor([14])
# Step 700, Loss: 2.17617130279541
# Class: tensor([14])
# Step 750, Loss: 2.158748149871826
# Class: tensor([14])
# Step 800, Loss: 2.1391608715057373
# Class: tensor([14])
# Step 850, Loss: 2.118778705596924
# Class: tensor([14])
# Step 900, Loss: 2.106020927429199
# Class: tensor([14])
# Step 950, Loss: 2.095505714416504
# Class: tensor([15])
# Step 0, Loss: 3.5171709060668945
# Class: tensor([15])
# Step 50, Loss: 1.9961166381835938
# Class: tensor([15])
# Step 100, Loss: 1.8068921566009521
# Class: tensor([15])
# Step 150, Loss: 1.6928175687789917
# Class: tensor([15])
# Step 200, Loss: 1.5627093315124512
# Class: tensor([15])
# Step 250, Loss: 1.4950454235076904
# Class: tensor([15])
# Step 300, Loss: 1.4088813066482544
# Class: tensor([15])
# Step 350, Loss: 1.3480123281478882
# Class: tensor([15])
# Step 400, Loss: 1.2958714962005615
# Class: tensor([15])
# Step 450, Loss: 1.2620295286178589
# Class: tensor([15])
# Step 500, Loss: 1.235567569732666
# Class: tensor([15])
# Step 550, Loss: 1.2207833528518677
# Class: tensor([15])
# Step 600, Loss: 1.2011122703552246
# Class: tensor([15])
# Step 650, Loss: 1.1842821836471558
# Class: tensor([15])
# Step 700, Loss: 1.1670538187026978
# Class: tensor([15])
# Step 750, Loss: 1.1486091613769531
# Class: tensor([15])
# Step 800, Loss: 1.1358401775360107
# Class: tensor([15])
# Step 850, Loss: 1.1206326484680176
# Class: tensor([15])
# Step 900, Loss: 1.1087405681610107
# Class: tensor([15])
# Step 950, Loss: 1.0967155694961548

# %%
# Display the generated image
img = gen(latent_vectors[0].to(device)).squeeze(dim=0).squeeze(dim=0)
print(img.shape)
# Out:
# torch.Size([64, 64])

# %%
plt.imshow(img.cpu().detach(), cmap='gray')

# %%
recovered_1 = []
for lv in latent_vectors:
    recovered_1.append(lv)

# %%
len(recovered_1)
# Out:
# 16

# %%
for i in range(0, len(recovered_1)):
    img = gen(recovered_1[i].to(device)).squeeze(dim=0).squeeze(dim=0)
    recovered_images.append(img)

# %%
len(recovered_images)
# Out:
# 28

# %%
# Create a figure with 2 rows and 4 columns
fig, axes = plt.subplots(4, 4, figsize=(10, 5))

# Flatten the 2D axes array and iterate over it
for ax, img in zip(axes.flatten(), recovered_images):
    ax.imshow(img.cpu().detach(), cmap='gray')  # Display the image
    ax.axis('off')  # Hide axes

plt.tight_layout()  # Adjust layout to avoid overlap
plt.show()
