# %%
# Attempting to recover training data using model's parameters and a DCGAN that was trained on similar data
# Author: Suraj Neupane
# Written from scratch as a part of a Research Project 2025, Concordia University of Edmonton.
import numpy as np

import torch
from torch import nn
from torch.nn import functional

from torch.utils import data
from torch.utils.data import DataLoader

import torchvision
from torchvision import datasets
from torchvision import transforms

import pickle

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
torch.__version__
# Out:
# '2.5.1+cu118'

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
device
# Out:
# 'cuda'

# %%
# DCGAN Implementation Class
# Discriminator
class Discriminator(nn.Module):
    def __init__(self, img_channels, features_d):
        super().__init__()
        self.disc = nn.Sequential(
            # Input shape: img_channels x 64 x 64
            nn.Conv2d(
              in_channels=img_channels, out_channels=features_d, kernel_size=4, stride=2, padding=1
            ), # Output shape: features_d x 32 x 32
            nn.LeakyReLU(0.2),
            self._block(features_d, features_d*2, 4, 2, 1), # Output shape: features_d*2 x 16 x 16
            self._block(features_d*2, features_d*4, 4, 2, 1), # Output shape: features_d*4 x 8 x 8
            self._block(features_d*4, features_d*8, 4, 2, 1), # Output shape: features_d*8 x 4 x 4
           
            nn.Conv2d(in_channels=features_d*8, out_channels=1, kernel_size=4, stride=2, padding=0), # Output shape: 1 x 1
            nn.Sigmoid(),
        )

    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(0.2),
        )

    def forward(self, X):
        return self.disc(X)

# %%
# Generator
class Generator(nn.Module):
    def __init__(self, z_dim, img_channels, features_g):
        super().__init__()
        self.gen = nn.Sequential(
            self._block(z_dim, features_g*16, 4, 1, 0), # z_dim: (batch_size, 100, 1, 1) -> (batch_size, 1024, 4, 4)
            self._block(features_g*16, features_g*8, 4, 2, 1), # z_dim: (batch_size, 1024, 4, 4) -> (batch_size, 512, 8, 8)
            self._block(features_g*8, features_g*4, 4, 2, 1), # z_dim: (batch_size, 512, 8, 8) -> (batch_size, 256, 16, 16)
            self._block(features_g*4, features_g*2, 4, 2, 1), # z_dim: (batch_size, 128, 16, 16) -> (batch_size, 64, 32, 32)
            nn.ConvTranspose2d(
                in_channels=features_g*2, out_channels=img_channels, kernel_size=4, stride=2, padding=1 # z_dim: (batch_size, 64, 32, 32) -> (batch_size, 1, 64, 64)
            ),
            nn.Tanh(),
        )
        
    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.ConvTranspose2d(
                in_channels, out_channels, kernel_size, stride, padding, bias=False,
            ),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
        )

    def forward(self, X):
        return self.gen(X)

# %%
# Hyperparams
z_dim = 100
img_channels = 1
features_disc = 64
features_gen = 64

# %%
# Create the model instances
gen = Generator(z_dim, img_channels, features_gen).to(device)
disc = Discriminator(img_channels, features_disc).to(device)

# %%
# Load the trained GAN
gen.load_state_dict(torch.load('saved models/Generator.pth', weights_only=True))
disc.load_state_dict(torch.load('saved models/Discriminator.pth', weights_only=True))
# Out:
# <All keys matched successfully>

# %%
# Generate a random fake image
noise = torch.randn(1, z_dim, 1, 1).to(device)
fake_img = gen(noise)

# %%
fake_img.shape
# Out:
# torch.Size([1, 1, 64, 64])

# %%
fake_img = fake_img.squeeze()
print(fake_img.shape)
plt.axis(False)
plt.title('Fake Generated Image:')
plt.imshow(fake_img.cpu().detach(), cmap='gray')
# Out:
# torch.Size([64, 64])

# %%
# Target Model
class TFCNN(nn.Module):
    def __init__(self, n_classes):
        super().__init__()
        self.n_classes = n_classes

        self.encoder = nn.Sequential(
            nn.Conv2d(1, 32, 3, stride=1, padding=1),
            nn.ReLU(True),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, 3, stride=1, padding=1),
            nn.ReLU(True),
            nn.MaxPool2d(2),
            nn.Conv2d(64, 64, 3, stride=1, padding=1),
            nn.ReLU(True),
            nn.MaxPool2d(2),
            Reshape(),
        )

        self.h_size = 64 * 4 * 4

        self.classifier = nn.Sequential(
            nn.Linear(64 * 4 * 4, 128),
            nn.ReLU(True),
            nn.Linear(128, n_classes)
        )

    def forward(self, xs):
        code = self.encoder(xs)
        logits = self.classifier(code)
        return code, logits

# %%
class Reshape(nn.Module):
    def __init__(self,):
        super().__init__()

    def forward(self, xs):
        return xs.reshape((xs.shape[0], -1))

# %%
class ClassifyNet(nn.Module):
    def __init__(self, net, init_way, n_classes, input_size=None):
        super().__init__()
        self.net = net
        self.init_way = init_way
        self.n_classes = n_classes

        model = TFCNN(n_classes)

        self.h_size = model.h_size

        # Convo and pool layers
        self.encoder = model.encoder

        # Classifier layer
        self.classifier = nn.Linear(
            self.h_size, self.n_classes, bias=False
        )

        if self.init_way == "orth":
            ws = get_orth_weights(self.h_size, self.n_classes)
            self.classifier.load_state_dict({"weight": ws})

    def forward(self, xs):
        hs = self.encoder(xs)
        logits = self.classifier(hs)
        return hs, logits

# %%
def load_target_model(base_net, n_classes, path):
    # Create the base model
    model = ClassifyNet(net=base_net, init_way='none', n_classes=n_classes)
    # Load the model
    model.load_state_dict(torch.load(path, weights_only=True))

    return model

# %%
# Target Model Loading
BASE_NET = 'TFCNN'
DATASET = 'face'
N_CLASSES = 40

target_model = load_target_model(base_net=BASE_NET, n_classes=N_CLASSES, path='saved models/fedavg_global_model.pth').to(device)
print('Model loaded successfully!')
target_model.eval()

num_params = sum(p.numel() for p in target_model.parameters())
print('Number of parameters in the loaded model:', num_params)
# Out:
# Model loaded successfully!
# Number of parameters in the loaded model: 96704

# %%
class RecoveredImage:
    def __init__(self, label, latent_vectors):
        self.label = label
        self.latent_vector = latent_vectors

# %%
recovered_images = []
learning_rate = 0.01
for i in range(0, 40):
    # Define a learnable latent vector
    z = torch.randn(1, z_dim, 1, 1, requires_grad=True)  # Start with random noise
    z.shape

    target_class = torch.tensor([i])  # Set the target class

    # Create the optimizer
    optimizer = torch.optim.Adam([z], lr=learning_rate)
    
    # Loss function (e.g., Cross-Entropy with classifier outputs)
    loss_fn = nn.CrossEntropyLoss()
    
    rounds = 3000
    for j in range(rounds):
        optimizer.zero_grad()
        
        generated_image = gen(z.to(device))  # Generate an image from the latent vector
        #generated_image = generated_image.repeat(1, 1, 1, 1)
        generated_image = functional.interpolate(generated_image, size=(32, 32), mode='nearest')
        #print(generated_image.shape)
        hs, prediction_logits = target_model(generated_image)  # Classifier output
        #print(prediction_logits)
        #print(type(prediction_logits))
        loss = loss_fn(prediction_logits, target_class.to(device))  # Minimize difference with true class
        loss.backward()
        optimizer.step()
    
        if j % 50 == 0:
            print(f"Recovering Image of class {i}. Step {j}, Loss: {loss.item()}")
            
    recovered_images.append(RecoveredImage(i, z))
# Out:
# Recovering Image of class 0. Step 0, Loss: 8.52090835571289
# Recovering Image of class 0. Step 50, Loss: 3.97540020942688
# Recovering Image of class 0. Step 100, Loss: 3.4516377449035645
# Recovering Image of class 0. Step 150, Loss: 3.2413899898529053
# Recovering Image of class 0. Step 200, Loss: 3.13033390045166
# Recovering Image of class 0. Step 250, Loss: 2.999574661254883
# Recovering Image of class 0. Step 300, Loss: 2.924386739730835
# Recovering Image of class 0. Step 350, Loss: 2.8632936477661133
# Recovering Image of class 0. Step 400, Loss: 2.803525447845459
# Recovering Image of class 0. Step 450, Loss: 2.757234811782837
# Recovering Image of class 0. Step 500, Loss: 2.714148998260498
# Recovering Image of class 0. Step 550, Loss: 2.6591475009918213
# Recovering Image of class 0. Step 600, Loss: 2.6114015579223633
# Recovering Image of class 0. Step 650, Loss: 2.572950839996338
# Recovering Image of class 0. Step 700, Loss: 2.532442808151245
# Recovering Image of class 0. Step 750, Loss: 2.4943652153015137
# Recovering Image of class 0. Step 800, Loss: 2.4265084266662598
# Recovering Image of class 0. Step 850, Loss: 2.357555389404297
# Recovering Image of class 0. Step 900, Loss: 2.3030154705047607
# Recovering Image of class 0. Step 950, Loss: 2.2473974227905273
# Recovering Image of class 0. Step 1000, Loss: 2.195797920227051
# Recovering Image of class 0. Step 1050, Loss: 2.1393508911132812
# Recovering Image of class 0. Step 1100, Loss: 2.052884340286255
# Recovering Image of class 0. Step 1150, Loss: 1.9865243434906006
# Recovering Image of class 0. Step 1200, Loss: 1.9620695114135742
# Recovering Image of class 0. Step 1250, Loss: 1.9440261125564575
# Recovering Image of class 0. Step 1300, Loss: 1.9342522621154785
# Recovering Image of class 0. Step 1350, Loss: 1.9324378967285156
# Recovering Image of class 0. Step 1400, Loss: 1.9203999042510986
# Recovering Image of class 0. Step 1450, Loss: 1.9151418209075928
# Recovering Image of class 0. Step 1500, Loss: 1.9092168807983398
# Recovering Image of class 0. Step 1550, Loss: 1.9039661884307861
# Recovering Image of class 0. Step 1600, Loss: 1.9010672569274902
# Recovering Image of class 0. Step 1650, Loss: 1.9015928506851196
# Recovering Image of class 0. Step 1700, Loss: 1.8950648307800293
# Recovering Image of class 0. Step 1750, Loss: 1.8911653757095337
# Recovering Image of class 0. Step 1800, Loss: 1.8850855827331543
# Recovering Image of class 0. Step 1850, Loss: 1.8851046562194824
# Recovering Image of class 0. Step 1900, Loss: 1.8811371326446533
# Recovering Image of class 0. Step 1950, Loss: 1.8778748512268066
# Recovering Image of class 0. Step 2000, Loss: 1.8788423538208008
# Recovering Image of class 0. Step 2050, Loss: 1.8732208013534546
# Recovering Image of class 0. Step 2100, Loss: 1.8724857568740845
# Recovering Image of class 0. Step 2150, Loss: 1.8620355129241943
# Recovering Image of class 0. Step 2200, Loss: 1.854204773902893
# Recovering Image of class 0. Step 2250, Loss: 1.8552249670028687
# Recovering Image of class 0. Step 2300, Loss: 1.804945945739746
# Recovering Image of class 9. Step 2850, Loss: 2.320683240890503
# Recovering Image of class 9. Step 2900, Loss: 2.3117337226867676
# Recovering Image of class 9. Step 2950, Loss: 2.307006359100342
# Recovering Image of class 10. Step 0, Loss: 1.591530442237854
# Recovering Image of class 10. Step 50, Loss: 0.7857486605644226
# Recovering Image of class 10. Step 100, Loss: 0.5408379435539246
# Recovering Image of class 10. Step 150, Loss: 0.46051597595214844
# Recovering Image of class 10. Step 200, Loss: 0.4094913601875305
# Recovering Image of class 10. Step 250, Loss: 0.36129239201545715
# Recovering Image of class 10. Step 300, Loss: 0.3347332179546356
# Recovering Image of class 10. Step 350, Loss: 0.3089412450790405
# Recovering Image of class 10. Step 400, Loss: 0.2885953485965729
# Recovering Image of class 10. Step 450, Loss: 0.2688565254211426
# Recovering Image of class 10. Step 500, Loss: 0.25612133741378784
# Recovering Image of class 10. Step 550, Loss: 0.24606652557849884
# Recovering Image of class 10. Step 600, Loss: 0.23625417053699493
# Recovering Image of class 10. Step 650, Loss: 0.229141503572464
# Recovering Image of class 10. Step 700, Loss: 0.22352389991283417
# Recovering Image of class 10. Step 750, Loss: 0.21871308982372284
# Recovering Image of class 10. Step 800, Loss: 0.2150261104106903
# Recovering Image of class 10. Step 850, Loss: 0.21117377281188965
# Recovering Image of class 10. Step 900, Loss: 0.20770448446273804
# Recovering Image of class 10. Step 950, Loss: 0.20553499460220337
# Recovering Image of class 10. Step 1000, Loss: 0.20333287119865417
# Recovering Image of class 10. Step 1050, Loss: 0.20079922676086426
# Recovering Image of class 10. Step 1100, Loss: 0.19726336002349854
# Recovering Image of class 10. Step 1150, Loss: 0.1927119493484497
# Recovering Image of class 10. Step 1200, Loss: 0.18811306357383728
# Recovering Image of class 10. Step 1250, Loss: 0.18523479998111725
# Recovering Image of class 10. Step 1300, Loss: 0.18258342146873474
# Recovering Image of class 10. Step 1350, Loss: 0.18178869783878326
# Recovering Image of class 10. Step 1400, Loss: 0.18096089363098145
# Recovering Image of class 10. Step 1450, Loss: 0.18034245073795319
# Recovering Image of class 10. Step 1500, Loss: 0.17994412779808044
# Recovering Image of class 10. Step 1550, Loss: 0.17909567058086395
# Recovering Image of class 10. Step 1600, Loss: 0.1786722093820572
# Recovering Image of class 10. Step 1650, Loss: 0.17843160033226013
# Recovering Image of class 10. Step 1700, Loss: 0.17786936461925507
# Recovering Image of class 10. Step 1750, Loss: 0.17746835947036743
# Recovering Image of class 10. Step 1800, Loss: 0.1770305335521698
# Recovering Image of class 10. Step 1850, Loss: 0.17638687789440155
# Recovering Image of class 10. Step 1900, Loss: 0.17567630112171173
# Recovering Image of class 10. Step 1950, Loss: 0.1747412234544754
# Recovering Image of class 10. Step 2000, Loss: 0.17395295202732086
# Recovering Image of class 10. Step 2050, Loss: 0.17364616692066193
# Recovering Image of class 10. Step 2100, Loss: 0.1735539734363556
# Recovering Image of class 10. Step 2150, Loss: 0.17300313711166382
# Recovering Image of class 10. Step 2200, Loss: 0.172712504863739
# Recovering Image of class 10. Step 2250, Loss: 0.17244206368923187
# Recovering Image of class 10. Step 2300, Loss: 0.17156943678855896
# Recovering Image of class 10. Step 2350, Loss: 0.1705349236726761
# Recovering Image of class 10. Step 2400, Loss: 0.17020094394683838
# Recovering Image of class 10. Step 2450, Loss: 0.16944138705730438
# Recovering Image of class 10. Step 2500, Loss: 0.1693456918001175
# Recovering Image of class 10. Step 2550, Loss: 0.16889633238315582
# Recovering Image of class 10. Step 2600, Loss: 0.1684369146823883
# Recovering Image of class 10. Step 2650, Loss: 0.16811160743236542
# Recovering Image of class 10. Step 2700, Loss: 0.16756057739257812
# Recovering Image of class 10. Step 2750, Loss: 0.1668805330991745
# Recovering Image of class 10. Step 2800, Loss: 0.1657712757587433
# Recovering Image of class 10. Step 2850, Loss: 0.1649370789527893
# Recovering Image of class 10. Step 2900, Loss: 0.1634690761566162
# Recovering Image of class 10. Step 2950, Loss: 0.16289401054382324
# Recovering Image of class 11. Step 0, Loss: 5.0049309730529785
# Recovering Image of class 11. Step 50, Loss: 2.804776191711426
# Recovering Image of class 11. Step 100, Loss: 2.6154966354370117
# Recovering Image of class 11. Step 150, Loss: 2.4746060371398926
# Recovering Image of class 11. Step 200, Loss: 2.325955867767334
# Recovering Image of class 11. Step 250, Loss: 2.196305513381958
# Recovering Image of class 11. Step 300, Loss: 2.0870895385742188
# Recovering Image of class 11. Step 350, Loss: 2.0078999996185303
# Recovering Image of class 11. Step 400, Loss: 1.9370231628417969
# Recovering Image of class 11. Step 450, Loss: 1.8738560676574707
# Recovering Image of class 11. Step 500, Loss: 1.79438054561615
# Recovering Image of class 11. Step 550, Loss: 1.7276053428649902
# Recovering Image of class 11. Step 600, Loss: 1.6780192852020264
# Recovering Image of class 11. Step 650, Loss: 1.6323760747909546
# Recovering Image of class 11. Step 700, Loss: 1.586609125137329
# Recovering Image of class 11. Step 750, Loss: 1.558980941772461
# Recovering Image of class 11. Step 800, Loss: 1.5313342809677124
# Recovering Image of class 11. Step 850, Loss: 1.5068918466567993
# Recovering Image of class 11. Step 900, Loss: 1.476578712463379
# Recovering Image of class 11. Step 950, Loss: 1.4512234926223755
# Recovering Image of class 11. Step 1000, Loss: 1.4304683208465576
# Recovering Image of class 11. Step 1050, Loss: 1.4079569578170776
# Recovering Image of class 11. Step 1100, Loss: 1.3942354917526245
# Recovering Image of class 11. Step 1150, Loss: 1.384470820426941
# Recovering Image of class 11. Step 1200, Loss: 1.3799045085906982
# Recovering Image of class 11. Step 1250, Loss: 1.3652184009552002
# Recovering Image of class 11. Step 1300, Loss: 1.3484265804290771
# Recovering Image of class 11. Step 1350, Loss: 1.334767460823059
# Recovering Image of class 11. Step 1400, Loss: 1.325232982635498
# Recovering Image of class 11. Step 1450, Loss: 1.3174467086791992
# Recovering Image of class 11. Step 1500, Loss: 1.3019434213638306
# Recovering Image of class 11. Step 1550, Loss: 1.2899702787399292
# Recovering Image of class 11. Step 1600, Loss: 1.2819470167160034
# Recovering Image of class 11. Step 1650, Loss: 1.2666940689086914
# Recovering Image of class 11. Step 1700, Loss: 1.2569836378097534
# Recovering Image of class 11. Step 1750, Loss: 1.25104558467865
# Recovering Image of class 11. Step 1800, Loss: 1.248708724975586
# Recovering Image of class 11. Step 1850, Loss: 1.2439409494400024
# Recovering Image of class 11. Step 1900, Loss: 1.2408409118652344
# Recovering Image of class 11. Step 1950, Loss: 1.2394465208053589
# Recovering Image of class 11. Step 2000, Loss: 1.2370989322662354
# Recovering Image of class 11. Step 2050, Loss: 1.2266837358474731
# Recovering Image of class 11. Step 2100, Loss: 1.2209585905075073
# Recovering Image of class 11. Step 2150, Loss: 1.214280366897583
# Recovering Image of class 11. Step 2200, Loss: 1.2078055143356323
# Recovering Image of class 11. Step 2250, Loss: 1.2022862434387207
# Recovering Image of class 11. Step 2300, Loss: 1.1962850093841553
# Recovering Image of class 11. Step 2350, Loss: 1.1897609233856201
# Recovering Image of class 11. Step 2400, Loss: 1.1841899156570435
# Recovering Image of class 11. Step 2450, Loss: 1.1791744232177734
# Recovering Image of class 11. Step 2500, Loss: 1.1783814430236816
# Recovering Image of class 11. Step 2550, Loss: 1.17674720287323
# Recovering Image of class 11. Step 2600, Loss: 1.1742101907730103
# Recovering Image of class 11. Step 2650, Loss: 1.170013666152954
# Recovering Image of class 11. Step 2700, Loss: 1.1712006330490112
# Recovering Image of class 11. Step 2750, Loss: 1.1687010526657104
# Recovering Image of class 11. Step 2800, Loss: 1.168980360031128
# Recovering Image of class 11. Step 2850, Loss: 1.1661914587020874
# Recovering Image of class 11. Step 2900, Loss: 1.1671178340911865
# Recovering Image of class 11. Step 2950, Loss: 1.1754367351531982
# Recovering Image of class 12. Step 0, Loss: 5.070884704589844
# Recovering Image of class 12. Step 50, Loss: 3.5646495819091797
# Recovering Image of class 12. Step 100, Loss: 3.2806272506713867
# Recovering Image of class 12. Step 150, Loss: 3.0730113983154297
# Recovering Image of class 12. Step 200, Loss: 2.9193639755249023
# Recovering Image of class 12. Step 250, Loss: 2.8209526538848877
# Recovering Image of class 12. Step 300, Loss: 2.749789237976074
# Recovering Image of class 12. Step 350, Loss: 2.6879117488861084
# Recovering Image of class 12. Step 400, Loss: 2.6339621543884277
# Recovering Image of class 12. Step 450, Loss: 2.556525707244873
# Recovering Image of class 12. Step 500, Loss: 2.4806289672851562
# Recovering Image of class 12. Step 550, Loss: 2.4189281463623047
# Recovering Image of class 12. Step 600, Loss: 2.34842848777771
# Recovering Image of class 12. Step 650, Loss: 2.3061325550079346
# Recovering Image of class 12. Step 700, Loss: 2.191380739212036
# Recovering Image of class 12. Step 750, Loss: 2.06486439704895
# Recovering Image of class 12. Step 800, Loss: 1.9994076490402222
# Recovering Image of class 12. Step 850, Loss: 1.9554189443588257
# Recovering Image of class 12. Step 900, Loss: 1.9336881637573242
# Recovering Image of class 12. Step 950, Loss: 1.9125409126281738
# Recovering Image of class 12. Step 1000, Loss: 1.884395956993103
# Recovering Image of class 12. Step 1050, Loss: 1.8742785453796387
# Recovering Image of class 12. Step 1100, Loss: 1.8467501401901245
# ...
# Recovering Image of class 35. Step 2800, Loss: 1.3704640865325928
# Recovering Image of class 35. Step 2850, Loss: 1.3661727905273438
# Recovering Image of class 35. Step 2900, Loss: 1.3678631782531738
# Recovering Image of class 35. Step 2950, Loss: 1.3679109811782837
# Recovering Image of class 36. Step 0, Loss: 4.648455619812012
# Recovering Image of class 36. Step 50, Loss: 3.3452646732330322
# Recovering Image of class 36. Step 100, Loss: 2.9560964107513428
# Recovering Image of class 36. Step 150, Loss: 2.28061580657959
# Recovering Image of class 36. Step 200, Loss: 1.9818921089172363
# Recovering Image of class 36. Step 250, Loss: 1.4257440567016602
# Recovering Image of class 36. Step 300, Loss: 0.9424799680709839
# Recovering Image of class 36. Step 350, Loss: 0.8784355521202087
# Recovering Image of class 36. Step 400, Loss: 0.8284348845481873
# Recovering Image of class 36. Step 450, Loss: 0.7935048341751099
# Recovering Image of class 36. Step 500, Loss: 0.7649110555648804
# Recovering Image of class 36. Step 550, Loss: 0.7482256889343262
# Recovering Image of class 36. Step 600, Loss: 0.7358477711677551
# Recovering Image of class 36. Step 650, Loss: 0.7187356948852539
# Recovering Image of class 36. Step 700, Loss: 0.7086408138275146
# Recovering Image of class 36. Step 750, Loss: 0.700045108795166
# Recovering Image of class 36. Step 800, Loss: 0.6942968964576721
# Recovering Image of class 36. Step 850, Loss: 0.6917735934257507
# Recovering Image of class 36. Step 900, Loss: 0.6834481954574585
# Recovering Image of class 36. Step 950, Loss: 0.6781889200210571
# Recovering Image of class 36. Step 1000, Loss: 0.6692219972610474
# Recovering Image of class 36. Step 1050, Loss: 0.6504957675933838
# Recovering Image of class 36. Step 1100, Loss: 0.6394432783126831
# Recovering Image of class 36. Step 1150, Loss: 0.6330270767211914
# Recovering Image of class 36. Step 1200, Loss: 0.6293194890022278
# Recovering Image of class 36. Step 1250, Loss: 0.6230573654174805
# Recovering Image of class 36. Step 1300, Loss: 0.6182427406311035
# Recovering Image of class 36. Step 1350, Loss: 0.6142855286598206
# Recovering Image of class 36. Step 1400, Loss: 0.6126914620399475
# Recovering Image of class 36. Step 1450, Loss: 0.6114542484283447
# Recovering Image of class 36. Step 1500, Loss: 0.6082189083099365
# Recovering Image of class 36. Step 1550, Loss: 0.6084442734718323
# Recovering Image of class 36. Step 1600, Loss: 0.6056510806083679
# Recovering Image of class 36. Step 1650, Loss: 0.6015907526016235
# Recovering Image of class 36. Step 1700, Loss: 0.6000553369522095
# Recovering Image of class 36. Step 1750, Loss: 0.5977345705032349
# Recovering Image of class 36. Step 1800, Loss: 0.5981239080429077
# Recovering Image of class 36. Step 1850, Loss: 0.5952631235122681
# Recovering Image of class 36. Step 1900, Loss: 0.5945070385932922
# Recovering Image of class 36. Step 1950, Loss: 0.5943462252616882
# Recovering Image of class 36. Step 2000, Loss: 0.5929215550422668
# Recovering Image of class 36. Step 2050, Loss: 0.5925155878067017
# Recovering Image of class 36. Step 2100, Loss: 0.5937221050262451
# Recovering Image of class 36. Step 2150, Loss: 0.5909796357154846
# Recovering Image of class 36. Step 2200, Loss: 0.5911205410957336
# Recovering Image of class 36. Step 2250, Loss: 0.5919819474220276
# Recovering Image of class 36. Step 2300, Loss: 0.5895586013793945
# Recovering Image of class 36. Step 2350, Loss: 0.589127242565155
# Recovering Image of class 36. Step 2400, Loss: 0.5827181339263916
# Recovering Image of class 38. Step 1450, Loss: 0.6677320599555969
# Recovering Image of class 38. Step 1500, Loss: 0.6585573554039001
# Recovering Image of class 38. Step 1550, Loss: 0.6521651744842529
# Recovering Image of class 38. Step 1600, Loss: 0.6503697037696838
# Recovering Image of class 38. Step 1650, Loss: 0.6445438265800476
# Recovering Image of class 38. Step 1700, Loss: 0.6386712789535522
# Recovering Image of class 38. Step 1750, Loss: 0.6334317326545715
# Recovering Image of class 38. Step 1800, Loss: 0.6295344233512878
# Recovering Image of class 38. Step 1850, Loss: 0.6064375638961792
# Recovering Image of class 38. Step 1900, Loss: 0.591333270072937
# Recovering Image of class 38. Step 1950, Loss: 0.5817464590072632
# Recovering Image of class 38. Step 2000, Loss: 0.5763107538223267
# Recovering Image of class 38. Step 2050, Loss: 0.5660325884819031
# Recovering Image of class 38. Step 2100, Loss: 0.5585781335830688
# Recovering Image of class 38. Step 2150, Loss: 0.5524128675460815
# Recovering Image of class 38. Step 2200, Loss: 0.5483758449554443
# Recovering Image of class 38. Step 2250, Loss: 0.5443052053451538
# Recovering Image of class 38. Step 2300, Loss: 0.5425266623497009
# Recovering Image of class 38. Step 2350, Loss: 0.539618968963623
# Recovering Image of class 38. Step 2400, Loss: 0.5358851552009583
# Recovering Image of class 38. Step 2450, Loss: 0.5353043079376221
# Recovering Image of class 38. Step 2500, Loss: 0.5322318077087402
# Recovering Image of class 38. Step 2550, Loss: 0.5310665369033813
# Recovering Image of class 38. Step 2600, Loss: 0.5293082594871521
# Recovering Image of class 38. Step 2650, Loss: 0.5282691717147827
# Recovering Image of class 38. Step 2700, Loss: 0.5261383056640625
# Recovering Image of class 38. Step 2750, Loss: 0.5256029367446899
# Recovering Image of class 38. Step 2800, Loss: 0.5255221128463745
# Recovering Image of class 38. Step 2850, Loss: 0.5226351022720337
# Recovering Image of class 38. Step 2900, Loss: 0.5229249596595764
# Recovering Image of class 38. Step 2950, Loss: 0.5209641456604004
# Recovering Image of class 39. Step 0, Loss: 6.6905364990234375
# Recovering Image of class 39. Step 50, Loss: 4.048148155212402
# Recovering Image of class 39. Step 100, Loss: 3.681583881378174
# Recovering Image of class 39. Step 150, Loss: 3.377143383026123
# Recovering Image of class 39. Step 200, Loss: 2.7061386108398438
# Recovering Image of class 39. Step 250, Loss: 2.4279046058654785
# Recovering Image of class 39. Step 300, Loss: 2.219123363494873
# Recovering Image of class 39. Step 350, Loss: 2.1342613697052
# Recovering Image of class 39. Step 400, Loss: 2.031421422958374
# Recovering Image of class 39. Step 450, Loss: 1.9188753366470337
# Recovering Image of class 39. Step 500, Loss: 1.8177849054336548
# Recovering Image of class 39. Step 550, Loss: 1.7500241994857788
# Recovering Image of class 39. Step 600, Loss: 1.6968156099319458
# Recovering Image of class 39. Step 650, Loss: 1.6583194732666016
# Recovering Image of class 39. Step 700, Loss: 1.628841519355774
# Recovering Image of class 39. Step 750, Loss: 1.6104371547698975
# Recovering Image of class 39. Step 800, Loss: 1.5970364809036255
# Recovering Image of class 39. Step 850, Loss: 1.5852711200714111
# Recovering Image of class 39. Step 900, Loss: 1.5762848854064941
# Recovering Image of class 39. Step 950, Loss: 1.5646332502365112
# Recovering Image of class 39. Step 1000, Loss: 1.5533256530761719
# Recovering Image of class 39. Step 1050, Loss: 1.5450851917266846
# Recovering Image of class 39. Step 1100, Loss: 1.5346670150756836
# Recovering Image of class 39. Step 1150, Loss: 1.5270150899887085
# Recovering Image of class 39. Step 1200, Loss: 1.5256468057632446
# Recovering Image of class 39. Step 1250, Loss: 1.5123788118362427
# Recovering Image of class 39. Step 1300, Loss: 1.507264256477356
# Recovering Image of class 39. Step 1350, Loss: 1.500601053237915
# Recovering Image of class 39. Step 1400, Loss: 1.5002323389053345
# Recovering Image of class 39. Step 1450, Loss: 1.4922311305999756
# Recovering Image of class 39. Step 1500, Loss: 1.495174765586853
# Recovering Image of class 39. Step 1550, Loss: 1.4876629114151
# Recovering Image of class 39. Step 1600, Loss: 1.484391450881958
# Recovering Image of class 39. Step 1650, Loss: 1.483362078666687
# Recovering Image of class 39. Step 1700, Loss: 1.4846739768981934
# Recovering Image of class 39. Step 1750, Loss: 1.4793506860733032
# Recovering Image of class 39. Step 1800, Loss: 1.487764835357666
# Recovering Image of class 39. Step 1850, Loss: 1.4794450998306274
# Recovering Image of class 39. Step 1900, Loss: 1.474055528640747
# Recovering Image of class 39. Step 1950, Loss: 1.4739840030670166
# Recovering Image of class 39. Step 2000, Loss: 1.4725350141525269
# Recovering Image of class 39. Step 2050, Loss: 1.4704936742782593
# Recovering Image of class 39. Step 2100, Loss: 1.469239592552185
# Recovering Image of class 39. Step 2150, Loss: 1.4677062034606934
# Recovering Image of class 39. Step 2200, Loss: 1.4678730964660645
# Recovering Image of class 39. Step 2250, Loss: 1.4648027420043945
# Recovering Image of class 39. Step 2300, Loss: 1.462841510772705
# Recovering Image of class 39. Step 2350, Loss: 1.4628905057907104
# Recovering Image of class 39. Step 2400, Loss: 1.4588361978530884
# Recovering Image of class 39. Step 2450, Loss: 1.4542373418807983
# Recovering Image of class 39. Step 2500, Loss: 1.4485743045806885
# Recovering Image of class 39. Step 2550, Loss: 1.4450727701187134
# Recovering Image of class 39. Step 2600, Loss: 1.4439337253570557
# Recovering Image of class 39. Step 2650, Loss: 1.442953109741211
# Recovering Image of class 39. Step 2700, Loss: 1.4422577619552612
# Recovering Image of class 39. Step 2750, Loss: 1.441075325012207
# Recovering Image of class 39. Step 2800, Loss: 1.4408239126205444
# Recovering Image of class 39. Step 2850, Loss: 1.4401212930679321
# Recovering Image of class 39. Step 2900, Loss: 1.4402530193328857
# Recovering Image of class 39. Step 2950, Loss: 1.4391205310821533

# %%
images = []
for r in recovered_images:
    img = gen(r.latent_vector.to(device)).squeeze()
    images.append(img)

# %%
len(images)
# Out:
# 40

# %%
# Create a figure with 2 rows and 4 columns
fig, axes = plt.subplots(10, 4, figsize=(12, 10))

# Flatten the 2D axes array and iterate over it
for ax, img in zip(axes.flatten(), recovered_images):
    img = gen(img.latent_vector.to(device)).squeeze()
    ax.imshow(img.cpu().detach(), cmap='gray')  # Display the image
    ax.axis('off')  # Hide axes

plt.tight_layout()  # Adjust layout to avoid overlap
plt.show()
