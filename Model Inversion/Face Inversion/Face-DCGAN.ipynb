# %%
# Creating a Deep Convolutional Generative Adverserial Network that creates realistic Face Images.
# Author: Suraj Neupane
# Written from scratch as a part of a Research Project 2025, Concordia University of Edmonton.
from PIL import Image
import numpy as np

import torch
from torch import nn

from torch.utils.data import DataLoader

import torchvision
from torchvision import datasets
from torchvision import transforms
from torchvision.datasets import ImageFolder

import matplotlib.pyplot as plt

# %%
torch.__version__
# Out:
# '2.5.1+cu118'

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
img_size = 64
img_channels = 1
# Transform the images to 64x64
transformations = transforms.Compose(
    [
        transforms.Resize((img_size, img_size)),
        transforms.Grayscale(num_output_channels=img_channels),
        transforms.ToTensor(),
    ]
)

# %%
# Visualize a data sample
image_path = "datasets/Face Dataset/s1/1.pgm"
image = Image.open(image_path)  # Load as PIL Image
image = transformations(image)  # Convert to tensor

# %%
# Display the image
plt.imshow(image.squeeze(), cmap="gray")
plt.title("Loaded PGM Image")
plt.show()

# %%
# Load the entire dataset
data_dir = "datasets/Face Dataset"
dataset = ImageFolder(root=data_dir, transform=transformations)
print(len(dataset))
print(f"Number of classes: {len(dataset.classes)}")
# Out:
# 400
# Number of classes: 40

# %%
# Create the Dataloader
BATCH_SIZE = 16

dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

# %%
data_iter = iter(dataloader)
first_batch_samples, first_batch_labels = next(data_iter)
first_batch_samples.shape, first_batch_labels.shape
# Out:
# (torch.Size([16, 1, 64, 64]), torch.Size([16]))

# %%
# Creating the DC-GAN
# Creating the Discriminator
class Discriminator(nn.Module):
    def __init__(self, img_channels, features_d):
        super().__init__()
        self.disc = nn.Sequential(
            # Input shape: img_channels x 64 x 64
            nn.Conv2d(
              in_channels=img_channels, out_channels=features_d, kernel_size=4, stride=2, padding=1
            ), # Output shape: features_d x 32 x 32
            nn.LeakyReLU(0.2),
            self._block(features_d, features_d*2, 4, 2, 1), # Output shape: features_d*2 x 16 x 16
            self._block(features_d*2, features_d*4, 4, 2, 1), # Output shape: features_d*4 x 8 x 8
            self._block(features_d*4, features_d*8, 4, 2, 1), # Output shape: features_d*8 x 4 x 4
           
            nn.Conv2d(in_channels=features_d*8, out_channels=1, kernel_size=4, stride=2, padding=0), # Output shape: 1 x 1
            nn.Sigmoid(),
        )

    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size, stride, padding, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.LeakyReLU(0.2),
        )

    def forward(self, X):
        return self.disc(X)

# %%
# Creating the Generator
class Generator(nn.Module):
    def __init__(self, z_dim, img_channels, features_g):
        super().__init__()
        self.gen = nn.Sequential(
            self._block(z_dim, features_g*16, 4, 1, 0),
            self._block(features_g*16, features_g*8, 4, 2, 1),
            self._block(features_g*8, features_g*4, 4, 2, 1),
            self._block(features_g*4, features_g*2, 4, 2, 1),
            nn.ConvTranspose2d(
                in_channels=features_g*2, out_channels=img_channels, kernel_size=4, stride=2, padding=1
            ),
            nn.Tanh(),
        )
        
    def _block(self, in_channels, out_channels, kernel_size, stride, padding):
        return nn.Sequential(
            nn.ConvTranspose2d(
                in_channels, out_channels, kernel_size, stride, padding, bias=False,
            ),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(),
        )

    def forward(self, X):
        return self.gen(X)

# %%
def initialize_weights(model):
    for m in model.modules():
        if isinstance(m, (nn.Conv2d, nn.ConvTranspose2d, nn.BatchNorm2d)):
            nn.init.normal_(m.weight.data, 0.0, 0.02)

# %%
# Testing the output shapes of the Discriminator and the Generator
def test():
    N, in_channels, H, W = 8, 1, 64, 64
    z_dim = 100
    x = torch.randn((N, in_channels, H, W))
    disc = Discriminator(in_channels, 8)
    initialize_weights(disc)

    print(disc(x).shape)
    assert disc(x).shape == (N, 1, 1, 1)

    gen = Generator(z_dim, in_channels, 8)
    initialize_weights(gen)
    z = torch.randn((N, z_dim, 1, 1))

    print(gen(z).shape)
    assert(gen(z).shape) == (N, in_channels, H, W)

# %%
test()
# Out:
# torch.Size([8, 1, 1, 1])
# torch.Size([8, 1, 64, 64])

# %%
# Setup the hyperparameters
learning_rate = 2e-4
batch_size = 16
image_size = 64
img_channels = 1
z_dim = 100
epochs = 400
features_disc = 64
features_gen = 64

# %%
# Create the model instances
gen = Generator(z_dim, img_channels, features_gen).to(device)
disc = Discriminator(img_channels, features_disc).to(device)

# %%
initialize_weights(gen)
initialize_weights(disc)

# %%
# Create the optimizer and the loss function
opt_gen = torch.optim.Adam(gen.parameters(), lr=learning_rate, betas=(0.5, 0.999))
opt_disc = torch.optim.Adam(disc.parameters(), lr=learning_rate, betas=(0.5, 0.999))
loss_function = nn.BCELoss()

# %%
fixed_noise = torch.randn(32, z_dim, 1, 1).to(device)

# %%
# Set the models to training mode
gen.train()
disc.train()
# Out:
# Discriminator(
#   (disc): Sequential(
#     (0): Conv2d(1, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (3): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (4): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): LeakyReLU(negative_slope=0.2)
#     )
#     (5): Conv2d(512, 1, kernel_size=(4, 4), stride=(2, 2))
#     (6): Sigmoid()
#   )
# )

# %%
fake_images = []

for epoch in range(epochs):
    for batch_index, (real_images, labels) in enumerate(dataloader):
        real_images = real_images.to(device)
        noise = torch.randn((batch_size, z_dim, 1, 1)).to(device)
        fake = gen(noise)
        
        # Train the discriminator max log(D(X)) + log(1 - (D(G(X))))
        disc_real = disc(real_images).reshape(-1) # Flatten the output
        loss_disc_real = loss_function(disc_real, torch.ones_like(disc_real))

        disc_fake = disc(fake).reshape(-1)
        loss_disc_fake = loss_function(disc_fake, torch.zeros_like(disc_fake))
        
        loss_disc = (loss_disc_real + loss_disc_fake) / 2
        disc.zero_grad()
        loss_disc.backward(retain_graph=True)
        opt_disc.step()

        # Train the Generator max log(D(G(z)))
        output = disc(fake).reshape(-1)
        loss_gen = loss_function(output, torch.ones_like(output))
        gen.zero_grad()
        loss_gen.backward()
        opt_gen.step()

        if batch_index % 5 == 0:
            print(f'Epoch: {epoch}. Batches seen: {batch_index}.')
            fake_images.append(fake)
# Out:
# Epoch: 0. Batches seen: 0.
# Epoch: 0. Batches seen: 5.
# Epoch: 0. Batches seen: 10.
# Epoch: 0. Batches seen: 15.
# Epoch: 0. Batches seen: 20.
# Epoch: 1. Batches seen: 0.
# Epoch: 1. Batches seen: 5.
# Epoch: 1. Batches seen: 10.
# Epoch: 1. Batches seen: 15.
# Epoch: 1. Batches seen: 20.
# Epoch: 2. Batches seen: 0.
# Epoch: 2. Batches seen: 5.
# Epoch: 2. Batches seen: 10.
# Epoch: 2. Batches seen: 15.
# Epoch: 2. Batches seen: 20.
# Epoch: 3. Batches seen: 0.
# Epoch: 3. Batches seen: 5.
# Epoch: 3. Batches seen: 10.
# Epoch: 3. Batches seen: 15.
# Epoch: 3. Batches seen: 20.
# Epoch: 4. Batches seen: 0.
# Epoch: 4. Batches seen: 5.
# Epoch: 4. Batches seen: 10.
# Epoch: 4. Batches seen: 15.
# Epoch: 4. Batches seen: 20.
# Epoch: 5. Batches seen: 0.
# Epoch: 5. Batches seen: 5.
# Epoch: 5. Batches seen: 10.
# Epoch: 5. Batches seen: 15.
# Epoch: 5. Batches seen: 20.
# Epoch: 6. Batches seen: 0.
# Epoch: 6. Batches seen: 5.
# Epoch: 6. Batches seen: 10.
# Epoch: 6. Batches seen: 15.
# Epoch: 6. Batches seen: 20.
# Epoch: 7. Batches seen: 0.
# Epoch: 7. Batches seen: 5.
# Epoch: 7. Batches seen: 10.
# Epoch: 7. Batches seen: 15.
# Epoch: 7. Batches seen: 20.
# Epoch: 8. Batches seen: 0.
# Epoch: 8. Batches seen: 5.
# Epoch: 8. Batches seen: 10.
# Epoch: 8. Batches seen: 15.
# Epoch: 8. Batches seen: 20.
# Epoch: 9. Batches seen: 0.
# Epoch: 9. Batches seen: 5.
# Epoch: 9. Batches seen: 10.
# Epoch: 9. Batches seen: 15.
# Epoch: 9. Batches seen: 20.
# Epoch: 10. Batches seen: 0.
# Epoch: 10. Batches seen: 5.
# Epoch: 10. Batches seen: 10.
# Epoch: 10. Batches seen: 15.
# Epoch: 10. Batches seen: 20.
# Epoch: 11. Batches seen: 0.
# Epoch: 11. Batches seen: 5.
# Epoch: 11. Batches seen: 10.
# Epoch: 11. Batches seen: 15.
# Epoch: 11. Batches seen: 20.
# Epoch: 12. Batches seen: 0.
# Epoch: 12. Batches seen: 5.
# Epoch: 12. Batches seen: 10.
# Epoch: 12. Batches seen: 15.
# Epoch: 12. Batches seen: 20.
# Epoch: 13. Batches seen: 0.
# Epoch: 13. Batches seen: 5.
# Epoch: 13. Batches seen: 10.
# Epoch: 13. Batches seen: 15.
# Epoch: 13. Batches seen: 20.
# Epoch: 14. Batches seen: 0.
# Epoch: 14. Batches seen: 5.
# Epoch: 14. Batches seen: 10.
# Epoch: 14. Batches seen: 15.
# Epoch: 14. Batches seen: 20.
# Epoch: 15. Batches seen: 0.
# Epoch: 15. Batches seen: 5.
# Epoch: 15. Batches seen: 10.
# Epoch: 15. Batches seen: 15.
# Epoch: 15. Batches seen: 20.
# Epoch: 16. Batches seen: 0.
# Epoch: 16. Batches seen: 5.
# Epoch: 16. Batches seen: 10.
# Epoch: 16. Batches seen: 15.
# Epoch: 16. Batches seen: 20.
# Epoch: 17. Batches seen: 0.
# Epoch: 17. Batches seen: 5.
# Epoch: 17. Batches seen: 10.
# Epoch: 17. Batches seen: 15.
# Epoch: 17. Batches seen: 20.
# Epoch: 18. Batches seen: 0.
# Epoch: 18. Batches seen: 5.
# Epoch: 18. Batches seen: 10.
# Epoch: 18. Batches seen: 15.
# Epoch: 18. Batches seen: 20.
# Epoch: 19. Batches seen: 0.
# Epoch: 19. Batches seen: 5.
# Epoch: 19. Batches seen: 10.
# Epoch: 19. Batches seen: 15.
# Epoch: 19. Batches seen: 20.
# Epoch: 20. Batches seen: 0.
# Epoch: 20. Batches seen: 5.
# Epoch: 20. Batches seen: 10.
# Epoch: 20. Batches seen: 15.
# Epoch: 20. Batches seen: 20.
# Epoch: 21. Batches seen: 0.
# Epoch: 21. Batches seen: 5.
# Epoch: 21. Batches seen: 10.
# Epoch: 21. Batches seen: 15.
# Epoch: 21. Batches seen: 20.
# Epoch: 22. Batches seen: 0.
# Epoch: 22. Batches seen: 5.
# Epoch: 22. Batches seen: 10.
# Epoch: 22. Batches seen: 15.
# Epoch: 22. Batches seen: 20.
# Epoch: 23. Batches seen: 0.
# Epoch: 23. Batches seen: 5.
# Epoch: 23. Batches seen: 10.
# Epoch: 23. Batches seen: 15.
# Epoch: 23. Batches seen: 20.
# Epoch: 24. Batches seen: 0.
# Epoch: 24. Batches seen: 5.
# Epoch: 24. Batches seen: 10.
# Epoch: 24. Batches seen: 15.
# Epoch: 24. Batches seen: 20.
# Epoch: 25. Batches seen: 0.
# Epoch: 25. Batches seen: 5.
# Epoch: 25. Batches seen: 10.
# Epoch: 25. Batches seen: 15.
# Epoch: 25. Batches seen: 20.
# Epoch: 26. Batches seen: 0.
# Epoch: 26. Batches seen: 5.
# Epoch: 26. Batches seen: 10.
# Epoch: 26. Batches seen: 15.
# Epoch: 26. Batches seen: 20.
# Epoch: 27. Batches seen: 0.
# Epoch: 27. Batches seen: 5.
# Epoch: 27. Batches seen: 10.
# Epoch: 27. Batches seen: 15.
# Epoch: 27. Batches seen: 20.
# Epoch: 28. Batches seen: 0.
# Epoch: 28. Batches seen: 5.
# Epoch: 28. Batches seen: 10.
# Epoch: 28. Batches seen: 15.
# Epoch: 28. Batches seen: 20.
# Epoch: 29. Batches seen: 0.
# Epoch: 29. Batches seen: 5.
# Epoch: 29. Batches seen: 10.
# Epoch: 29. Batches seen: 15.
# Epoch: 29. Batches seen: 20.
# Epoch: 30. Batches seen: 0.
# Epoch: 30. Batches seen: 5.
# Epoch: 30. Batches seen: 10.
# Epoch: 30. Batches seen: 15.
# Epoch: 30. Batches seen: 20.
# Epoch: 31. Batches seen: 0.
# Epoch: 31. Batches seen: 5.
# Epoch: 31. Batches seen: 10.
# Epoch: 31. Batches seen: 15.
# Epoch: 31. Batches seen: 20.
# Epoch: 32. Batches seen: 0.
# Epoch: 32. Batches seen: 5.
# Epoch: 32. Batches seen: 10.
# Epoch: 32. Batches seen: 15.
# Epoch: 32. Batches seen: 20.
# Epoch: 33. Batches seen: 0.
# Epoch: 33. Batches seen: 5.
# Epoch: 33. Batches seen: 10.
# Epoch: 33. Batches seen: 15.
# Epoch: 33. Batches seen: 20.
# Epoch: 34. Batches seen: 0.
# Epoch: 34. Batches seen: 5.
# Epoch: 34. Batches seen: 10.
# Epoch: 34. Batches seen: 15.
# Epoch: 34. Batches seen: 20.
# Epoch: 35. Batches seen: 0.
# Epoch: 35. Batches seen: 5.
# Epoch: 35. Batches seen: 10.
# Epoch: 35. Batches seen: 15.
# Epoch: 35. Batches seen: 20.
# Epoch: 36. Batches seen: 0.
# Epoch: 36. Batches seen: 5.
# Epoch: 36. Batches seen: 10.
# Epoch: 36. Batches seen: 15.
# Epoch: 36. Batches seen: 20.
# Epoch: 37. Batches seen: 0.
# Epoch: 37. Batches seen: 5.
# Epoch: 37. Batches seen: 10.
# Epoch: 37. Batches seen: 15.
# Epoch: 37. Batches seen: 20.
# Epoch: 38. Batches seen: 0.
# Epoch: 38. Batches seen: 5.
# Epoch: 38. Batches seen: 10.
# Epoch: 38. Batches seen: 15.
# Epoch: 38. Batches seen: 20.
# Epoch: 39. Batches seen: 0.
# Epoch: 39. Batches seen: 5.
# Epoch: 39. Batches seen: 10.
# Epoch: 39. Batches seen: 15.
# Epoch: 39. Batches seen: 20.
# Epoch: 40. Batches seen: 0.
# Epoch: 40. Batches seen: 5.
# Epoch: 40. Batches seen: 10.
# Epoch: 40. Batches seen: 15.
# Epoch: 40. Batches seen: 20.
# Epoch: 41. Batches seen: 0.
# Epoch: 41. Batches seen: 5.
# Epoch: 41. Batches seen: 10.
# Epoch: 41. Batches seen: 15.
# Epoch: 41. Batches seen: 20.
# Epoch: 42. Batches seen: 0.
# Epoch: 42. Batches seen: 5.
# Epoch: 42. Batches seen: 10.
# Epoch: 42. Batches seen: 15.
# Epoch: 42. Batches seen: 20.
# Epoch: 43. Batches seen: 0.
# Epoch: 43. Batches seen: 5.
# Epoch: 43. Batches seen: 10.
# Epoch: 43. Batches seen: 15.
# Epoch: 43. Batches seen: 20.
# Epoch: 44. Batches seen: 0.
# Epoch: 44. Batches seen: 5.
# Epoch: 44. Batches seen: 10.
# Epoch: 44. Batches seen: 15.
# Epoch: 44. Batches seen: 20.
# Epoch: 45. Batches seen: 0.
# Epoch: 45. Batches seen: 5.
# Epoch: 45. Batches seen: 10.
# Epoch: 45. Batches seen: 15.
# Epoch: 45. Batches seen: 20.
# Epoch: 46. Batches seen: 0.
# Epoch: 46. Batches seen: 5.
# Epoch: 46. Batches seen: 10.
# Epoch: 46. Batches seen: 15.
# Epoch: 46. Batches seen: 20.
# Epoch: 47. Batches seen: 0.
# Epoch: 47. Batches seen: 5.
# Epoch: 47. Batches seen: 10.
# Epoch: 47. Batches seen: 15.
# Epoch: 47. Batches seen: 20.
# Epoch: 48. Batches seen: 0.
# Epoch: 48. Batches seen: 5.
# Epoch: 48. Batches seen: 10.
# Epoch: 48. Batches seen: 15.
# Epoch: 48. Batches seen: 20.
# Epoch: 49. Batches seen: 0.
# Epoch: 49. Batches seen: 5.
# Epoch: 49. Batches seen: 10.
# Epoch: 49. Batches seen: 15.
# Epoch: 49. Batches seen: 20.
# Epoch: 50. Batches seen: 0.
# Epoch: 50. Batches seen: 5.
# Epoch: 50. Batches seen: 10.
# Epoch: 50. Batches seen: 15.
# Epoch: 50. Batches seen: 20.
# Epoch: 51. Batches seen: 0.
# Epoch: 51. Batches seen: 5.
# Epoch: 51. Batches seen: 10.
# Epoch: 51. Batches seen: 15.
# Epoch: 51. Batches seen: 20.
# Epoch: 52. Batches seen: 0.
# Epoch: 52. Batches seen: 5.
# Epoch: 52. Batches seen: 10.
# Epoch: 52. Batches seen: 15.
# Epoch: 52. Batches seen: 20.
# Epoch: 53. Batches seen: 0.
# Epoch: 53. Batches seen: 5.
# Epoch: 53. Batches seen: 10.
# Epoch: 53. Batches seen: 15.
# Epoch: 53. Batches seen: 20.
# Epoch: 54. Batches seen: 0.
# Epoch: 54. Batches seen: 5.
# Epoch: 54. Batches seen: 10.
# Epoch: 54. Batches seen: 15.
# Epoch: 54. Batches seen: 20.
# Epoch: 55. Batches seen: 0.
# Epoch: 55. Batches seen: 5.
# Epoch: 55. Batches seen: 10.
# Epoch: 55. Batches seen: 15.
# Epoch: 55. Batches seen: 20.
# Epoch: 56. Batches seen: 0.
# Epoch: 56. Batches seen: 5.
# Epoch: 56. Batches seen: 10.
# Epoch: 56. Batches seen: 15.
# Epoch: 56. Batches seen: 20.
# Epoch: 57. Batches seen: 0.
# Epoch: 57. Batches seen: 5.
# Epoch: 57. Batches seen: 10.
# Epoch: 57. Batches seen: 15.
# Epoch: 57. Batches seen: 20.
# Epoch: 58. Batches seen: 0.
# Epoch: 58. Batches seen: 5.
# Epoch: 58. Batches seen: 10.
# Epoch: 58. Batches seen: 15.
# Epoch: 58. Batches seen: 20.
# Epoch: 59. Batches seen: 0.
# Epoch: 59. Batches seen: 5.
# Epoch: 59. Batches seen: 10.
# Epoch: 59. Batches seen: 15.
# Epoch: 59. Batches seen: 20.
# Epoch: 60. Batches seen: 0.
# Epoch: 60. Batches seen: 5.
# Epoch: 60. Batches seen: 10.
# Epoch: 60. Batches seen: 15.
# Epoch: 60. Batches seen: 20.
# Epoch: 61. Batches seen: 0.
# Epoch: 61. Batches seen: 5.
# Epoch: 61. Batches seen: 10.
# Epoch: 61. Batches seen: 15.
# Epoch: 61. Batches seen: 20.
# Epoch: 62. Batches seen: 0.
# Epoch: 62. Batches seen: 5.
# Epoch: 62. Batches seen: 10.
# Epoch: 62. Batches seen: 15.
# Epoch: 62. Batches seen: 20.
# Epoch: 63. Batches seen: 0.
# Epoch: 63. Batches seen: 5.
# Epoch: 63. Batches seen: 10.
# Epoch: 63. Batches seen: 15.
# Epoch: 63. Batches seen: 20.
# Epoch: 64. Batches seen: 0.
# Epoch: 64. Batches seen: 5.
# Epoch: 64. Batches seen: 10.
# Epoch: 64. Batches seen: 15.
# Epoch: 64. Batches seen: 20.
# Epoch: 65. Batches seen: 0.
# Epoch: 65. Batches seen: 5.
# Epoch: 65. Batches seen: 10.
# Epoch: 65. Batches seen: 15.
# Epoch: 65. Batches seen: 20.
# Epoch: 66. Batches seen: 0.
# Epoch: 66. Batches seen: 5.
# Epoch: 66. Batches seen: 10.
# Epoch: 66. Batches seen: 15.
# Epoch: 66. Batches seen: 20.
# Epoch: 67. Batches seen: 0.
# Epoch: 67. Batches seen: 5.
# Epoch: 67. Batches seen: 10.
# Epoch: 67. Batches seen: 15.
# Epoch: 67. Batches seen: 20.
# Epoch: 68. Batches seen: 0.
# Epoch: 68. Batches seen: 5.
# Epoch: 68. Batches seen: 10.
# Epoch: 68. Batches seen: 15.
# Epoch: 68. Batches seen: 20.
# Epoch: 69. Batches seen: 0.
# Epoch: 69. Batches seen: 5.
# Epoch: 69. Batches seen: 10.
# Epoch: 69. Batches seen: 15.
# Epoch: 69. Batches seen: 20.
# Epoch: 70. Batches seen: 0.
# Epoch: 70. Batches seen: 5.
# Epoch: 70. Batches seen: 10.
# Epoch: 70. Batches seen: 15.
# Epoch: 70. Batches seen: 20.
# Epoch: 71. Batches seen: 0.
# Epoch: 71. Batches seen: 5.
# Epoch: 71. Batches seen: 10.
# Epoch: 71. Batches seen: 15.
# Epoch: 71. Batches seen: 20.
# Epoch: 72. Batches seen: 0.
# Epoch: 72. Batches seen: 5.
# Epoch: 72. Batches seen: 10.
# Epoch: 72. Batches seen: 15.
# Epoch: 72. Batches seen: 20.
# Epoch: 73. Batches seen: 0.
# Epoch: 73. Batches seen: 5.
# Epoch: 73. Batches seen: 10.
# Epoch: 73. Batches seen: 15.
# Epoch: 73. Batches seen: 20.
# Epoch: 74. Batches seen: 0.
# Epoch: 74. Batches seen: 5.
# Epoch: 74. Batches seen: 10.
# Epoch: 74. Batches seen: 15.
# Epoch: 74. Batches seen: 20.
# Epoch: 75. Batches seen: 0.
# Epoch: 75. Batches seen: 5.
# Epoch: 75. Batches seen: 10.
# Epoch: 75. Batches seen: 15.
# Epoch: 75. Batches seen: 20.
# Epoch: 76. Batches seen: 0.
# Epoch: 76. Batches seen: 5.
# Epoch: 76. Batches seen: 10.
# Epoch: 76. Batches seen: 15.
# Epoch: 76. Batches seen: 20.
# Epoch: 77. Batches seen: 0.
# Epoch: 77. Batches seen: 5.
# Epoch: 77. Batches seen: 10.
# Epoch: 77. Batches seen: 15.
# Epoch: 77. Batches seen: 20.
# Epoch: 78. Batches seen: 0.
# Epoch: 78. Batches seen: 5.
# Epoch: 78. Batches seen: 10.
# Epoch: 78. Batches seen: 15.
# Epoch: 78. Batches seen: 20.
# Epoch: 79. Batches seen: 0.
# Epoch: 79. Batches seen: 5.
# Epoch: 79. Batches seen: 10.
# Epoch: 79. Batches seen: 15.
# Epoch: 79. Batches seen: 20.
# Epoch: 80. Batches seen: 0.
# Epoch: 80. Batches seen: 5.
# Epoch: 80. Batches seen: 10.
# Epoch: 80. Batches seen: 15.
# Epoch: 80. Batches seen: 20.
# Epoch: 81. Batches seen: 0.
# Epoch: 81. Batches seen: 5.
# Epoch: 81. Batches seen: 10.
# Epoch: 81. Batches seen: 15.
# Epoch: 81. Batches seen: 20.
# Epoch: 82. Batches seen: 0.
# Epoch: 82. Batches seen: 5.
# Epoch: 82. Batches seen: 10.
# Epoch: 82. Batches seen: 15.
# Epoch: 82. Batches seen: 20.
# Epoch: 83. Batches seen: 0.
# Epoch: 83. Batches seen: 5.
# Epoch: 83. Batches seen: 10.
# Epoch: 83. Batches seen: 15.
# Epoch: 83. Batches seen: 20.
# Epoch: 84. Batches seen: 0.
# Epoch: 84. Batches seen: 5.
# Epoch: 84. Batches seen: 10.
# Epoch: 84. Batches seen: 15.
# Epoch: 84. Batches seen: 20.
# Epoch: 85. Batches seen: 0.
# Epoch: 85. Batches seen: 5.
# Epoch: 85. Batches seen: 10.
# Epoch: 85. Batches seen: 15.
# Epoch: 85. Batches seen: 20.
# Epoch: 86. Batches seen: 0.
# Epoch: 86. Batches seen: 5.
# Epoch: 86. Batches seen: 10.
# Epoch: 86. Batches seen: 15.
# Epoch: 86. Batches seen: 20.
# Epoch: 87. Batches seen: 0.
# Epoch: 87. Batches seen: 5.
# Epoch: 87. Batches seen: 10.
# Epoch: 87. Batches seen: 15.
# Epoch: 87. Batches seen: 20.
# Epoch: 88. Batches seen: 0.
# Epoch: 88. Batches seen: 5.
# Epoch: 88. Batches seen: 10.
# Epoch: 88. Batches seen: 15.
# Epoch: 88. Batches seen: 20.
# Epoch: 89. Batches seen: 0.
# Epoch: 89. Batches seen: 5.
# Epoch: 89. Batches seen: 10.
# Epoch: 89. Batches seen: 15.
# Epoch: 89. Batches seen: 20.
# Epoch: 90. Batches seen: 0.
# Epoch: 90. Batches seen: 5.
# Epoch: 90. Batches seen: 10.
# Epoch: 90. Batches seen: 15.
# Epoch: 90. Batches seen: 20.
# Epoch: 91. Batches seen: 0.
# Epoch: 91. Batches seen: 5.
# Epoch: 91. Batches seen: 10.
# Epoch: 91. Batches seen: 15.
# Epoch: 91. Batches seen: 20.
# Epoch: 92. Batches seen: 0.
# Epoch: 92. Batches seen: 5.
# Epoch: 92. Batches seen: 10.
# Epoch: 92. Batches seen: 15.
# Epoch: 92. Batches seen: 20.
# Epoch: 93. Batches seen: 0.
# Epoch: 93. Batches seen: 5.
# Epoch: 93. Batches seen: 10.
# Epoch: 93. Batches seen: 15.
# Epoch: 93. Batches seen: 20.
# Epoch: 94. Batches seen: 0.
# Epoch: 94. Batches seen: 5.
# Epoch: 94. Batches seen: 10.
# Epoch: 94. Batches seen: 15.
# Epoch: 94. Batches seen: 20.
# Epoch: 95. Batches seen: 0.
# Epoch: 95. Batches seen: 5.
# Epoch: 95. Batches seen: 10.
# Epoch: 95. Batches seen: 15.
# Epoch: 95. Batches seen: 20.
# Epoch: 96. Batches seen: 0.
# Epoch: 96. Batches seen: 5.
# Epoch: 96. Batches seen: 10.
# Epoch: 96. Batches seen: 15.
# Epoch: 96. Batches seen: 20.
# Epoch: 97. Batches seen: 0.
# Epoch: 97. Batches seen: 5.
# Epoch: 97. Batches seen: 10.
# Epoch: 97. Batches seen: 15.
# Epoch: 97. Batches seen: 20.
# Epoch: 98. Batches seen: 0.
# Epoch: 98. Batches seen: 5.
# Epoch: 98. Batches seen: 10.
# Epoch: 98. Batches seen: 15.
# Epoch: 98. Batches seen: 20.
# Epoch: 99. Batches seen: 0.
# Epoch: 99. Batches seen: 5.
# Epoch: 99. Batches seen: 10.
# Epoch: 99. Batches seen: 15.
# Epoch: 99. Batches seen: 20.
# Epoch: 100. Batches seen: 0.
# Epoch: 100. Batches seen: 5.
# Epoch: 100. Batches seen: 10.
# Epoch: 100. Batches seen: 15.
# Epoch: 100. Batches seen: 20.
# Epoch: 101. Batches seen: 0.
# Epoch: 101. Batches seen: 5.
# Epoch: 101. Batches seen: 10.
# Epoch: 101. Batches seen: 15.
# Epoch: 101. Batches seen: 20.
# Epoch: 102. Batches seen: 0.
# Epoch: 102. Batches seen: 5.
# Epoch: 102. Batches seen: 10.
# Epoch: 102. Batches seen: 15.
# Epoch: 102. Batches seen: 20.
# Epoch: 103. Batches seen: 0.
# Epoch: 103. Batches seen: 5.
# Epoch: 103. Batches seen: 10.
# Epoch: 103. Batches seen: 15.
# Epoch: 103. Batches seen: 20.
# Epoch: 104. Batches seen: 0.
# Epoch: 104. Batches seen: 5.
# Epoch: 104. Batches seen: 10.
# Epoch: 104. Batches seen: 15.
# Epoch: 104. Batches seen: 20.
# Epoch: 105. Batches seen: 0.
# Epoch: 105. Batches seen: 5.
# Epoch: 105. Batches seen: 10.
# Epoch: 105. Batches seen: 15.
# Epoch: 105. Batches seen: 20.
# Epoch: 106. Batches seen: 0.
# Epoch: 106. Batches seen: 5.
# Epoch: 106. Batches seen: 10.
# Epoch: 106. Batches seen: 15.
# Epoch: 106. Batches seen: 20.
# Epoch: 107. Batches seen: 0.
# Epoch: 107. Batches seen: 5.
# Epoch: 107. Batches seen: 10.
# Epoch: 107. Batches seen: 15.
# Epoch: 107. Batches seen: 20.
# Epoch: 108. Batches seen: 0.
# Epoch: 108. Batches seen: 5.
# Epoch: 108. Batches seen: 10.
# Epoch: 108. Batches seen: 15.
# Epoch: 108. Batches seen: 20.
# Epoch: 109. Batches seen: 0.
# Epoch: 109. Batches seen: 5.
# Epoch: 109. Batches seen: 10.
# Epoch: 109. Batches seen: 15.
# Epoch: 109. Batches seen: 20.
# Epoch: 110. Batches seen: 0.
# Epoch: 110. Batches seen: 5.
# Epoch: 110. Batches seen: 10.
# Epoch: 110. Batches seen: 15.
# Epoch: 110. Batches seen: 20.
# Epoch: 111. Batches seen: 0.
# Epoch: 111. Batches seen: 5.
# Epoch: 111. Batches seen: 10.
# Epoch: 111. Batches seen: 15.
# Epoch: 111. Batches seen: 20.
# Epoch: 112. Batches seen: 0.
# Epoch: 112. Batches seen: 5.
# Epoch: 112. Batches seen: 10.
# Epoch: 112. Batches seen: 15.
# Epoch: 112. Batches seen: 20.
# Epoch: 113. Batches seen: 0.
# Epoch: 113. Batches seen: 5.
# Epoch: 113. Batches seen: 10.
# Epoch: 113. Batches seen: 15.
# Epoch: 113. Batches seen: 20.
# Epoch: 114. Batches seen: 0.
# Epoch: 114. Batches seen: 5.
# Epoch: 114. Batches seen: 10.
# Epoch: 114. Batches seen: 15.
# Epoch: 114. Batches seen: 20.
# Epoch: 115. Batches seen: 0.
# Epoch: 115. Batches seen: 5.
# Epoch: 115. Batches seen: 10.
# Epoch: 115. Batches seen: 15.
# Epoch: 115. Batches seen: 20.
# Epoch: 116. Batches seen: 0.
# Epoch: 116. Batches seen: 5.
# Epoch: 116. Batches seen: 10.
# Epoch: 116. Batches seen: 15.
# Epoch: 116. Batches seen: 20.
# Epoch: 117. Batches seen: 0.
# Epoch: 117. Batches seen: 5.
# Epoch: 117. Batches seen: 10.
# Epoch: 117. Batches seen: 15.
# Epoch: 117. Batches seen: 20.
# Epoch: 118. Batches seen: 0.
# Epoch: 118. Batches seen: 5.
# Epoch: 118. Batches seen: 10.
# Epoch: 118. Batches seen: 15.
# Epoch: 118. Batches seen: 20.
# Epoch: 119. Batches seen: 0.
# Epoch: 119. Batches seen: 5.
# Epoch: 119. Batches seen: 10.
# Epoch: 119. Batches seen: 15.
# Epoch: 119. Batches seen: 20.
# Epoch: 120. Batches seen: 0.
# Epoch: 120. Batches seen: 5.
# Epoch: 120. Batches seen: 10.
# Epoch: 120. Batches seen: 15.
# Epoch: 120. Batches seen: 20.
# Epoch: 121. Batches seen: 0.
# Epoch: 121. Batches seen: 5.
# Epoch: 121. Batches seen: 10.
# Epoch: 121. Batches seen: 15.
# Epoch: 121. Batches seen: 20.
# Epoch: 122. Batches seen: 0.
# Epoch: 122. Batches seen: 5.
# Epoch: 122. Batches seen: 10.
# Epoch: 122. Batches seen: 15.
# Epoch: 122. Batches seen: 20.
# Epoch: 123. Batches seen: 0.
# Epoch: 123. Batches seen: 5.
# Epoch: 123. Batches seen: 10.
# Epoch: 123. Batches seen: 15.
# Epoch: 123. Batches seen: 20.
# Epoch: 124. Batches seen: 0.
# Epoch: 124. Batches seen: 5.
# Epoch: 124. Batches seen: 10.
# Epoch: 124. Batches seen: 15.
# Epoch: 124. Batches seen: 20.
# Epoch: 125. Batches seen: 0.
# Epoch: 125. Batches seen: 5.
# Epoch: 125. Batches seen: 10.
# Epoch: 125. Batches seen: 15.
# Epoch: 125. Batches seen: 20.
# Epoch: 126. Batches seen: 0.
# Epoch: 126. Batches seen: 5.
# Epoch: 126. Batches seen: 10.
# Epoch: 126. Batches seen: 15.
# Epoch: 126. Batches seen: 20.
# Epoch: 127. Batches seen: 0.
# Epoch: 127. Batches seen: 5.
# Epoch: 127. Batches seen: 10.
# Epoch: 127. Batches seen: 15.
# Epoch: 127. Batches seen: 20.
# Epoch: 128. Batches seen: 0.
# Epoch: 128. Batches seen: 5.
# Epoch: 128. Batches seen: 10.
# Epoch: 128. Batches seen: 15.
# Epoch: 128. Batches seen: 20.
# Epoch: 129. Batches seen: 0.
# Epoch: 129. Batches seen: 5.
# Epoch: 129. Batches seen: 10.
# Epoch: 129. Batches seen: 15.
# Epoch: 129. Batches seen: 20.
# Epoch: 130. Batches seen: 0.
# Epoch: 130. Batches seen: 5.
# Epoch: 130. Batches seen: 10.
# Epoch: 130. Batches seen: 15.
# Epoch: 130. Batches seen: 20.
# Epoch: 131. Batches seen: 0.
# Epoch: 131. Batches seen: 5.
# Epoch: 131. Batches seen: 10.
# Epoch: 131. Batches seen: 15.
# Epoch: 131. Batches seen: 20.
# Epoch: 132. Batches seen: 0.
# Epoch: 132. Batches seen: 5.
# Epoch: 132. Batches seen: 10.
# Epoch: 132. Batches seen: 15.
# Epoch: 132. Batches seen: 20.
# Epoch: 133. Batches seen: 0.
# Epoch: 133. Batches seen: 5.
# Epoch: 133. Batches seen: 10.
# Epoch: 133. Batches seen: 15.
# Epoch: 133. Batches seen: 20.
# Epoch: 134. Batches seen: 0.
# Epoch: 134. Batches seen: 5.
# Epoch: 134. Batches seen: 10.
# Epoch: 134. Batches seen: 15.
# Epoch: 134. Batches seen: 20.
# Epoch: 135. Batches seen: 0.
# Epoch: 135. Batches seen: 5.
# Epoch: 135. Batches seen: 10.
# Epoch: 135. Batches seen: 15.
# Epoch: 135. Batches seen: 20.
# Epoch: 136. Batches seen: 0.
# Epoch: 136. Batches seen: 5.
# Epoch: 136. Batches seen: 10.
# Epoch: 136. Batches seen: 15.
# Epoch: 136. Batches seen: 20.
# Epoch: 137. Batches seen: 0.
# Epoch: 137. Batches seen: 5.
# Epoch: 137. Batches seen: 10.
# Epoch: 137. Batches seen: 15.
# Epoch: 137. Batches seen: 20.
# Epoch: 138. Batches seen: 0.
# Epoch: 138. Batches seen: 5.
# Epoch: 138. Batches seen: 10.
# Epoch: 138. Batches seen: 15.
# Epoch: 138. Batches seen: 20.
# Epoch: 139. Batches seen: 0.
# Epoch: 139. Batches seen: 5.
# Epoch: 139. Batches seen: 10.
# Epoch: 139. Batches seen: 15.
# Epoch: 139. Batches seen: 20.
# Epoch: 140. Batches seen: 0.
# Epoch: 140. Batches seen: 5.
# Epoch: 140. Batches seen: 10.
# Epoch: 140. Batches seen: 15.
# Epoch: 140. Batches seen: 20.
# Epoch: 141. Batches seen: 0.
# Epoch: 141. Batches seen: 5.
# Epoch: 141. Batches seen: 10.
# Epoch: 141. Batches seen: 15.
# Epoch: 141. Batches seen: 20.
# Epoch: 142. Batches seen: 0.
# Epoch: 142. Batches seen: 5.
# Epoch: 142. Batches seen: 10.
# Epoch: 142. Batches seen: 15.
# Epoch: 142. Batches seen: 20.
# Epoch: 143. Batches seen: 0.
# Epoch: 143. Batches seen: 5.
# Epoch: 143. Batches seen: 10.
# Epoch: 143. Batches seen: 15.
# Epoch: 143. Batches seen: 20.
# Epoch: 144. Batches seen: 0.
# Epoch: 144. Batches seen: 5.
# Epoch: 144. Batches seen: 10.
# Epoch: 144. Batches seen: 15.
# Epoch: 144. Batches seen: 20.
# Epoch: 145. Batches seen: 0.
# Epoch: 145. Batches seen: 5.
# Epoch: 145. Batches seen: 10.
# Epoch: 145. Batches seen: 15.
# Epoch: 145. Batches seen: 20.
# Epoch: 146. Batches seen: 0.
# Epoch: 146. Batches seen: 5.
# Epoch: 146. Batches seen: 10.
# Epoch: 146. Batches seen: 15.
# Epoch: 146. Batches seen: 20.
# Epoch: 147. Batches seen: 0.
# Epoch: 147. Batches seen: 5.
# Epoch: 147. Batches seen: 10.
# Epoch: 147. Batches seen: 15.
# Epoch: 147. Batches seen: 20.
# Epoch: 148. Batches seen: 0.
# Epoch: 148. Batches seen: 5.
# Epoch: 148. Batches seen: 10.
# Epoch: 148. Batches seen: 15.
# Epoch: 148. Batches seen: 20.
# Epoch: 149. Batches seen: 0.
# Epoch: 149. Batches seen: 5.
# Epoch: 149. Batches seen: 10.
# Epoch: 149. Batches seen: 15.
# Epoch: 149. Batches seen: 20.
# Epoch: 150. Batches seen: 0.
# Epoch: 150. Batches seen: 5.
# Epoch: 150. Batches seen: 10.
# Epoch: 150. Batches seen: 15.
# Epoch: 150. Batches seen: 20.
# Epoch: 151. Batches seen: 0.
# Epoch: 151. Batches seen: 5.
# Epoch: 151. Batches seen: 10.
# Epoch: 151. Batches seen: 15.
# Epoch: 151. Batches seen: 20.
# Epoch: 152. Batches seen: 0.
# Epoch: 152. Batches seen: 5.
# Epoch: 152. Batches seen: 10.
# Epoch: 152. Batches seen: 15.
# Epoch: 152. Batches seen: 20.
# Epoch: 153. Batches seen: 0.
# Epoch: 153. Batches seen: 5.
# Epoch: 153. Batches seen: 10.
# Epoch: 153. Batches seen: 15.
# Epoch: 153. Batches seen: 20.
# Epoch: 154. Batches seen: 0.
# Epoch: 154. Batches seen: 5.
# Epoch: 154. Batches seen: 10.
# Epoch: 154. Batches seen: 15.
# Epoch: 154. Batches seen: 20.
# Epoch: 155. Batches seen: 0.
# Epoch: 155. Batches seen: 5.
# Epoch: 155. Batches seen: 10.
# Epoch: 155. Batches seen: 15.
# Epoch: 155. Batches seen: 20.
# Epoch: 156. Batches seen: 0.
# Epoch: 156. Batches seen: 5.
# Epoch: 156. Batches seen: 10.
# Epoch: 156. Batches seen: 15.
# Epoch: 156. Batches seen: 20.
# Epoch: 157. Batches seen: 0.
# Epoch: 157. Batches seen: 5.
# Epoch: 157. Batches seen: 10.
# Epoch: 157. Batches seen: 15.
# Epoch: 157. Batches seen: 20.
# Epoch: 158. Batches seen: 0.
# Epoch: 158. Batches seen: 5.
# Epoch: 158. Batches seen: 10.
# Epoch: 158. Batches seen: 15.
# Epoch: 158. Batches seen: 20.
# Epoch: 159. Batches seen: 0.
# Epoch: 159. Batches seen: 5.
# Epoch: 159. Batches seen: 10.
# Epoch: 159. Batches seen: 15.
# Epoch: 159. Batches seen: 20.
# Epoch: 160. Batches seen: 0.
# Epoch: 160. Batches seen: 5.
# Epoch: 160. Batches seen: 10.
# Epoch: 160. Batches seen: 15.
# Epoch: 160. Batches seen: 20.
# Epoch: 161. Batches seen: 0.
# Epoch: 161. Batches seen: 5.
# Epoch: 161. Batches seen: 10.
# Epoch: 161. Batches seen: 15.
# Epoch: 161. Batches seen: 20.
# Epoch: 162. Batches seen: 0.
# Epoch: 162. Batches seen: 5.
# Epoch: 162. Batches seen: 10.
# Epoch: 162. Batches seen: 15.
# Epoch: 162. Batches seen: 20.
# Epoch: 163. Batches seen: 0.
# Epoch: 163. Batches seen: 5.
# Epoch: 163. Batches seen: 10.
# Epoch: 163. Batches seen: 15.
# Epoch: 163. Batches seen: 20.
# Epoch: 164. Batches seen: 0.
# Epoch: 164. Batches seen: 5.
# Epoch: 164. Batches seen: 10.
# Epoch: 164. Batches seen: 15.
# Epoch: 164. Batches seen: 20.
# Epoch: 165. Batches seen: 0.
# Epoch: 165. Batches seen: 5.
# Epoch: 165. Batches seen: 10.
# Epoch: 165. Batches seen: 15.
# Epoch: 165. Batches seen: 20.
# Epoch: 166. Batches seen: 0.
# Epoch: 166. Batches seen: 5.
# Epoch: 166. Batches seen: 10.
# Epoch: 166. Batches seen: 15.
# Epoch: 166. Batches seen: 20.
# Epoch: 167. Batches seen: 0.
# Epoch: 167. Batches seen: 5.
# Epoch: 167. Batches seen: 10.
# Epoch: 167. Batches seen: 15.
# Epoch: 167. Batches seen: 20.
# Epoch: 168. Batches seen: 0.
# Epoch: 168. Batches seen: 5.
# Epoch: 168. Batches seen: 10.
# Epoch: 168. Batches seen: 15.
# Epoch: 168. Batches seen: 20.
# Epoch: 169. Batches seen: 0.
# Epoch: 169. Batches seen: 5.
# Epoch: 169. Batches seen: 10.
# Epoch: 169. Batches seen: 15.
# Epoch: 169. Batches seen: 20.
# Epoch: 170. Batches seen: 0.
# Epoch: 170. Batches seen: 5.
# Epoch: 170. Batches seen: 10.
# Epoch: 170. Batches seen: 15.
# Epoch: 170. Batches seen: 20.
# Epoch: 171. Batches seen: 0.
# Epoch: 171. Batches seen: 5.
# Epoch: 171. Batches seen: 10.
# Epoch: 171. Batches seen: 15.
# Epoch: 171. Batches seen: 20.
# Epoch: 172. Batches seen: 0.
# Epoch: 172. Batches seen: 5.
# Epoch: 172. Batches seen: 10.
# Epoch: 172. Batches seen: 15.
# Epoch: 172. Batches seen: 20.
# Epoch: 173. Batches seen: 0.
# Epoch: 173. Batches seen: 5.
# Epoch: 173. Batches seen: 10.
# Epoch: 173. Batches seen: 15.
# Epoch: 173. Batches seen: 20.
# Epoch: 174. Batches seen: 0.
# Epoch: 174. Batches seen: 5.
# Epoch: 174. Batches seen: 10.
# Epoch: 174. Batches seen: 15.
# Epoch: 174. Batches seen: 20.
# Epoch: 175. Batches seen: 0.
# Epoch: 175. Batches seen: 5.
# Epoch: 175. Batches seen: 10.
# Epoch: 175. Batches seen: 15.
# Epoch: 175. Batches seen: 20.
# Epoch: 176. Batches seen: 0.
# Epoch: 176. Batches seen: 5.
# Epoch: 176. Batches seen: 10.
# Epoch: 176. Batches seen: 15.
# Epoch: 176. Batches seen: 20.
# Epoch: 177. Batches seen: 0.
# Epoch: 177. Batches seen: 5.
# Epoch: 177. Batches seen: 10.
# Epoch: 177. Batches seen: 15.
# Epoch: 177. Batches seen: 20.
# Epoch: 178. Batches seen: 0.
# Epoch: 178. Batches seen: 5.
# Epoch: 178. Batches seen: 10.
# Epoch: 178. Batches seen: 15.
# Epoch: 178. Batches seen: 20.
# Epoch: 179. Batches seen: 0.
# Epoch: 179. Batches seen: 5.
# Epoch: 179. Batches seen: 10.
# Epoch: 179. Batches seen: 15.
# Epoch: 179. Batches seen: 20.
# Epoch: 180. Batches seen: 0.
# Epoch: 180. Batches seen: 5.
# Epoch: 180. Batches seen: 10.
# Epoch: 180. Batches seen: 15.
# Epoch: 180. Batches seen: 20.
# Epoch: 181. Batches seen: 0.
# Epoch: 181. Batches seen: 5.
# Epoch: 181. Batches seen: 10.
# Epoch: 181. Batches seen: 15.
# Epoch: 181. Batches seen: 20.
# Epoch: 182. Batches seen: 0.
# Epoch: 182. Batches seen: 5.
# Epoch: 182. Batches seen: 10.
# Epoch: 182. Batches seen: 15.
# Epoch: 182. Batches seen: 20.
# Epoch: 183. Batches seen: 0.
# Epoch: 183. Batches seen: 5.
# Epoch: 183. Batches seen: 10.
# Epoch: 183. Batches seen: 15.
# Epoch: 183. Batches seen: 20.
# Epoch: 184. Batches seen: 0.
# Epoch: 184. Batches seen: 5.
# Epoch: 184. Batches seen: 10.
# Epoch: 184. Batches seen: 15.
# Epoch: 184. Batches seen: 20.
# Epoch: 185. Batches seen: 0.
# Epoch: 185. Batches seen: 5.
# Epoch: 185. Batches seen: 10.
# Epoch: 185. Batches seen: 15.
# Epoch: 185. Batches seen: 20.
# Epoch: 186. Batches seen: 0.
# Epoch: 186. Batches seen: 5.
# Epoch: 186. Batches seen: 10.
# Epoch: 186. Batches seen: 15.
# Epoch: 186. Batches seen: 20.
# Epoch: 187. Batches seen: 0.
# Epoch: 187. Batches seen: 5.
# Epoch: 187. Batches seen: 10.
# Epoch: 187. Batches seen: 15.
# Epoch: 187. Batches seen: 20.
# Epoch: 188. Batches seen: 0.
# Epoch: 188. Batches seen: 5.
# Epoch: 188. Batches seen: 10.
# Epoch: 188. Batches seen: 15.
# Epoch: 188. Batches seen: 20.
# Epoch: 189. Batches seen: 0.
# Epoch: 189. Batches seen: 5.
# Epoch: 189. Batches seen: 10.
# Epoch: 189. Batches seen: 15.
# Epoch: 189. Batches seen: 20.
# Epoch: 190. Batches seen: 0.
# Epoch: 190. Batches seen: 5.
# Epoch: 190. Batches seen: 10.
# Epoch: 190. Batches seen: 15.
# Epoch: 190. Batches seen: 20.
# Epoch: 191. Batches seen: 0.
# Epoch: 191. Batches seen: 5.
# Epoch: 191. Batches seen: 10.
# Epoch: 191. Batches seen: 15.
# Epoch: 191. Batches seen: 20.
# Epoch: 192. Batches seen: 0.
# Epoch: 192. Batches seen: 5.
# Epoch: 192. Batches seen: 10.
# Epoch: 192. Batches seen: 15.
# Epoch: 192. Batches seen: 20.
# Epoch: 193. Batches seen: 0.
# Epoch: 193. Batches seen: 5.
# Epoch: 193. Batches seen: 10.
# Epoch: 193. Batches seen: 15.
# Epoch: 193. Batches seen: 20.
# Epoch: 194. Batches seen: 0.
# Epoch: 194. Batches seen: 5.
# Epoch: 194. Batches seen: 10.
# Epoch: 194. Batches seen: 15.
# Epoch: 194. Batches seen: 20.
# Epoch: 195. Batches seen: 0.
# Epoch: 195. Batches seen: 5.
# Epoch: 195. Batches seen: 10.
# Epoch: 195. Batches seen: 15.
# Epoch: 195. Batches seen: 20.
# Epoch: 196. Batches seen: 0.
# Epoch: 196. Batches seen: 5.
# Epoch: 196. Batches seen: 10.
# Epoch: 196. Batches seen: 15.
# Epoch: 196. Batches seen: 20.
# Epoch: 197. Batches seen: 0.
# Epoch: 197. Batches seen: 5.
# Epoch: 197. Batches seen: 10.
# Epoch: 197. Batches seen: 15.
# Epoch: 197. Batches seen: 20.
# Epoch: 198. Batches seen: 0.
# Epoch: 198. Batches seen: 5.
# Epoch: 198. Batches seen: 10.
# Epoch: 198. Batches seen: 15.
# Epoch: 198. Batches seen: 20.
# Epoch: 199. Batches seen: 0.
# Epoch: 199. Batches seen: 5.
# Epoch: 199. Batches seen: 10.
# Epoch: 199. Batches seen: 15.
# Epoch: 199. Batches seen: 20.
# Epoch: 200. Batches seen: 0.
# Epoch: 200. Batches seen: 5.
# Epoch: 200. Batches seen: 10.
# Epoch: 200. Batches seen: 15.
# Epoch: 200. Batches seen: 20.
# Epoch: 201. Batches seen: 0.
# Epoch: 201. Batches seen: 5.
# Epoch: 201. Batches seen: 10.
# Epoch: 201. Batches seen: 15.
# Epoch: 201. Batches seen: 20.
# Epoch: 202. Batches seen: 0.
# Epoch: 202. Batches seen: 5.
# Epoch: 202. Batches seen: 10.
# Epoch: 202. Batches seen: 15.
# Epoch: 202. Batches seen: 20.
# Epoch: 203. Batches seen: 0.
# Epoch: 203. Batches seen: 5.
# Epoch: 203. Batches seen: 10.
# Epoch: 203. Batches seen: 15.
# Epoch: 203. Batches seen: 20.
# Epoch: 204. Batches seen: 0.
# Epoch: 204. Batches seen: 5.
# Epoch: 204. Batches seen: 10.
# Epoch: 204. Batches seen: 15.
# Epoch: 204. Batches seen: 20.
# Epoch: 205. Batches seen: 0.
# Epoch: 205. Batches seen: 5.
# Epoch: 205. Batches seen: 10.
# Epoch: 205. Batches seen: 15.
# Epoch: 205. Batches seen: 20.
# Epoch: 206. Batches seen: 0.
# Epoch: 206. Batches seen: 5.
# Epoch: 206. Batches seen: 10.
# Epoch: 206. Batches seen: 15.
# Epoch: 206. Batches seen: 20.
# Epoch: 207. Batches seen: 0.
# Epoch: 207. Batches seen: 5.
# Epoch: 207. Batches seen: 10.
# Epoch: 207. Batches seen: 15.
# Epoch: 207. Batches seen: 20.
# Epoch: 208. Batches seen: 0.
# Epoch: 208. Batches seen: 5.
# Epoch: 208. Batches seen: 10.
# Epoch: 208. Batches seen: 15.
# Epoch: 208. Batches seen: 20.
# Epoch: 209. Batches seen: 0.
# Epoch: 209. Batches seen: 5.
# Epoch: 209. Batches seen: 10.
# Epoch: 209. Batches seen: 15.
# Epoch: 209. Batches seen: 20.
# Epoch: 210. Batches seen: 0.
# Epoch: 210. Batches seen: 5.
# Epoch: 210. Batches seen: 10.
# Epoch: 210. Batches seen: 15.
# Epoch: 210. Batches seen: 20.
# Epoch: 211. Batches seen: 0.
# Epoch: 211. Batches seen: 5.
# Epoch: 211. Batches seen: 10.
# Epoch: 211. Batches seen: 15.
# Epoch: 211. Batches seen: 20.
# Epoch: 212. Batches seen: 0.
# Epoch: 212. Batches seen: 5.
# Epoch: 212. Batches seen: 10.
# Epoch: 212. Batches seen: 15.
# Epoch: 212. Batches seen: 20.
# Epoch: 213. Batches seen: 0.
# Epoch: 213. Batches seen: 5.
# Epoch: 213. Batches seen: 10.
# Epoch: 213. Batches seen: 15.
# Epoch: 213. Batches seen: 20.
# Epoch: 214. Batches seen: 0.
# Epoch: 214. Batches seen: 5.
# Epoch: 214. Batches seen: 10.
# Epoch: 214. Batches seen: 15.
# Epoch: 214. Batches seen: 20.
# Epoch: 215. Batches seen: 0.
# Epoch: 215. Batches seen: 5.
# Epoch: 215. Batches seen: 10.
# Epoch: 215. Batches seen: 15.
# Epoch: 215. Batches seen: 20.
# Epoch: 216. Batches seen: 0.
# Epoch: 216. Batches seen: 5.
# Epoch: 216. Batches seen: 10.
# Epoch: 216. Batches seen: 15.
# Epoch: 216. Batches seen: 20.
# Epoch: 217. Batches seen: 0.
# Epoch: 217. Batches seen: 5.
# Epoch: 217. Batches seen: 10.
# Epoch: 217. Batches seen: 15.
# Epoch: 217. Batches seen: 20.
# Epoch: 218. Batches seen: 0.
# Epoch: 218. Batches seen: 5.
# Epoch: 218. Batches seen: 10.
# Epoch: 218. Batches seen: 15.
# Epoch: 218. Batches seen: 20.
# Epoch: 219. Batches seen: 0.
# Epoch: 219. Batches seen: 5.
# Epoch: 219. Batches seen: 10.
# Epoch: 219. Batches seen: 15.
# Epoch: 219. Batches seen: 20.
# Epoch: 220. Batches seen: 0.
# Epoch: 220. Batches seen: 5.
# Epoch: 220. Batches seen: 10.
# Epoch: 220. Batches seen: 15.
# Epoch: 220. Batches seen: 20.
# Epoch: 221. Batches seen: 0.
# Epoch: 221. Batches seen: 5.
# Epoch: 221. Batches seen: 10.
# Epoch: 221. Batches seen: 15.
# Epoch: 221. Batches seen: 20.
# Epoch: 222. Batches seen: 0.
# Epoch: 222. Batches seen: 5.
# Epoch: 222. Batches seen: 10.
# Epoch: 222. Batches seen: 15.
# Epoch: 222. Batches seen: 20.
# Epoch: 223. Batches seen: 0.
# Epoch: 223. Batches seen: 5.
# Epoch: 223. Batches seen: 10.
# Epoch: 223. Batches seen: 15.
# Epoch: 223. Batches seen: 20.
# Epoch: 224. Batches seen: 0.
# Epoch: 224. Batches seen: 5.
# Epoch: 224. Batches seen: 10.
# Epoch: 224. Batches seen: 15.
# Epoch: 224. Batches seen: 20.
# Epoch: 225. Batches seen: 0.
# Epoch: 225. Batches seen: 5.
# Epoch: 225. Batches seen: 10.
# Epoch: 225. Batches seen: 15.
# Epoch: 225. Batches seen: 20.
# Epoch: 226. Batches seen: 0.
# Epoch: 226. Batches seen: 5.
# Epoch: 226. Batches seen: 10.
# Epoch: 226. Batches seen: 15.
# Epoch: 226. Batches seen: 20.
# Epoch: 227. Batches seen: 0.
# Epoch: 227. Batches seen: 5.
# Epoch: 227. Batches seen: 10.
# Epoch: 227. Batches seen: 15.
# Epoch: 227. Batches seen: 20.
# Epoch: 228. Batches seen: 0.
# Epoch: 228. Batches seen: 5.
# Epoch: 228. Batches seen: 10.
# Epoch: 228. Batches seen: 15.
# Epoch: 228. Batches seen: 20.
# Epoch: 229. Batches seen: 0.
# Epoch: 229. Batches seen: 5.
# Epoch: 229. Batches seen: 10.
# Epoch: 229. Batches seen: 15.
# Epoch: 229. Batches seen: 20.
# Epoch: 230. Batches seen: 0.
# Epoch: 230. Batches seen: 5.
# Epoch: 230. Batches seen: 10.
# Epoch: 230. Batches seen: 15.
# Epoch: 230. Batches seen: 20.
# Epoch: 231. Batches seen: 0.
# Epoch: 231. Batches seen: 5.
# Epoch: 231. Batches seen: 10.
# Epoch: 231. Batches seen: 15.
# Epoch: 231. Batches seen: 20.
# Epoch: 232. Batches seen: 0.
# Epoch: 232. Batches seen: 5.
# Epoch: 232. Batches seen: 10.
# Epoch: 232. Batches seen: 15.
# Epoch: 232. Batches seen: 20.
# Epoch: 233. Batches seen: 0.
# Epoch: 233. Batches seen: 5.
# Epoch: 233. Batches seen: 10.
# Epoch: 233. Batches seen: 15.
# Epoch: 233. Batches seen: 20.
# Epoch: 234. Batches seen: 0.
# Epoch: 234. Batches seen: 5.
# Epoch: 234. Batches seen: 10.
# Epoch: 234. Batches seen: 15.
# Epoch: 234. Batches seen: 20.
# Epoch: 235. Batches seen: 0.
# Epoch: 235. Batches seen: 5.
# Epoch: 235. Batches seen: 10.
# Epoch: 235. Batches seen: 15.
# Epoch: 235. Batches seen: 20.
# Epoch: 236. Batches seen: 0.
# Epoch: 236. Batches seen: 5.
# Epoch: 236. Batches seen: 10.
# Epoch: 236. Batches seen: 15.
# Epoch: 236. Batches seen: 20.
# Epoch: 237. Batches seen: 0.
# Epoch: 237. Batches seen: 5.
# Epoch: 237. Batches seen: 10.
# Epoch: 237. Batches seen: 15.
# Epoch: 237. Batches seen: 20.
# Epoch: 238. Batches seen: 0.
# Epoch: 238. Batches seen: 5.
# Epoch: 238. Batches seen: 10.
# Epoch: 238. Batches seen: 15.
# Epoch: 238. Batches seen: 20.
# Epoch: 239. Batches seen: 0.
# Epoch: 239. Batches seen: 5.
# Epoch: 239. Batches seen: 10.
# Epoch: 239. Batches seen: 15.
# Epoch: 239. Batches seen: 20.
# Epoch: 240. Batches seen: 0.
# Epoch: 240. Batches seen: 5.
# Epoch: 240. Batches seen: 10.
# Epoch: 240. Batches seen: 15.
# Epoch: 240. Batches seen: 20.
# Epoch: 241. Batches seen: 0.
# Epoch: 241. Batches seen: 5.
# Epoch: 241. Batches seen: 10.
# Epoch: 241. Batches seen: 15.
# Epoch: 241. Batches seen: 20.
# Epoch: 242. Batches seen: 0.
# Epoch: 242. Batches seen: 5.
# Epoch: 242. Batches seen: 10.
# Epoch: 242. Batches seen: 15.
# Epoch: 242. Batches seen: 20.
# Epoch: 243. Batches seen: 0.
# Epoch: 243. Batches seen: 5.
# Epoch: 243. Batches seen: 10.
# Epoch: 243. Batches seen: 15.
# Epoch: 243. Batches seen: 20.
# Epoch: 244. Batches seen: 0.
# Epoch: 244. Batches seen: 5.
# Epoch: 244. Batches seen: 10.
# Epoch: 244. Batches seen: 15.
# Epoch: 244. Batches seen: 20.
# Epoch: 245. Batches seen: 0.
# Epoch: 245. Batches seen: 5.
# Epoch: 245. Batches seen: 10.
# Epoch: 245. Batches seen: 15.
# Epoch: 245. Batches seen: 20.
# Epoch: 246. Batches seen: 0.
# Epoch: 246. Batches seen: 5.
# Epoch: 246. Batches seen: 10.
# Epoch: 246. Batches seen: 15.
# Epoch: 246. Batches seen: 20.
# Epoch: 247. Batches seen: 0.
# Epoch: 247. Batches seen: 5.
# Epoch: 247. Batches seen: 10.
# Epoch: 247. Batches seen: 15.
# Epoch: 247. Batches seen: 20.
# Epoch: 248. Batches seen: 0.
# Epoch: 248. Batches seen: 5.
# Epoch: 248. Batches seen: 10.
# Epoch: 248. Batches seen: 15.
# Epoch: 248. Batches seen: 20.
# Epoch: 249. Batches seen: 0.
# Epoch: 249. Batches seen: 5.
# Epoch: 249. Batches seen: 10.
# Epoch: 249. Batches seen: 15.
# Epoch: 249. Batches seen: 20.
# Epoch: 250. Batches seen: 0.
# Epoch: 250. Batches seen: 5.
# Epoch: 250. Batches seen: 10.
# Epoch: 250. Batches seen: 15.
# Epoch: 250. Batches seen: 20.
# Epoch: 251. Batches seen: 0.
# Epoch: 251. Batches seen: 5.
# Epoch: 251. Batches seen: 10.
# Epoch: 251. Batches seen: 15.
# Epoch: 251. Batches seen: 20.
# Epoch: 252. Batches seen: 0.
# Epoch: 252. Batches seen: 5.
# Epoch: 252. Batches seen: 10.
# Epoch: 252. Batches seen: 15.
# Epoch: 252. Batches seen: 20.
# Epoch: 253. Batches seen: 0.
# Epoch: 253. Batches seen: 5.
# Epoch: 253. Batches seen: 10.
# Epoch: 253. Batches seen: 15.
# Epoch: 253. Batches seen: 20.
# Epoch: 254. Batches seen: 0.
# Epoch: 254. Batches seen: 5.
# Epoch: 254. Batches seen: 10.
# Epoch: 254. Batches seen: 15.
# Epoch: 254. Batches seen: 20.
# Epoch: 255. Batches seen: 0.
# Epoch: 255. Batches seen: 5.
# Epoch: 255. Batches seen: 10.
# Epoch: 255. Batches seen: 15.
# Epoch: 255. Batches seen: 20.
# Epoch: 256. Batches seen: 0.
# Epoch: 256. Batches seen: 5.
# Epoch: 256. Batches seen: 10.
# Epoch: 256. Batches seen: 15.
# Epoch: 256. Batches seen: 20.
# Epoch: 257. Batches seen: 0.
# Epoch: 257. Batches seen: 5.
# Epoch: 257. Batches seen: 10.
# Epoch: 257. Batches seen: 15.
# Epoch: 257. Batches seen: 20.
# Epoch: 258. Batches seen: 0.
# Epoch: 258. Batches seen: 5.
# Epoch: 258. Batches seen: 10.
# Epoch: 258. Batches seen: 15.
# Epoch: 258. Batches seen: 20.
# Epoch: 259. Batches seen: 0.
# Epoch: 259. Batches seen: 5.
# Epoch: 259. Batches seen: 10.
# Epoch: 259. Batches seen: 15.
# Epoch: 259. Batches seen: 20.
# Epoch: 260. Batches seen: 0.
# Epoch: 260. Batches seen: 5.
# Epoch: 260. Batches seen: 10.
# Epoch: 260. Batches seen: 15.
# Epoch: 260. Batches seen: 20.
# Epoch: 261. Batches seen: 0.
# Epoch: 261. Batches seen: 5.
# Epoch: 261. Batches seen: 10.
# Epoch: 261. Batches seen: 15.
# Epoch: 261. Batches seen: 20.
# Epoch: 262. Batches seen: 0.
# Epoch: 262. Batches seen: 5.
# Epoch: 262. Batches seen: 10.
# Epoch: 262. Batches seen: 15.
# Epoch: 262. Batches seen: 20.
# Epoch: 263. Batches seen: 0.
# Epoch: 263. Batches seen: 5.
# Epoch: 263. Batches seen: 10.
# Epoch: 263. Batches seen: 15.
# Epoch: 263. Batches seen: 20.
# Epoch: 264. Batches seen: 0.
# Epoch: 264. Batches seen: 5.
# Epoch: 264. Batches seen: 10.
# Epoch: 264. Batches seen: 15.
# Epoch: 264. Batches seen: 20.
# Epoch: 265. Batches seen: 0.
# Epoch: 265. Batches seen: 5.
# Epoch: 265. Batches seen: 10.
# Epoch: 265. Batches seen: 15.
# Epoch: 265. Batches seen: 20.
# Epoch: 266. Batches seen: 0.
# Epoch: 266. Batches seen: 5.
# Epoch: 266. Batches seen: 10.
# Epoch: 266. Batches seen: 15.
# Epoch: 266. Batches seen: 20.
# Epoch: 267. Batches seen: 0.
# Epoch: 267. Batches seen: 5.
# Epoch: 267. Batches seen: 10.
# Epoch: 267. Batches seen: 15.
# Epoch: 267. Batches seen: 20.
# Epoch: 268. Batches seen: 0.
# Epoch: 268. Batches seen: 5.
# Epoch: 268. Batches seen: 10.
# Epoch: 268. Batches seen: 15.
# Epoch: 268. Batches seen: 20.
# Epoch: 269. Batches seen: 0.
# Epoch: 269. Batches seen: 5.
# Epoch: 269. Batches seen: 10.
# Epoch: 269. Batches seen: 15.
# Epoch: 269. Batches seen: 20.
# Epoch: 270. Batches seen: 0.
# Epoch: 270. Batches seen: 5.
# Epoch: 270. Batches seen: 10.
# Epoch: 270. Batches seen: 15.
# Epoch: 270. Batches seen: 20.
# Epoch: 271. Batches seen: 0.
# Epoch: 271. Batches seen: 5.
# Epoch: 271. Batches seen: 10.
# Epoch: 271. Batches seen: 15.
# Epoch: 271. Batches seen: 20.
# Epoch: 272. Batches seen: 0.
# Epoch: 272. Batches seen: 5.
# Epoch: 272. Batches seen: 10.
# Epoch: 272. Batches seen: 15.
# Epoch: 272. Batches seen: 20.
# Epoch: 273. Batches seen: 0.
# Epoch: 273. Batches seen: 5.
# Epoch: 273. Batches seen: 10.
# Epoch: 273. Batches seen: 15.
# Epoch: 273. Batches seen: 20.
# Epoch: 274. Batches seen: 0.
# Epoch: 274. Batches seen: 5.
# Epoch: 274. Batches seen: 10.
# Epoch: 274. Batches seen: 15.
# Epoch: 274. Batches seen: 20.
# Epoch: 275. Batches seen: 0.
# Epoch: 275. Batches seen: 5.
# Epoch: 275. Batches seen: 10.
# Epoch: 275. Batches seen: 15.
# Epoch: 275. Batches seen: 20.
# Epoch: 276. Batches seen: 0.
# Epoch: 276. Batches seen: 5.
# Epoch: 276. Batches seen: 10.
# Epoch: 276. Batches seen: 15.
# Epoch: 276. Batches seen: 20.
# Epoch: 277. Batches seen: 0.
# Epoch: 277. Batches seen: 5.
# Epoch: 277. Batches seen: 10.
# Epoch: 277. Batches seen: 15.
# Epoch: 277. Batches seen: 20.
# Epoch: 278. Batches seen: 0.
# Epoch: 278. Batches seen: 5.
# Epoch: 278. Batches seen: 10.
# Epoch: 278. Batches seen: 15.
# Epoch: 278. Batches seen: 20.
# Epoch: 279. Batches seen: 0.
# Epoch: 279. Batches seen: 5.
# Epoch: 279. Batches seen: 10.
# Epoch: 279. Batches seen: 15.
# Epoch: 279. Batches seen: 20.
# Epoch: 280. Batches seen: 0.
# Epoch: 280. Batches seen: 5.
# Epoch: 280. Batches seen: 10.
# Epoch: 280. Batches seen: 15.
# Epoch: 280. Batches seen: 20.
# Epoch: 281. Batches seen: 0.
# Epoch: 281. Batches seen: 5.
# Epoch: 281. Batches seen: 10.
# Epoch: 281. Batches seen: 15.
# Epoch: 281. Batches seen: 20.
# Epoch: 282. Batches seen: 0.
# Epoch: 282. Batches seen: 5.
# Epoch: 282. Batches seen: 10.
# Epoch: 282. Batches seen: 15.
# Epoch: 282. Batches seen: 20.
# Epoch: 283. Batches seen: 0.
# Epoch: 283. Batches seen: 5.
# Epoch: 283. Batches seen: 10.
# Epoch: 283. Batches seen: 15.
# Epoch: 283. Batches seen: 20.
# Epoch: 284. Batches seen: 0.
# Epoch: 284. Batches seen: 5.
# Epoch: 284. Batches seen: 10.
# Epoch: 284. Batches seen: 15.
# Epoch: 284. Batches seen: 20.
# Epoch: 285. Batches seen: 0.
# Epoch: 285. Batches seen: 5.
# Epoch: 285. Batches seen: 10.
# Epoch: 285. Batches seen: 15.
# Epoch: 285. Batches seen: 20.
# Epoch: 286. Batches seen: 0.
# Epoch: 286. Batches seen: 5.
# Epoch: 286. Batches seen: 10.
# Epoch: 286. Batches seen: 15.
# Epoch: 286. Batches seen: 20.
# Epoch: 287. Batches seen: 0.
# Epoch: 287. Batches seen: 5.
# Epoch: 287. Batches seen: 10.
# Epoch: 287. Batches seen: 15.
# Epoch: 287. Batches seen: 20.
# Epoch: 288. Batches seen: 0.
# Epoch: 288. Batches seen: 5.
# Epoch: 288. Batches seen: 10.
# Epoch: 288. Batches seen: 15.
# Epoch: 288. Batches seen: 20.
# Epoch: 289. Batches seen: 0.
# Epoch: 289. Batches seen: 5.
# Epoch: 289. Batches seen: 10.
# Epoch: 289. Batches seen: 15.
# Epoch: 289. Batches seen: 20.
# Epoch: 290. Batches seen: 0.
# Epoch: 290. Batches seen: 5.
# Epoch: 290. Batches seen: 10.
# Epoch: 290. Batches seen: 15.
# Epoch: 290. Batches seen: 20.
# Epoch: 291. Batches seen: 0.
# Epoch: 291. Batches seen: 5.
# Epoch: 291. Batches seen: 10.
# Epoch: 291. Batches seen: 15.
# Epoch: 291. Batches seen: 20.
# Epoch: 292. Batches seen: 0.
# Epoch: 292. Batches seen: 5.
# Epoch: 292. Batches seen: 10.
# Epoch: 292. Batches seen: 15.
# Epoch: 292. Batches seen: 20.
# Epoch: 293. Batches seen: 0.
# Epoch: 293. Batches seen: 5.
# Epoch: 293. Batches seen: 10.
# Epoch: 293. Batches seen: 15.
# Epoch: 293. Batches seen: 20.
# Epoch: 294. Batches seen: 0.
# Epoch: 294. Batches seen: 5.
# Epoch: 294. Batches seen: 10.
# Epoch: 294. Batches seen: 15.
# Epoch: 294. Batches seen: 20.
# Epoch: 295. Batches seen: 0.
# Epoch: 295. Batches seen: 5.
# Epoch: 295. Batches seen: 10.
# Epoch: 295. Batches seen: 15.
# Epoch: 295. Batches seen: 20.
# Epoch: 296. Batches seen: 0.
# Epoch: 296. Batches seen: 5.
# Epoch: 296. Batches seen: 10.
# Epoch: 296. Batches seen: 15.
# Epoch: 296. Batches seen: 20.
# Epoch: 297. Batches seen: 0.
# Epoch: 297. Batches seen: 5.
# Epoch: 297. Batches seen: 10.
# Epoch: 297. Batches seen: 15.
# Epoch: 297. Batches seen: 20.
# Epoch: 298. Batches seen: 0.
# Epoch: 298. Batches seen: 5.
# Epoch: 298. Batches seen: 10.
# Epoch: 298. Batches seen: 15.
# Epoch: 298. Batches seen: 20.
# Epoch: 299. Batches seen: 0.
# Epoch: 299. Batches seen: 5.
# Epoch: 299. Batches seen: 10.
# Epoch: 299. Batches seen: 15.
# Epoch: 299. Batches seen: 20.
# Epoch: 300. Batches seen: 0.
# Epoch: 300. Batches seen: 5.
# Epoch: 300. Batches seen: 10.
# Epoch: 300. Batches seen: 15.
# Epoch: 300. Batches seen: 20.
# Epoch: 301. Batches seen: 0.
# Epoch: 301. Batches seen: 5.
# Epoch: 301. Batches seen: 10.
# Epoch: 301. Batches seen: 15.
# Epoch: 301. Batches seen: 20.
# Epoch: 302. Batches seen: 0.
# Epoch: 302. Batches seen: 5.
# Epoch: 302. Batches seen: 10.
# Epoch: 302. Batches seen: 15.
# Epoch: 302. Batches seen: 20.
# Epoch: 303. Batches seen: 0.
# Epoch: 303. Batches seen: 5.
# Epoch: 303. Batches seen: 10.
# Epoch: 303. Batches seen: 15.
# Epoch: 303. Batches seen: 20.
# Epoch: 304. Batches seen: 0.
# Epoch: 304. Batches seen: 5.
# Epoch: 304. Batches seen: 10.
# Epoch: 304. Batches seen: 15.
# Epoch: 304. Batches seen: 20.
# Epoch: 305. Batches seen: 0.
# Epoch: 305. Batches seen: 5.
# Epoch: 305. Batches seen: 10.
# Epoch: 305. Batches seen: 15.
# Epoch: 305. Batches seen: 20.
# Epoch: 306. Batches seen: 0.
# Epoch: 306. Batches seen: 5.
# Epoch: 306. Batches seen: 10.
# Epoch: 306. Batches seen: 15.
# Epoch: 306. Batches seen: 20.
# Epoch: 307. Batches seen: 0.
# Epoch: 307. Batches seen: 5.
# Epoch: 307. Batches seen: 10.
# Epoch: 307. Batches seen: 15.
# Epoch: 307. Batches seen: 20.
# Epoch: 308. Batches seen: 0.
# Epoch: 308. Batches seen: 5.
# Epoch: 308. Batches seen: 10.
# Epoch: 308. Batches seen: 15.
# Epoch: 308. Batches seen: 20.
# Epoch: 309. Batches seen: 0.
# Epoch: 309. Batches seen: 5.
# Epoch: 309. Batches seen: 10.
# Epoch: 309. Batches seen: 15.
# Epoch: 309. Batches seen: 20.
# Epoch: 310. Batches seen: 0.
# Epoch: 310. Batches seen: 5.
# Epoch: 310. Batches seen: 10.
# Epoch: 310. Batches seen: 15.
# Epoch: 310. Batches seen: 20.
# Epoch: 311. Batches seen: 0.
# Epoch: 311. Batches seen: 5.
# Epoch: 311. Batches seen: 10.
# Epoch: 311. Batches seen: 15.
# Epoch: 311. Batches seen: 20.
# Epoch: 312. Batches seen: 0.
# Epoch: 312. Batches seen: 5.
# Epoch: 312. Batches seen: 10.
# Epoch: 312. Batches seen: 15.
# Epoch: 312. Batches seen: 20.
# Epoch: 313. Batches seen: 0.
# Epoch: 313. Batches seen: 5.
# Epoch: 313. Batches seen: 10.
# Epoch: 313. Batches seen: 15.
# Epoch: 313. Batches seen: 20.
# Epoch: 314. Batches seen: 0.
# Epoch: 314. Batches seen: 5.
# Epoch: 314. Batches seen: 10.
# Epoch: 314. Batches seen: 15.
# Epoch: 314. Batches seen: 20.
# Epoch: 315. Batches seen: 0.
# Epoch: 315. Batches seen: 5.
# Epoch: 315. Batches seen: 10.
# Epoch: 315. Batches seen: 15.
# Epoch: 315. Batches seen: 20.
# Epoch: 316. Batches seen: 0.
# Epoch: 316. Batches seen: 5.
# Epoch: 316. Batches seen: 10.
# Epoch: 316. Batches seen: 15.
# Epoch: 316. Batches seen: 20.
# Epoch: 317. Batches seen: 0.
# Epoch: 317. Batches seen: 5.
# Epoch: 317. Batches seen: 10.
# Epoch: 317. Batches seen: 15.
# Epoch: 317. Batches seen: 20.
# Epoch: 318. Batches seen: 0.
# Epoch: 318. Batches seen: 5.
# Epoch: 318. Batches seen: 10.
# Epoch: 318. Batches seen: 15.
# Epoch: 318. Batches seen: 20.
# Epoch: 319. Batches seen: 0.
# Epoch: 319. Batches seen: 5.
# Epoch: 319. Batches seen: 10.
# Epoch: 319. Batches seen: 15.
# Epoch: 319. Batches seen: 20.
# Epoch: 320. Batches seen: 0.
# Epoch: 320. Batches seen: 5.
# Epoch: 320. Batches seen: 10.
# Epoch: 320. Batches seen: 15.
# Epoch: 320. Batches seen: 20.
# Epoch: 321. Batches seen: 0.
# Epoch: 321. Batches seen: 5.
# Epoch: 321. Batches seen: 10.
# Epoch: 321. Batches seen: 15.
# Epoch: 321. Batches seen: 20.
# Epoch: 322. Batches seen: 0.
# Epoch: 322. Batches seen: 5.
# Epoch: 322. Batches seen: 10.
# Epoch: 322. Batches seen: 15.
# Epoch: 322. Batches seen: 20.
# Epoch: 323. Batches seen: 0.
# Epoch: 323. Batches seen: 5.
# Epoch: 323. Batches seen: 10.
# Epoch: 323. Batches seen: 15.
# Epoch: 323. Batches seen: 20.
# Epoch: 324. Batches seen: 0.
# Epoch: 324. Batches seen: 5.
# Epoch: 324. Batches seen: 10.
# Epoch: 324. Batches seen: 15.
# Epoch: 324. Batches seen: 20.
# Epoch: 325. Batches seen: 0.
# Epoch: 325. Batches seen: 5.
# Epoch: 325. Batches seen: 10.
# Epoch: 325. Batches seen: 15.
# Epoch: 325. Batches seen: 20.
# Epoch: 326. Batches seen: 0.
# Epoch: 326. Batches seen: 5.
# Epoch: 326. Batches seen: 10.
# Epoch: 326. Batches seen: 15.
# Epoch: 326. Batches seen: 20.
# Epoch: 327. Batches seen: 0.
# Epoch: 327. Batches seen: 5.
# Epoch: 327. Batches seen: 10.
# Epoch: 327. Batches seen: 15.
# Epoch: 327. Batches seen: 20.
# Epoch: 328. Batches seen: 0.
# Epoch: 328. Batches seen: 5.
# Epoch: 328. Batches seen: 10.
# Epoch: 328. Batches seen: 15.
# Epoch: 328. Batches seen: 20.
# Epoch: 329. Batches seen: 0.
# Epoch: 329. Batches seen: 5.
# Epoch: 329. Batches seen: 10.
# Epoch: 329. Batches seen: 15.
# Epoch: 329. Batches seen: 20.
# Epoch: 330. Batches seen: 0.
# Epoch: 330. Batches seen: 5.
# Epoch: 330. Batches seen: 10.
# Epoch: 330. Batches seen: 15.
# Epoch: 330. Batches seen: 20.
# Epoch: 331. Batches seen: 0.
# Epoch: 331. Batches seen: 5.
# Epoch: 331. Batches seen: 10.
# Epoch: 331. Batches seen: 15.
# Epoch: 331. Batches seen: 20.
# Epoch: 332. Batches seen: 0.
# Epoch: 332. Batches seen: 5.
# Epoch: 332. Batches seen: 10.
# Epoch: 332. Batches seen: 15.
# Epoch: 332. Batches seen: 20.
# Epoch: 333. Batches seen: 0.
# Epoch: 333. Batches seen: 5.
# Epoch: 333. Batches seen: 10.
# Epoch: 333. Batches seen: 15.
# Epoch: 333. Batches seen: 20.
# Epoch: 334. Batches seen: 0.
# Epoch: 334. Batches seen: 5.
# Epoch: 334. Batches seen: 10.
# Epoch: 334. Batches seen: 15.
# Epoch: 334. Batches seen: 20.
# Epoch: 335. Batches seen: 0.
# Epoch: 335. Batches seen: 5.
# Epoch: 335. Batches seen: 10.
# Epoch: 335. Batches seen: 15.
# Epoch: 335. Batches seen: 20.
# Epoch: 336. Batches seen: 0.
# Epoch: 336. Batches seen: 5.
# Epoch: 336. Batches seen: 10.
# Epoch: 336. Batches seen: 15.
# Epoch: 336. Batches seen: 20.
# Epoch: 337. Batches seen: 0.
# Epoch: 337. Batches seen: 5.
# Epoch: 337. Batches seen: 10.
# Epoch: 337. Batches seen: 15.
# Epoch: 337. Batches seen: 20.
# Epoch: 338. Batches seen: 0.
# Epoch: 338. Batches seen: 5.
# Epoch: 338. Batches seen: 10.
# Epoch: 338. Batches seen: 15.
# Epoch: 338. Batches seen: 20.
# Epoch: 339. Batches seen: 0.
# Epoch: 339. Batches seen: 5.
# Epoch: 339. Batches seen: 10.
# Epoch: 339. Batches seen: 15.
# Epoch: 339. Batches seen: 20.
# Epoch: 340. Batches seen: 0.
# Epoch: 340. Batches seen: 5.
# Epoch: 340. Batches seen: 10.
# Epoch: 340. Batches seen: 15.
# Epoch: 340. Batches seen: 20.
# Epoch: 341. Batches seen: 0.
# Epoch: 341. Batches seen: 5.
# Epoch: 341. Batches seen: 10.
# Epoch: 341. Batches seen: 15.
# Epoch: 341. Batches seen: 20.
# Epoch: 342. Batches seen: 0.
# Epoch: 342. Batches seen: 5.
# Epoch: 342. Batches seen: 10.
# Epoch: 342. Batches seen: 15.
# Epoch: 342. Batches seen: 20.
# Epoch: 343. Batches seen: 0.
# Epoch: 343. Batches seen: 5.
# Epoch: 343. Batches seen: 10.
# Epoch: 343. Batches seen: 15.
# Epoch: 343. Batches seen: 20.
# Epoch: 344. Batches seen: 0.
# Epoch: 344. Batches seen: 5.
# Epoch: 344. Batches seen: 10.
# Epoch: 344. Batches seen: 15.
# Epoch: 344. Batches seen: 20.
# Epoch: 345. Batches seen: 0.
# Epoch: 345. Batches seen: 5.
# Epoch: 345. Batches seen: 10.
# Epoch: 345. Batches seen: 15.
# Epoch: 345. Batches seen: 20.
# Epoch: 346. Batches seen: 0.
# Epoch: 346. Batches seen: 5.
# Epoch: 346. Batches seen: 10.
# Epoch: 346. Batches seen: 15.
# Epoch: 346. Batches seen: 20.
# Epoch: 347. Batches seen: 0.
# Epoch: 347. Batches seen: 5.
# Epoch: 347. Batches seen: 10.
# Epoch: 347. Batches seen: 15.
# Epoch: 347. Batches seen: 20.
# Epoch: 348. Batches seen: 0.
# Epoch: 348. Batches seen: 5.
# Epoch: 348. Batches seen: 10.
# Epoch: 348. Batches seen: 15.
# Epoch: 348. Batches seen: 20.
# Epoch: 349. Batches seen: 0.
# Epoch: 349. Batches seen: 5.
# Epoch: 349. Batches seen: 10.
# Epoch: 349. Batches seen: 15.
# Epoch: 349. Batches seen: 20.
# Epoch: 350. Batches seen: 0.
# Epoch: 350. Batches seen: 5.
# Epoch: 350. Batches seen: 10.
# Epoch: 350. Batches seen: 15.
# Epoch: 350. Batches seen: 20.
# Epoch: 351. Batches seen: 0.
# Epoch: 351. Batches seen: 5.
# Epoch: 351. Batches seen: 10.
# Epoch: 351. Batches seen: 15.
# Epoch: 351. Batches seen: 20.
# Epoch: 352. Batches seen: 0.
# Epoch: 352. Batches seen: 5.
# Epoch: 352. Batches seen: 10.
# Epoch: 352. Batches seen: 15.
# Epoch: 352. Batches seen: 20.
# Epoch: 353. Batches seen: 0.
# Epoch: 353. Batches seen: 5.
# Epoch: 353. Batches seen: 10.
# Epoch: 353. Batches seen: 15.
# Epoch: 353. Batches seen: 20.
# Epoch: 354. Batches seen: 0.
# Epoch: 354. Batches seen: 5.
# Epoch: 354. Batches seen: 10.
# Epoch: 354. Batches seen: 15.
# Epoch: 354. Batches seen: 20.
# Epoch: 355. Batches seen: 0.
# Epoch: 355. Batches seen: 5.
# Epoch: 355. Batches seen: 10.
# Epoch: 355. Batches seen: 15.
# Epoch: 355. Batches seen: 20.
# Epoch: 356. Batches seen: 0.
# Epoch: 356. Batches seen: 5.
# Epoch: 356. Batches seen: 10.
# Epoch: 356. Batches seen: 15.
# Epoch: 356. Batches seen: 20.
# Epoch: 357. Batches seen: 0.
# Epoch: 357. Batches seen: 5.
# Epoch: 357. Batches seen: 10.
# Epoch: 357. Batches seen: 15.
# Epoch: 357. Batches seen: 20.
# Epoch: 358. Batches seen: 0.
# Epoch: 358. Batches seen: 5.
# Epoch: 358. Batches seen: 10.
# Epoch: 358. Batches seen: 15.
# Epoch: 358. Batches seen: 20.
# Epoch: 359. Batches seen: 0.
# Epoch: 359. Batches seen: 5.
# Epoch: 359. Batches seen: 10.
# Epoch: 359. Batches seen: 15.
# Epoch: 359. Batches seen: 20.
# Epoch: 360. Batches seen: 0.
# Epoch: 360. Batches seen: 5.
# Epoch: 360. Batches seen: 10.
# Epoch: 360. Batches seen: 15.
# Epoch: 360. Batches seen: 20.
# Epoch: 361. Batches seen: 0.
# Epoch: 361. Batches seen: 5.
# Epoch: 361. Batches seen: 10.
# Epoch: 361. Batches seen: 15.
# Epoch: 361. Batches seen: 20.
# Epoch: 362. Batches seen: 0.
# Epoch: 362. Batches seen: 5.
# Epoch: 362. Batches seen: 10.
# Epoch: 362. Batches seen: 15.
# Epoch: 362. Batches seen: 20.
# Epoch: 363. Batches seen: 0.
# Epoch: 363. Batches seen: 5.
# Epoch: 363. Batches seen: 10.
# Epoch: 363. Batches seen: 15.
# Epoch: 363. Batches seen: 20.
# Epoch: 364. Batches seen: 0.
# Epoch: 364. Batches seen: 5.
# Epoch: 364. Batches seen: 10.
# Epoch: 364. Batches seen: 15.
# Epoch: 364. Batches seen: 20.
# Epoch: 365. Batches seen: 0.
# Epoch: 365. Batches seen: 5.
# Epoch: 365. Batches seen: 10.
# Epoch: 365. Batches seen: 15.
# Epoch: 365. Batches seen: 20.
# Epoch: 366. Batches seen: 0.
# Epoch: 366. Batches seen: 5.
# Epoch: 366. Batches seen: 10.
# Epoch: 366. Batches seen: 15.
# Epoch: 366. Batches seen: 20.
# Epoch: 367. Batches seen: 0.
# Epoch: 367. Batches seen: 5.
# Epoch: 367. Batches seen: 10.
# Epoch: 367. Batches seen: 15.
# Epoch: 367. Batches seen: 20.
# Epoch: 368. Batches seen: 0.
# Epoch: 368. Batches seen: 5.
# Epoch: 368. Batches seen: 10.
# Epoch: 368. Batches seen: 15.
# Epoch: 368. Batches seen: 20.
# Epoch: 369. Batches seen: 0.
# Epoch: 369. Batches seen: 5.
# Epoch: 369. Batches seen: 10.
# Epoch: 369. Batches seen: 15.
# Epoch: 369. Batches seen: 20.
# Epoch: 370. Batches seen: 0.
# Epoch: 370. Batches seen: 5.
# Epoch: 370. Batches seen: 10.
# Epoch: 370. Batches seen: 15.
# Epoch: 370. Batches seen: 20.
# Epoch: 371. Batches seen: 0.
# Epoch: 371. Batches seen: 5.
# Epoch: 371. Batches seen: 10.
# Epoch: 371. Batches seen: 15.
# Epoch: 371. Batches seen: 20.
# Epoch: 372. Batches seen: 0.
# Epoch: 372. Batches seen: 5.
# Epoch: 372. Batches seen: 10.
# Epoch: 372. Batches seen: 15.
# Epoch: 372. Batches seen: 20.
# Epoch: 373. Batches seen: 0.
# Epoch: 373. Batches seen: 5.
# Epoch: 373. Batches seen: 10.
# Epoch: 373. Batches seen: 15.
# Epoch: 373. Batches seen: 20.
# Epoch: 374. Batches seen: 0.
# Epoch: 374. Batches seen: 5.
# Epoch: 374. Batches seen: 10.
# Epoch: 374. Batches seen: 15.
# Epoch: 374. Batches seen: 20.
# Epoch: 375. Batches seen: 0.
# Epoch: 375. Batches seen: 5.
# Epoch: 375. Batches seen: 10.
# Epoch: 375. Batches seen: 15.
# Epoch: 375. Batches seen: 20.
# Epoch: 376. Batches seen: 0.
# Epoch: 376. Batches seen: 5.
# Epoch: 376. Batches seen: 10.
# Epoch: 376. Batches seen: 15.
# Epoch: 376. Batches seen: 20.
# Epoch: 377. Batches seen: 0.
# Epoch: 377. Batches seen: 5.
# Epoch: 377. Batches seen: 10.
# Epoch: 377. Batches seen: 15.
# Epoch: 377. Batches seen: 20.
# Epoch: 378. Batches seen: 0.
# Epoch: 378. Batches seen: 5.
# Epoch: 378. Batches seen: 10.
# Epoch: 378. Batches seen: 15.
# Epoch: 378. Batches seen: 20.
# Epoch: 379. Batches seen: 0.
# Epoch: 379. Batches seen: 5.
# Epoch: 379. Batches seen: 10.
# Epoch: 379. Batches seen: 15.
# Epoch: 379. Batches seen: 20.
# Epoch: 380. Batches seen: 0.
# Epoch: 380. Batches seen: 5.
# Epoch: 380. Batches seen: 10.
# Epoch: 380. Batches seen: 15.
# Epoch: 380. Batches seen: 20.
# Epoch: 381. Batches seen: 0.
# Epoch: 381. Batches seen: 5.
# Epoch: 381. Batches seen: 10.
# Epoch: 381. Batches seen: 15.
# Epoch: 381. Batches seen: 20.
# Epoch: 382. Batches seen: 0.
# Epoch: 382. Batches seen: 5.
# Epoch: 382. Batches seen: 10.
# Epoch: 382. Batches seen: 15.
# Epoch: 382. Batches seen: 20.
# Epoch: 383. Batches seen: 0.
# Epoch: 383. Batches seen: 5.
# Epoch: 383. Batches seen: 10.
# Epoch: 383. Batches seen: 15.
# Epoch: 383. Batches seen: 20.
# Epoch: 384. Batches seen: 0.
# Epoch: 384. Batches seen: 5.
# Epoch: 384. Batches seen: 10.
# Epoch: 384. Batches seen: 15.
# Epoch: 384. Batches seen: 20.
# Epoch: 385. Batches seen: 0.
# Epoch: 385. Batches seen: 5.
# Epoch: 385. Batches seen: 10.
# Epoch: 385. Batches seen: 15.
# Epoch: 385. Batches seen: 20.
# Epoch: 386. Batches seen: 0.
# Epoch: 386. Batches seen: 5.
# Epoch: 386. Batches seen: 10.
# Epoch: 386. Batches seen: 15.
# Epoch: 386. Batches seen: 20.
# Epoch: 387. Batches seen: 0.
# Epoch: 387. Batches seen: 5.
# Epoch: 387. Batches seen: 10.
# Epoch: 387. Batches seen: 15.
# Epoch: 387. Batches seen: 20.
# Epoch: 388. Batches seen: 0.
# Epoch: 388. Batches seen: 5.
# Epoch: 388. Batches seen: 10.
# Epoch: 388. Batches seen: 15.
# Epoch: 388. Batches seen: 20.
# Epoch: 389. Batches seen: 0.
# Epoch: 389. Batches seen: 5.
# Epoch: 389. Batches seen: 10.
# Epoch: 389. Batches seen: 15.
# Epoch: 389. Batches seen: 20.
# Epoch: 390. Batches seen: 0.
# Epoch: 390. Batches seen: 5.
# Epoch: 390. Batches seen: 10.
# Epoch: 390. Batches seen: 15.
# Epoch: 390. Batches seen: 20.
# Epoch: 391. Batches seen: 0.
# Epoch: 391. Batches seen: 5.
# Epoch: 391. Batches seen: 10.
# Epoch: 391. Batches seen: 15.
# Epoch: 391. Batches seen: 20.
# Epoch: 392. Batches seen: 0.
# Epoch: 392. Batches seen: 5.
# Epoch: 392. Batches seen: 10.
# Epoch: 392. Batches seen: 15.
# Epoch: 392. Batches seen: 20.
# Epoch: 393. Batches seen: 0.
# Epoch: 393. Batches seen: 5.
# Epoch: 393. Batches seen: 10.
# Epoch: 393. Batches seen: 15.
# Epoch: 393. Batches seen: 20.
# Epoch: 394. Batches seen: 0.
# Epoch: 394. Batches seen: 5.
# Epoch: 394. Batches seen: 10.
# Epoch: 394. Batches seen: 15.
# Epoch: 394. Batches seen: 20.
# Epoch: 395. Batches seen: 0.
# Epoch: 395. Batches seen: 5.
# Epoch: 395. Batches seen: 10.
# Epoch: 395. Batches seen: 15.
# Epoch: 395. Batches seen: 20.
# Epoch: 396. Batches seen: 0.
# Epoch: 396. Batches seen: 5.
# Epoch: 396. Batches seen: 10.
# Epoch: 396. Batches seen: 15.
# Epoch: 396. Batches seen: 20.
# Epoch: 397. Batches seen: 0.
# Epoch: 397. Batches seen: 5.
# Epoch: 397. Batches seen: 10.
# Epoch: 397. Batches seen: 15.
# Epoch: 397. Batches seen: 20.
# Epoch: 398. Batches seen: 0.
# Epoch: 398. Batches seen: 5.
# Epoch: 398. Batches seen: 10.
# Epoch: 398. Batches seen: 15.
# Epoch: 398. Batches seen: 20.
# Epoch: 399. Batches seen: 0.
# Epoch: 399. Batches seen: 5.
# Epoch: 399. Batches seen: 10.
# Epoch: 399. Batches seen: 15.
# Epoch: 399. Batches seen: 20.

# %%
fake_image = fake_images[-1]
fake_image[10][0].shape
# Out:
# torch.Size([64, 64])

# %%
print('Fake Generated Images:')

for i in range(1, 16):
    grid = plt.subplot(4, 4, i)
    plt.axis(False)
    plt.imshow(fake_image[i][0].squeeze(dim=0).cpu().detach().numpy(), cmap='gray')
# Out:
# Fake Generated Images:

# %%
# Saving the DCGAN
torch.save(gen.state_dict(), 'saved models/Generator.pth')
torch.save(disc.state_dict(), 'saved models/Discriminator.pth')
